# %%
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QVBoxLayout, QLabel, QCheckBox, QSpinBox
import serial
import time
import base64
#import keyboard

# %% [markdown]
# # UI

# %%
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QVBoxLayout, QLabel, QCheckBox, QSpinBox

class MotorControlerUI(QWidget):
    def __init__(self):
        super().__init__()
        self.initUI()
        self.ui_events = []

    def initUI(self):
        # Create buttons s1 to s6
        self.buttons = []
        button_pos =[(50,50),(50,100),(50,150),(50,200),(50,250),(50,300)]
        for i in range(1, 7):
            button = QPushButton(f'S{i}', self)
            button.clicked.connect(self.buttonClicked)
            button.move(button_pos[i-1][0],button_pos[i-1][1])
            self.buttons.append(button)

        #labels for s1->s6
        self.labels = []
        label_pos = [(bp[0]*4,bp[1]) for bp in button_pos]
        for i in range(1,7):
            label = QLabel(f"Label{i}",self)
            label.move(label_pos[i-1][0],label_pos[i-1][1])
            label.setText("0")
            label.setFixedWidth(50)
            self.labels.append(label)

        #spinBox for s1->s6
        self.spinboxs = []
        spinbox_pos = [(bp[0]*6,bp[1]) for bp in button_pos]
        for i in range(1,7):
            spinbox = QSpinBox(self)
            spinbox.setObjectName(f"s{i}")
            spinbox.setRange(-500,500)
            spinbox.setFixedWidth(150)
            spinbox.move(spinbox_pos[i-1][0],spinbox_pos[i-1][1])
            self.spinboxs.append(spinbox)
        
        #buton pairs (1-6,2-5,3-4)
        self.pair_buttons = []
        pair_button_pos = [(bp[0]*10,bp[1]) for bp in button_pos[:3]]
        pair_button_names = ["S1-6","S2-5","S3-4"]
        for i in range(3):
            button = QPushButton(pair_button_names[i], self)
            button.clicked.connect(self.pairButtonCliked)
            button.move(pair_button_pos[i][0],pair_button_pos[i][1])
            self.pair_buttons.append(button)
        
        #spinbox pairs (1-6,2-5,3-4)
        self.pair_spinboxs = []
        pair_spinbox_pos = [(bp[0]*12,bp[1]) for bp in button_pos[:3]]
        for i in range(3):
            spinbox = QSpinBox(self)
            spinbox.setObjectName(pair_button_names[i])
            spinbox.setRange(-500,500)
            spinbox.setFixedWidth(150)
            spinbox.move(pair_spinbox_pos[i][0],pair_spinbox_pos[i][1])
            self.pair_spinboxs.append(spinbox)


        #time input
        self.timeInput = QSpinBox(self)
        self.timeInput.setObjectName("timeInput")
        self.timeInput.setRange(800,100000)
        self.timeInput.setFixedWidth(150)
        self.timeInput.move(spinbox_pos[5][0],spinbox_pos[5][1]+100)

        #time input explanation
        self.labelTime = QLabel("Time pr. instruction",self)
        self.labelTime.move(label_pos[5][0]-50,label_pos[5][1]+100)

        #spinbox header
        self.labelInfo = QLabel("- = ClockWise",self)
        self.labelInfo.move(spinbox_pos[0][0],spinbox_pos[0][1]-25)

        #label header
        self.labelPos = QLabel("MotorPosition",self)
        self.labelPos.move(label_pos[0][0],label_pos[0][1]-25)

        #all motors input
        self.allButton = QPushButton(f'S1-6', self)
        self.allButton.clicked.connect(self.allButtonClicked)
        self.allButton.move(button_pos[5][0],button_pos[5][1]+100)

        #start protocol
        self.startProt = QPushButton("StartProtocol",self)
        self.startProt.clicked.connect(self.startProtocol)
        self.startProt.move(button_pos[5][0],button_pos[5][1]+200)

        self.setWindowTitle('Motor controler')
        self.setGeometry(300, 300, 800, 600)  # Set window position and size

    #UPDATES
    def updateLabels(self,mc): #pass array of motor change values to update labels
        for i in range(6):
            label = self.labels[i]
            cur_val = int(label.text())
            label.setText(str(cur_val+mc[i]))


    #UI EVENTS
    def buttonClicked(self): #button click (adds spinbox to label)
        sender = self.sender()
        index = int(sender.text()[1]) - 1
        spinbox = self.spinboxs[index]
        change_val = spinbox.value()
        label = self.labels[index]
        cur_val = int(label.text())
        new_val = change_val+cur_val
        label.setText(str(new_val))
        #get time
        time_val = self.timeInput.value()

        self.ui_events.append(["1B",index,change_val,time_val,f'Button {sender.text()} clicked. With Value {change_val}: {cur_val} -> {new_val}'])

    def allButtonClicked(self): #button for running all motors at the same time
        mc = [0,0,0,0,0,0]
        time_val = self.timeInput.value()
        
        for i in range(6): #get value from each of the spin boxes
            mc[i] = self.spinboxs[i].value()
            label = self.labels[i]
            label.setText(str(mc[i]+int(label.text())))

        self.ui_events.append(["AB",mc,time_val,f"Allbutton {self.sender().text()} clicked. With Values {mc}'"])

    def startProtocol(self):
        self.ui_events.append(["SP",f"StartProtocol {self.sender().text()} clicked."])

    def pairButtonCliked(self):
        sender = self.sender().text()
        time_val = self.timeInput.value()
        mc = [0,0,0,0,0,0]
        match sender: #could be made cleaner with a map or somting
            case "S1-6":
                val = self.pair_spinboxs[0].value()
                mc[0] = val
                mc[5] = val
            case "S2-5": #s2-5
                val = self.pair_spinboxs[1].value()
                mc[1] = val
                mc[4] = val   
            case "S3-4": #s3-4
                val = self.pair_spinboxs[2].value()
                mc[2] = val
                mc[3] = val

        self.updateLabels(mc)
        self.ui_events.append(["PB",mc,time_val,f"Pairbutton {sender} clicked. With Values {mc}'"])


#Handle events
def handleUIEvents(ui_widget,mc,timeval,protocol):
    while ui_widget.ui_events:
        event = ui_widget.ui_events.pop(0)
        print(event)

        match event[0]: #TODO: make a standard structure for events (but good enough for now)
            case "1B": #1:idx 2:changeVal 3: time val
                mc[event[1]] = event[2]
                timeval[0] = event[3]
            case "AB": #1: mcVal #2:time val
                #print(mc)
                for i in range(6):
                    mc[i] = event[1][i]
                #mc = event[1]
                #print(mc)
                timeval[0] = event[2]
            case "SP":
                protocol[0] = True
            case "PB":
                for i in range(6):
                    mc[i] = event[1][i]
                timeval[0] = event[2]
            case _:
                print(f"Unknown first event {event[0]}")

    app.processEvents()

# %% [markdown]
# # Serial protocol

# %%
#initial protocol from https://forum.arduino.cc/t/serial-input-basics-updated/382007/2
# and https://forum.arduino.cc/t/pc-arduino-comms-using-python-updated/574496 

startMarker = '<'
endMarker = '>'
dataStarted = False
dataBuf = ""
messageComplete = False

#========================
#========================
    # the functions

def setupSerial(baudRate, serialPortName):
    global  serialPort
    serialPort = serial.Serial(port= serialPortName, baudrate = baudRate, timeout=0, rtscts=True)
    print("Serial port " + serialPortName + " opened  Baudrate " + str(baudRate))
    waitForArduino()

#========================

def sendToArduino(stringToSend):
    # this adds the start- and end-markers before sending
    global startMarker, endMarker, serialPort
    
    stringWithMarkers = (startMarker)
    stringWithMarkers += stringToSend
    stringWithMarkers += (endMarker)

    serialPort.write(stringWithMarkers.encode('utf-8')) # encode needed for Python3


#==================

def recvLikeArduino():

    global startMarker, endMarker, serialPort, dataStarted, dataBuf, messageComplete

    if serialPort.inWaiting() > 0 and messageComplete == False:
        x = serialPort.read().decode("utf-8") # decode needed for Python3
        
        if dataStarted == True:
            if x != endMarker:
                dataBuf = dataBuf + x
            else:
                dataStarted = False
                messageComplete = True
        elif x == startMarker:
            dataBuf = ''
            dataStarted = True
    
    if (messageComplete == True):
        messageComplete = False
        return dataBuf
    else:
        return "XXX" 

#==================

def waitForArduino():
    # wait until the Arduino sends 'Arduino is ready' - allows time for Arduino reset
    # it also ensures that any bytes left over from a previous message are discarded
    print("Waiting for Arduino to reset")
     
    msg = ""
    while msg.find("Arduino is ready") == -1:
        msg = recvLikeArduino()
        if not (msg == 'XXX'): 
            print(msg)

# %% [markdown]
# # Messaging protocol

# %%
#<msg> (where "<" starts a msg and ">" ends 1)

#start <
#first char is used for identifying the type of msg. M=reltive move, R=reset
#next 4x6 chars are used for the amount you want the steppers to move 2signed bytes pr stepper
#4bytes for the amount of time to complete the moves
#end >

def num_to_hex(num):
  if num > 32767  or num < -32768:
    raise TypeError(f"Number {num} is does not fit withing 4 char hex")
  
  # Convert negative numbers to two's complement representation
  if num < 0:
    num = (1 << 16) + num
  
  hex_value = hex(num & 0xFFFF)[2:].zfill(4)  # Convert to hexadecimal and pad with zeros
  return hex_value

def hex_to_num(hex_string):
  if not isinstance(hex_string, str) or len(hex_string) != 4:
    TypeError(f"Input must be a string of 4 characters")
  
  num = int(hex_string, 16)
  # Handle negative numbers
  if num >= 0x8000:
      num -= 1 << 16
  return num

#convert array of relative motor steps to a string that can be sent to the arduino
#current types: (R) and M
def encode_motor_msg(motor_steps,timer,msg_type):
  if not(msg_type in ["M","R"]):
    TypeError(f"Unknown msg_type: {msg_type}")
  
  if len(motor_steps) != 6:
    TypeError(f"Expected 6 motor values got: {motor_steps}")
  
  motor_hex = ""
  for ms in motor_steps:
    motor_hex += num_to_hex(ms)
  
  time_hex = num_to_hex(timer)

  return msg_type + motor_hex + time_hex

#decode motor message

def decode_motor_msg(motor_msg):
  msg_type = motor_msg[0]
  motor_hex = motor_msg[1:25]
  timer_hex = motor_msg[25:29]

  motor_vals = []
  for i in range(0,24,4):
    motor_vals.append(hex_to_num(motor_hex[i:i+4])) 
  

  return msg_type, motor_vals, hex_to_num(timer_hex)


# Examples:
numbers = [-1234, 32767, 9012, 3456, -7890, 1234]

for i in numbers:
  hexval = num_to_hex(i)
  print(hexval,hex_to_num(hexval))

fullEncode = encode_motor_msg(numbers,1000,"M")
print(fullEncode,decode_motor_msg(fullEncode))
# Out:
# fb2e -1234
# 7fff 32767
# 2334 9012
# 0d80 3456
# e12e -7890
# 04d2 1234
# Mfb2e7fff23340d80e12e04d203e8 ('M', [-1234, 32767, 9012, 3456, -7890, 1234], 1000)

# %% [markdown]
# # Protocols

# %%
import itertools

# Define the ranges for each number
ranges = [
    range(-20, 21,20),  # Range for a
    range(-20, 21,20),  # Range for b
    range(-20, 21,20),  # Range for c
    range(-20, 21,20),  # Range for d
    range(-20, 21,20),  # Range for e
    range(-20, 21,20),  # Range for f
]

# Generate all combinations
combinations = list(itertools.product(*ranges))
#print(len(combinations))
comb_list = list(map(list,combinations))
#print(combinations)
#print(len(set(combinations)))
#print(set(combinations))

#print(comb_list)

# %%
#function for repeatin protocol (does not create copies, uses same ref)
def repeatProtocol(prot,amount):
  return prot*amount

a = [[1],[2],[3]]
repeatProtocol(a,4)

def calcRelativePos(cur,moves):
  rel_moves = []
  cur_poses = []
  for m in moves:
    rel = [0,0,0,0,0,0]
    for i in range(6):
      rel[i] = m[i] - cur[i]
    cur = m
    rel_moves.append(rel)
    cur_poses.append(cur)
  return rel_moves, cur_poses

# %%
prot_60data, _ = calcRelativePos([0,0,0,0,0,0],comb_list)
prot_60data_50 = prot_60data[:50]

print(len(prot_60data),len(prot_60data_50))
# Out:
# 729 50

# %%
 #up -> reset
prot_ur = [[100,100,100,100,100,100],[-100,-100,-100,-100,-100,-100]]
#up->reset->donw->reset
prot_full = [[100,100,100,100,100,100],[-100,-100,-100,-100,-100,-100],[-100,-100,-100,-100,-100,-100],[100,100,100,100,100,100]] 
prot_34 = [[0,0,100,100,0,0],[0,0,-100,-100,0,0],[0,0,-100,-100,0,0],[0,0,100,100,0,0]]

prot_dr = [[-100,-100,-100,-100,-100,-100],[100,100,100,100,100,100]]

prot_34_down = [[0,0,100,100,0,0],[0,0,-100,-100,0,0]]


prot_full_10 = repeatProtocol(prot_full,10)
prot_updwon_10 = repeatProtocol(prot_ur,50)
prot_34_10 = repeatProtocol(prot_34,10)
prot_dr_10 = repeatProtocol(prot_dr,50)

prot_34_down_50 = repeatProtocol(prot_34_down,50)

# %% [markdown]
# # Main loop

# %%
setupSerial(115200, "COM3")
count = 0
prevTime = time.time()

motor_vals = [0,0,0,0,0,0] #current motor positions
motor_change = [0,0,0,0,0,0] #Changes for next motor iteration
time_val = [1] # time pointer

def calcMotorvals(cur,new):
    return [a+b for a,b in zip(cur,new)]

protocol_running = [False] #protocol pointer
protocol_ctr = 0 #counter for where in protocl we are
protocol_delay = 2 #in seconds
protocol_mc = prot_60data#prot_updwon_10 #prot_dr_10
protocol_prevtime = 0
protocol_maxctr = len(protocol_mc)


if __name__ == '__main__':
    app = QApplication(sys.argv)
    mcUI = MotorControlerUI()
    mcUI.show()

    # Your main loop
    while True:
        # Receive and handle messages from the microcontroller 
        arduinoReply = recvLikeArduino() # check for a reply
        if not (arduinoReply == 'XXX'):
            print ("Time %s  Reply %s" %(time.time(), arduinoReply))
    
        # Handle UI events
        handleUIEvents(mcUI,motor_change,time_val,protocol_running)

        # Respond to the microcontroller
        if motor_change != [0,0,0,0,0,0] and not protocol_running[0]: #control with UI
            motor_vals = calcMotorvals(motor_vals,motor_change) #update total motor values
            enc_msg = encode_motor_msg(motor_change,time_val[0],"M")
            sendToArduino(enc_msg)
            print("motorchange:",motor_change,"msg:", enc_msg, "time:", time_val)

            motor_change = [0,0,0,0,0,0]

        elif protocol_running[0]:
            if time.time() - protocol_prevtime > protocol_delay: #send next move after certain time
                protocol_prevtime = time.time()
                motor_vals = calcMotorvals(motor_vals,protocol_mc[protocol_ctr])

                mcUI.updateLabels(protocol_mc[protocol_ctr]) #update labels in UI

                enc_msg = encode_motor_msg(protocol_mc[protocol_ctr],int(protocol_delay*1000),"M")
                sendToArduino(enc_msg)

                print(protocol_prevtime,f"protocol iteration {protocol_ctr}",protocol_mc[protocol_ctr])
                protocol_ctr += 1
            
            if protocol_ctr == protocol_maxctr: #reset after protocol is finished
                protocol_running[0] = False
                protocol_ctr = 0
                print("protocol finished")


        #elif time.time() - prevTime > 1.0: # send a message at intervals
        #    sendToArduino("this is a test " + str(count))
        #    prevTime = time.time()
        #    count += 1
    
    sys.exit(app.exec_()) #independently run the program
# Out:
# Serial port COM3 opened  Baudrate 115200
# Waiting for Arduino to reset
# Arduino is ready
# ['SP', 'StartProtocol StartProtocol clicked.']
# 1713793019.037227 protocol iteration 0 [-20, -20, -20, -20, -20, -20]
# Time 1713793019.0542316  Reply This just in ... Mffecffecffecffecffecffec07d0   M   -20   -20   -20   -20   -20   -20   2000   20878
# Time 1713793019.0562286  Reply Start driving20880
# 1713793021.0379999 protocol iteration 1 [0, 0, 0, 0, 0, 20]
# Time 1713793021.0541644  Reply Finished driving 22880 S1done S2done S3done S4done S5done S6done
# Time 1713793021.0621626  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   22887
# Time 1713793021.0631695  Reply Start driving22889
# 1713793023.0385516 protocol iteration 2 [0, 0, 0, 0, 0, 20]
# Time 1713793023.0645533  Reply Finished driving 24889 S1done S2done S3done S4done S5done S6done
# Time 1713793023.0725732  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   24896
# Time 1713793023.0735688  Reply Start driving24898
# 1713793025.0386326 protocol iteration 3 [0, 0, 0, 0, 20, -40]
# Time 1713793025.073622  Reply Finished driving 26898 S1done S2done S3done S4done S5done S6done
# Time 1713793025.0806382  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   26905
# Time 1713793025.083638  Reply Start driving26907
# 1713793027.0388124 protocol iteration 4 [0, 0, 0, 0, 0, 20]
# Time 1713793027.0828166  Reply Finished driving 28907 S1done S2done S3done S4done S5done S6done
# Time 1713793027.0918162  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   28914
# Time 1713793027.0928164  Reply Start driving28916
# 1713793029.039314 protocol iteration 5 [0, 0, 0, 0, 0, 20]
# Time 1713793029.0913196  Reply Finished driving 30916 S1done S2done S3done S4done S5done S6done
# Time 1713793029.1003194  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   30923
# Time 1713793029.1023207  Reply Start driving30925
# 1713793031.0399306 protocol iteration 6 [0, 0, 0, 0, 20, -40]
# Time 1713793031.102303  Reply Finished driving 32925 S1done S2done S3done S4done S5done S6done
# Time 1713793031.109319  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   32932
# Time 1713793031.1103194  Reply Start driving32934
# 1713793033.0405354 protocol iteration 7 [0, 0, 0, 0, 0, 20]
# Time 1713793033.1123486  Reply Finished driving 34934 S1done S2done S3done S4done S5done S6done
# Time 1713793033.118367  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   34941
# Time 1713793033.1203656  Reply Start driving34944
# 1713793035.0409722 protocol iteration 8 [0, 0, 0, 0, 0, 20]
# Time 1713793035.1214797  Reply Finished driving 36944 S1done S2done S3done S4done S5done S6done
# Time 1713793035.1297534  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   36952
# Time 1713793035.130753  Reply Start driving36954
# 1713793037.0414748 protocol iteration 9 [0, 0, 0, 20, -40, -40]
# Time 1713793037.131469  Reply Finished driving 38955 S1done S2done S3done S4done S5done S6done
# Time 1713793037.1394699  Reply This just in ... M0000000000000014ffd8ffd807d0   M   0   0   0   20   -40   -40   2000   38962
# Time 1713793037.1414707  Reply Start driving38964
# 1713793039.0424 protocol iteration 10 [0, 0, 0, 0, 0, 20]
# Time 1713793039.1417341  Reply Finished driving 40965 S1done S2done S3done S4done S5done S6done
# Time 1713793039.1497393  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   40972
# Time 1713793039.150743  Reply Start driving40974
# 1713793041.043009 protocol iteration 11 [0, 0, 0, 0, 0, 20]
# Time 1713793041.1520011  Reply Finished driving 42974 S1done S2done S3done S4done S5done S6done
# Time 1713793041.16  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   42981
# Time 1713793041.1609998  Reply Start driving42983
# 1713793043.043908 protocol iteration 12 [0, 0, 0, 0, 20, -40]
# Time 1713793043.1599348  Reply Finished driving 44983 S1done S2done S3done S4done S5done S6done
# Time 1713793043.1679373  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   44990
# Time 1713793043.1709344  Reply Start driving44992
# 1713793045.0444598 protocol iteration 13 [0, 0, 0, 0, 0, 20]
# Time 1713793045.170473  Reply Finished driving 46992 S1done S2done S3done S4done S5done S6done
# Time 1713793045.1774707  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   46999
# Time 1713793045.178475  Reply Start driving47001
# 1713793047.0449 protocol iteration 14 [0, 0, 0, 0, 0, 20]
# Time 1713793047.177821  Reply Finished driving 49001 S1done S2done S3done S4done S5done S6done
# Time 1713793047.1868072  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   49008
# Time 1713793047.18982  Reply Start driving49010
# 1713793049.0455456 protocol iteration 15 [0, 0, 0, 0, 20, -40]
# Time 1713793049.1892245  Reply Finished driving 51010 S1done S2done S3done S4done S5done S6done
# Time 1713793049.1962214  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   51017
# Time 1713793049.1982217  Reply Start driving51019
# 1713793051.0462782 protocol iteration 16 [0, 0, 0, 0, 0, 20]
# Time 1713793051.1980658  Reply Finished driving 53019 S1done S2done S3done S4done S5done S6done
# Time 1713793051.2060883  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   53026
# Time 1713793051.2080834  Reply Start driving53028
# 1713793053.0469124 protocol iteration 17 [0, 0, 0, 0, 0, 20]
# Time 1713793053.2064312  Reply Finished driving 55028 S1done S2done S3done S4done S5done S6done
# Time 1713793053.2144265  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   55035
# Time 1713793053.2174146  Reply Start driving55037
# 1713793055.0478323 protocol iteration 18 [0, 0, 0, 20, -40, -40]
# Time 1713793055.2170594  Reply Finished driving 57037 S1done S2done S3done S4done S5done S6done
# Time 1713793055.2250597  Reply This just in ... M0000000000000014ffd8ffd807d0   M   0   0   0   20   -40   -40   2000   57044
# Time 1713793055.22606  Reply Start driving57047
# 1713793057.0488048 protocol iteration 19 [0, 0, 0, 0, 0, 20]
# Time 1713793057.2288048  Reply Finished driving 59048 S1done S2done S3done S4done S5done S6done
# Time 1713793057.2358015  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   59056
# Time 1713793057.2378037  Reply Start driving59058
# 1713793059.0494227 protocol iteration 20 [0, 0, 0, 0, 0, 20]
# Time 1713793059.236435  Reply Finished driving 61058 S1done S2done S3done S4done S5done S6done
# Time 1713793059.2444365  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   61065
# Time 1713793059.2474363  Reply Start driving61067
# 1713793061.0503047 protocol iteration 21 [0, 0, 0, 0, 20, -40]
# Time 1713793061.2463198  Reply Finished driving 63067 S1done S2done S3done S4done S5done S6done
# Time 1713793061.2543206  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   63074
# Time 1713793061.2573225  Reply Start driving63076
# 1713793063.0513253 protocol iteration 22 [0, 0, 0, 0, 0, 20]
# Time 1713793063.256785  Reply Finished driving 65076 S1done S2done S3done S4done S5done S6done
# Time 1713793063.264824  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   65083
# Time 1713793063.265781  Reply Start driving65085
# 1713793065.051411 protocol iteration 23 [0, 0, 0, 0, 0, 20]
# Time 1713793065.265462  Reply Finished driving 67085 S1done S2done S3done S4done S5done S6done
# Time 1713793065.272461  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   67092
# Time 1713793065.2754633  Reply Start driving67094
# 1713793067.0515149 protocol iteration 24 [0, 0, 0, 0, 20, -40]
# Time 1713793067.2747235  Reply Finished driving 69094 S1done S2done S3done S4done S5done S6done
# Time 1713793067.2827194  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   69101
# Time 1713793067.284702  Reply Start driving69103
# 1713793069.0525172 protocol iteration 25 [0, 0, 0, 0, 0, 20]
# Time 1713793069.2830684  Reply Finished driving 71103 S1done S2done S3done S4done S5done S6done
# Time 1713793069.292049  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   71110
# Time 1713793069.2940493  Reply Start driving71112
# 1713793071.0530517 protocol iteration 26 [0, 0, 0, 0, 0, 20]
# Time 1713793071.2939134  Reply Finished driving 73112 S1done S2done S3done S4done S5done S6done
# Time 1713793071.3012986  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   73119
# Time 1713793071.30193  Reply Start driving73121
# 1713793073.053713 protocol iteration 27 [0, 0, 20, -40, -40, -40]
# Time 1713793073.3035295  Reply Finished driving 75121 S1done S2done S3done S4done S5done S6done
# Time 1713793073.3115478  Reply This just in ... M000000000014ffd8ffd8ffd807d0   M   0   0   20   -40   -40   -40   2000   75128
# Time 1713793073.312546  Reply Start driving75130
# 1713793075.0542076 protocol iteration 28 [0, 0, 0, 0, 0, 20]
# Time 1713793075.312229  Reply Finished driving 77131 S1done S2done S3done S4done S5done S6done
# Time 1713793075.3202412  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   77138
# Time 1713793075.3222415  Reply Start driving77140
# 1713793077.0543027 protocol iteration 29 [0, 0, 0, 0, 0, 20]
# Time 1713793077.3223248  Reply Finished driving 79140 S1done S2done S3done S4done S5done S6done
# Time 1713793077.330333  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   79148
# Time 1713793077.331329  Reply Start driving79150
# 1713793079.05485 protocol iteration 30 [0, 0, 0, 0, 20, -40]
# Time 1713793079.3327603  Reply Finished driving 81150 S1done S2done S3done S4done S5done S6done
# Time 1713793079.3409698  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   81158
# Time 1713793079.3419757  Reply Start driving81160
# 1713793081.0549266 protocol iteration 31 [0, 0, 0, 0, 0, 20]
# Time 1713793081.3409386  Reply Finished driving 83160 S1done S2done S3done S4done S5done S6done
# Time 1713793081.3489447  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   83167
# Time 1713793081.3519282  Reply Start driving83169
# 1713793083.0555146 protocol iteration 32 [0, 0, 0, 0, 0, 20]
# Time 1713793083.350846  Reply Finished driving 85169 S1done S2done S3done S4done S5done S6done
# Time 1713793083.3598473  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   85176
# Time 1713793083.3608491  Reply Start driving85178
# 1713793085.0562322 protocol iteration 33 [0, 0, 0, 0, 20, -40]
# Time 1713793085.3609986  Reply Finished driving 87178 S1done S2done S3done S4done S5done S6done
# Time 1713793085.3689888  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   87185
# Time 1713793085.370001  Reply Start driving87187
# 1713793087.0566518 protocol iteration 34 [0, 0, 0, 0, 0, 20]
# Time 1713793087.3691974  Reply Finished driving 89187 S1done S2done S3done S4done S5done S6done
# Time 1713793087.3781967  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   89194
# Time 1713793087.380196  Reply Start driving89196
# 1713793089.0572343 protocol iteration 35 [0, 0, 0, 0, 0, 20]
# Time 1713793089.3797255  Reply Finished driving 91196 S1done S2done S3done S4done S5done S6done
# Time 1713793089.3877258  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   91203
# Time 1713793089.3887262  Reply Start driving91205
# 1713793091.0572863 protocol iteration 36 [0, 0, 0, 20, -40, -40]
# Time 1713793091.3881435  Reply Finished driving 93205 S1done S2done S3done S4done S5done S6done
# Time 1713793091.3961437  Reply This just in ... M0000000000000014ffd8ffd807d0   M   0   0   0   20   -40   -40   2000   93212
# Time 1713793091.3991606  Reply Start driving93214
# 1713793093.0574324 protocol iteration 37 [0, 0, 0, 0, 0, 20]
# Time 1713793093.3995256  Reply Finished driving 95215 S1done S2done S3done S4done S5done S6done
# Time 1713793093.4065251  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   95222
# Time 1713793093.4095263  Reply Start driving95224
# 1713793095.0583205 protocol iteration 38 [0, 0, 0, 0, 0, 20]
# Time 1713793095.4096441  Reply Finished driving 97224 S1done S2done S3done S4done S5done S6done
# Time 1713793095.4166582  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   97231
# Time 1713793095.4176424  Reply Start driving97233
# 1713793097.0592947 protocol iteration 39 [0, 0, 0, 0, 20, -40]
# Time 1713793097.41841  Reply Finished driving 99233 S1done S2done S3done S4done S5done S6done
# Time 1713793097.4244246  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   99240
# Time 1713793097.4284096  Reply Start driving99243
# 1713793099.059346 protocol iteration 40 [0, 0, 0, 0, 0, 20]
# Time 1713793099.4281569  Reply Finished driving 101243 S1done S2done S3done S4done S5done S6done
# Time 1713793099.4361632  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   101251
# Time 1713793099.4381588  Reply Start driving101253
# 1713793101.0601459 protocol iteration 41 [0, 0, 0, 0, 0, 20]
# Time 1713793101.4397233  Reply Finished driving 103254 S1done S2done S3done S4done S5done S6done
# Time 1713793101.4467425  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   103261
# Time 1713793101.4487467  Reply Start driving103263
# 1713793103.0610926 protocol iteration 42 [0, 0, 0, 0, 20, -40]
# Time 1713793103.448849  Reply Finished driving 105264 S1done S2done S3done S4done S5done S6done
# Time 1713793103.4568267  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   105271
# Time 1713793103.4588416  Reply Start driving105273
# 1713793105.0613678 protocol iteration 43 [0, 0, 0, 0, 0, 20]
# Time 1713793105.4598222  Reply Finished driving 107274 S1done S2done S3done S4done S5done S6done
# Time 1713793105.4688087  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   107281
# Time 1713793105.4698071  Reply Start driving107283
# 1713793107.0616384 protocol iteration 44 [0, 0, 0, 0, 0, 20]
# Time 1713793107.4705548  Reply Finished driving 109284 S1done S2done S3done S4done S5done S6done
# Time 1713793107.4785411  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   109291
# Time 1713793107.479541  Reply Start driving109293
# 1713793109.0619144 protocol iteration 45 [0, 0, 0, 20, -40, -40]
# Time 1713793109.4793074  Reply Finished driving 111294 S1done S2done S3done S4done S5done S6done
# Time 1713793109.4893203  Reply This just in ... M0000000000000014ffd8ffd807d0   M   0   0   0   20   -40   -40   2000   111301
# Time 1713793109.4903276  Reply Start driving111303
# 1713793111.0619352 protocol iteration 46 [0, 0, 0, 0, 0, 20]
# Time 1713793111.489838  Reply Finished driving 113304 S1done S2done S3done S4done S5done S6done
# Time 1713793111.4978364  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   113311
# Time 1713793111.5008214  Reply Start driving113313
# 1713793113.062255 protocol iteration 47 [0, 0, 0, 0, 0, 20]
# Time 1713793113.500906  Reply Finished driving 115314 S1done S2done S3done S4done S5done S6done
# Time 1713793113.5089242  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   115321
# Time 1713793113.5109277  Reply Start driving115323
# 1713793115.0631225 protocol iteration 48 [0, 0, 0, 0, 20, -40]
# Time 1713793115.51089  Reply Finished driving 117324 S1done S2done S3done S4done S5done S6done
# Time 1713793115.5198689  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   117331
# Time 1713793115.5208688  Reply Start driving117334
# 1713793117.064065 protocol iteration 49 [0, 0, 0, 0, 0, 20]
# Time 1713793117.5230572  Reply Finished driving 119335 S1done S2done S3done S4done S5done S6done
# Time 1713793117.5310779  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   119343
# Time 1713793117.5320795  Reply Start driving119345
# 1713793119.0645945 protocol iteration 50 [0, 0, 0, 0, 0, 20]
# Time 1713793119.5330422  Reply Finished driving 121346 S1done S2done S3done S4done S5done S6done
# Time 1713793119.541291  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   121353
# Time 1713793119.5422912  Reply Start driving121355
# 1713793121.064827 protocol iteration 51 [0, 0, 0, 0, 20, -40]
# Time 1713793121.5428858  Reply Finished driving 123355 S1done S2done S3done S4done S5done S6done
# Time 1713793121.5508687  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   123362
# Time 1713793121.5518692  Reply Start driving123364
# 1713793123.0652518 protocol iteration 52 [0, 0, 0, 0, 0, 20]
# Time 1713793123.5515826  Reply Finished driving 125365 S1done S2done S3done S4done S5done S6done
# Time 1713793123.5605826  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   125372
# Time 1713793123.5625823  Reply Start driving125374
# 1713793125.065469 protocol iteration 53 [0, 0, 0, 0, 0, 20]
# Time 1713793125.5622344  Reply Finished driving 127375 S1done S2done S3done S4done S5done S6done
# Time 1713793125.5712373  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   127382
# Time 1713793125.5732362  Reply Start driving127384
# 1713793127.0656679 protocol iteration 54 [0, 0, 20, -40, -40, -40]
# Time 1713793127.573229  Reply Finished driving 129385 S1done S2done S3done S4done S5done S6done
# Time 1713793127.5832336  Reply This just in ... M000000000014ffd8ffd8ffd807d0   M   0   0   20   -40   -40   -40   2000   129393
# Time 1713793127.5852334  Reply Start driving129394
# 1713793129.0661225 protocol iteration 55 [0, 0, 0, 0, 0, 20]
# Time 1713793129.587304  Reply Finished driving 131395 S1done S2done S3done S4done S5done S6done
# Time 1713793129.5952892  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   131402
# Time 1713793129.5962894  Reply Start driving131404
# 1713793131.0665212 protocol iteration 56 [0, 0, 0, 0, 0, 20]
# Time 1713793131.595057  Reply Finished driving 133405 S1done S2done S3done S4done S5done S6done
# Time 1713793131.6020575  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   133412
# Time 1713793131.6030574  Reply Start driving133414
# 1713793133.066983 protocol iteration 57 [0, 0, 0, 0, 20, -40]
# Time 1713793133.6050563  Reply Finished driving 135415 S1done S2done S3done S4done S5done S6done
# Time 1713793133.6130564  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   135422
# Time 1713793133.6140566  Reply Start driving135425
# 1713793135.067551 protocol iteration 58 [0, 0, 0, 0, 0, 20]
# Time 1713793135.6167488  Reply Finished driving 137426 S1done S2done S3done S4done S5done S6done
# Time 1713793135.6247678  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   137434
# Time 1713793135.6247678  Reply Start driving137436
# 1713793137.0680537 protocol iteration 59 [0, 0, 0, 0, 0, 20]
# Time 1713793137.6266327  Reply Finished driving 139437 S1done S2done S3done S4done S5done S6done
# Time 1713793137.6336339  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   139444
# Time 1713793137.6356332  Reply Start driving139446
# 1713793139.0680788 protocol iteration 60 [0, 0, 0, 0, 20, -40]
# Time 1713793139.637606  Reply Finished driving 141447 S1done S2done S3done S4done S5done S6done
# Time 1713793139.644605  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   141454
# Time 1713793139.6466076  Reply Start driving141456
# 1713793141.0685449 protocol iteration 61 [0, 0, 0, 0, 0, 20]
# Time 1713793141.6472917  Reply Finished driving 143457 S1done S2done S3done S4done S5done S6done
# Time 1713793141.6543086  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   143464
# Time 1713793141.65731  Reply Start driving143466
# 1713793143.0688925 protocol iteration 62 [0, 0, 0, 0, 0, 20]
# Time 1713793143.6573062  Reply Finished driving 145467 S1done S2done S3done S4done S5done S6done
# Time 1713793143.6653028  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   145474
# Time 1713793143.6662896  Reply Start driving145476
# 1713793145.0698223 protocol iteration 63 [0, 0, 0, 20, -40, -40]
# Time 1713793145.6681387  Reply Finished driving 147477 S1done S2done S3done S4done S5done S6done
# Time 1713793145.6763902  Reply This just in ... M0000000000000014ffd8ffd807d0   M   0   0   0   20   -40   -40   2000   147484
# Time 1713793145.677386  Reply Start driving147486
# 1713793147.0703309 protocol iteration 64 [0, 0, 0, 0, 0, 20]
# Time 1713793147.6786678  Reply Finished driving 149487 S1done S2done S3done S4done S5done S6done
# Time 1713793147.6866527  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   149494
# Time 1713793147.6876736  Reply Start driving149496
# 1713793149.0705378 protocol iteration 65 [0, 0, 0, 0, 0, 20]
# Time 1713793149.6890414  Reply Finished driving 151497 S1done S2done S3done S4done S5done S6done
# Time 1713793149.6970358  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   151504
# Time 1713793149.6980424  Reply Start driving151506
# 1713793151.0712335 protocol iteration 66 [0, 0, 0, 0, 20, -40]
# Time 1713793151.6976268  Reply Finished driving 153506 S1done S2done S3done S4done S5done S6done
# Time 1713793151.7056382  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   153513
# Time 1713793151.7086334  Reply Start driving153516
# 1713793153.0717173 protocol iteration 67 [0, 0, 0, 0, 0, 20]
# Time 1713793153.7106261  Reply Finished driving 155517 S1done S2done S3done S4done S5done S6done
# Time 1713793153.7176285  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   155525
# Time 1713793153.7196262  Reply Start driving155527
# 1713793155.0726707 protocol iteration 68 [0, 0, 0, 0, 0, 20]
# Time 1713793155.7195184  Reply Finished driving 157528 S1done S2done S3done S4done S5done S6done
# Time 1713793155.7275403  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   157535
# Time 1713793155.7295349  Reply Start driving157537
# 1713793157.073314 protocol iteration 69 [0, 0, 0, 0, 20, -40]
# Time 1713793157.7302182  Reply Finished driving 159538 S1done S2done S3done S4done S5done S6done
# Time 1713793157.7382195  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   159545
# Time 1713793157.7392204  Reply Start driving159547
# 1713793159.0738258 protocol iteration 70 [0, 0, 0, 0, 0, 20]
# Time 1713793159.7404006  Reply Finished driving 161548 S1done S2done S3done S4done S5done S6done
# Time 1713793159.7483947  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   161555
# Time 1713793159.749394  Reply Start driving161557
# 1713793161.0741153 protocol iteration 71 [0, 0, 0, 0, 0, 20]
# Time 1713793161.751133  Reply Finished driving 163558 S1done S2done S3done S4done S5done S6done
# Time 1713793161.7591474  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   163565
# Time 1713793161.7611504  Reply Start driving163567
# 1713793163.074731 protocol iteration 72 [0, 0, 0, 20, -40, -40]
# Time 1713793163.7607362  Reply Finished driving 165567 S1done S2done S3done S4done S5done S6done
# Time 1713793163.7677195  Reply This just in ... M0000000000000014ffd8ffd807d0   M   0   0   0   20   -40   -40   2000   165574
# Time 1713793163.77073  Reply Start driving165576
# 1713793165.0748 protocol iteration 73 [0, 0, 0, 0, 0, 20]
# Time 1713793165.7714238  Reply Finished driving 167577 S1done S2done S3done S4done S5done S6done
# Time 1713793165.7784414  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   167584
# Time 1713793165.7794454  Reply Start driving167586
# 1713793167.0753334 protocol iteration 74 [0, 0, 0, 0, 0, 20]
# Time 1713793167.7816715  Reply Finished driving 169587 S1done S2done S3done S4done S5done S6done
# Time 1713793167.7886894  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   169594
# Time 1713793167.7906885  Reply Start driving169596
# 1713793169.075862 protocol iteration 75 [0, 0, 0, 0, 20, -40]
# Time 1713793169.792036  Reply Finished driving 171597 S1done S2done S3done S4done S5done S6done
# Time 1713793169.8000534  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   171604
# Time 1713793169.802051  Reply Start driving171607
# 1713793171.076129 protocol iteration 76 [0, 0, 0, 0, 0, 20]
# Time 1713793171.802615  Reply Finished driving 173608 S1done S2done S3done S4done S5done S6done
# Time 1713793171.8106263  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   173616
# Time 1713793171.811632  Reply Start driving173618
# 1713793173.076733 protocol iteration 77 [0, 0, 0, 0, 0, 20]
# Time 1713793173.8131146  Reply Finished driving 175619 S1done S2done S3done S4done S5done S6done
# Time 1713793173.8211164  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   175626
# Time 1713793173.8221161  Reply Start driving175628
# 1713793175.077624 protocol iteration 78 [0, 0, 0, 0, 20, -40]
# Time 1713793175.821866  Reply Finished driving 177628 S1done S2done S3done S4done S5done S6done
# Time 1713793175.8298655  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   177635
# Time 1713793175.8328626  Reply Start driving177637
# 1713793177.0780628 protocol iteration 79 [0, 0, 0, 0, 0, 20]
# Time 1713793177.8341584  Reply Finished driving 179638 S1done S2done S3done S4done S5done S6done
# Time 1713793177.8401582  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   179645
# Time 1713793177.8431728  Reply Start driving179647
# 1713793179.0784514 protocol iteration 80 [0, 0, 0, 0, 0, 20]
# Time 1713793179.844684  Reply Finished driving 181648 S1done S2done S3done S4done S5done S6done
# Time 1713793179.851684  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   181655
# Time 1713793179.8526843  Reply Start driving181657
# 1713793181.079193 protocol iteration 81 [0, 20, -40, -40, -40, -40]
# Time 1713793181.8533342  Reply Finished driving 183657 S1done S2done S3done S4done S5done S6done
# Time 1713793181.8613331  Reply This just in ... M00000014ffd8ffd8ffd8ffd807d0   M   0   20   -40   -40   -40   -40   2000   183665
# Time 1713793181.8623364  Reply Start driving183666
# 1713793183.0794091 protocol iteration 82 [0, 0, 0, 0, 0, 20]
# Time 1713793183.8615885  Reply Finished driving 185667 S1done S2done S3done S4done S5done S6done
# Time 1713793183.869582  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   185674
# Time 1713793183.872584  Reply Start driving185676
# 1713793185.0799735 protocol iteration 83 [0, 0, 0, 0, 0, 20]
# Time 1713793185.873472  Reply Finished driving 187677 S1done S2done S3done S4done S5done S6done
# Time 1713793185.8804724  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   187684
# Time 1713793185.8834724  Reply Start driving187686
# 1713793187.080515 protocol iteration 84 [0, 0, 0, 0, 20, -40]
# Time 1713793187.8840802  Reply Finished driving 189687 S1done S2done S3done S4done S5done S6done
# Time 1713793187.8920999  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   189694
# Time 1713793187.8940954  Reply Start driving189697
# 1713793189.0814536 protocol iteration 85 [0, 0, 0, 0, 0, 20]
# Time 1713793189.8947983  Reply Finished driving 191698 S1done S2done S3done S4done S5done S6done
# Time 1713793189.902795  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   191706
# Time 1713793189.9047797  Reply Start driving191708
# 1713793191.0818486 protocol iteration 86 [0, 0, 0, 0, 0, 20]
# Time 1713793191.90551  Reply Finished driving 193709 S1done S2done S3done S4done S5done S6done
# Time 1713793191.9135122  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   193716
# Time 1713793191.9145114  Reply Start driving193718
# 1713793193.0827253 protocol iteration 87 [0, 0, 0, 0, 20, -40]
# Time 1713793193.9162786  Reply Finished driving 195719 S1done S2done S3done S4done S5done S6done
# Time 1713793193.9242773  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   195726
# Time 1713793193.9252765  Reply Start driving195728
# 1713793195.083453 protocol iteration 88 [0, 0, 0, 0, 0, 20]
# Time 1713793195.926302  Reply Finished driving 197729 S1done S2done S3done S4done S5done S6done
# Time 1713793195.934865  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   197736
# Time 1713793195.935873  Reply Start driving197738
# 1713793197.0841792 protocol iteration 89 [0, 0, 0, 0, 0, 20]
# Time 1713793197.9370198  Reply Finished driving 199739 S1done S2done S3done S4done S5done S6done
# Time 1713793197.9450176  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   199746
# Time 1713793197.9470172  Reply Start driving199748
# 1713793199.084452 protocol iteration 90 [0, 0, 0, 20, -40, -40]
# Time 1713793199.946173  Reply Finished driving 201749 S1done S2done S3done S4done S5done S6done
# Time 1713793199.9541678  Reply This just in ... M0000000000000014ffd8ffd807d0   M   0   0   0   20   -40   -40   2000   201756
# Time 1713793199.9571724  Reply Start driving201758
# 1713793201.0850124 protocol iteration 91 [0, 0, 0, 0, 0, 20]
# Time 1713793201.957109  Reply Finished driving 203759 S1done S2done S3done S4done S5done S6done
# Time 1713793201.9651115  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   203766
# Time 1713793201.9671133  Reply Start driving203768
# 1713793203.0850663 protocol iteration 92 [0, 0, 0, 0, 0, 20]
# Time 1713793203.967707  Reply Finished driving 205769 S1done S2done S3done S4done S5done S6done
# Time 1713793203.9757056  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   205776
# Time 1713793203.9777055  Reply Start driving205778
# 1713793205.085789 protocol iteration 93 [0, 0, 0, 0, 20, -40]
# Time 1713793205.9772482  Reply Finished driving 207778 S1done S2done S3done S4done S5done S6done
# Time 1713793205.9852502  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   207785
# Time 1713793205.9872518  Reply Start driving207788
# 1713793207.0860329 protocol iteration 94 [0, 0, 0, 0, 0, 20]
# Time 1713793207.9888897  Reply Finished driving 209789 S1done S2done S3done S4done S5done S6done
# Time 1713793207.9968905  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   209797
# Time 1713793207.997872  Reply Start driving209799
# 1713793209.0869071 protocol iteration 95 [0, 0, 0, 0, 0, 20]
# Time 1713793210.0005553  Reply Finished driving 211800 S1done S2done S3done S4done S5done S6done
# Time 1713793210.0085697  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   211807
# Time 1713793210.009572  Reply Start driving211809
# 1713793211.0874286 protocol iteration 96 [0, 0, 0, 0, 20, -40]
# Time 1713793212.009319  Reply Finished driving 213810 S1done S2done S3done S4done S5done S6done
# Time 1713793212.017321  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   213817
# Time 1713793212.0193202  Reply Start driving213819
# 1713793213.0876164 protocol iteration 97 [0, 0, 0, 0, 0, 20]
# Time 1713793214.0202467  Reply Finished driving 215820 S1done S2done S3done S4done S5done S6done
# Time 1713793214.027246  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   215827
# Time 1713793214.029246  Reply Start driving215829
# 1713793215.088438 protocol iteration 98 [0, 0, 0, 0, 0, 20]
# Time 1713793216.0296047  Reply Finished driving 217830 S1done S2done S3done S4done S5done S6done
# Time 1713793216.0378363  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   217837
# Time 1713793216.039859  Reply Start driving217839
# 1713793217.089007 protocol iteration 99 [0, 0, 0, 20, -40, -40]
# Time 1713793218.039617  Reply Finished driving 219839 S1done S2done S3done S4done S5done S6done
# Time 1713793218.0486166  Reply This just in ... M0000000000000014ffd8ffd807d0   M   0   0   0   20   -40   -40   2000   219846
# Time 1713793218.049616  Reply Start driving219848
# 1713793219.0896232 protocol iteration 100 [0, 0, 0, 0, 0, 20]
# Time 1713793220.050143  Reply Finished driving 221849 S1done S2done S3done S4done S5done S6done
# Time 1713793220.0581627  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   221856
# Time 1713793220.0591648  Reply Start driving221858
# 1713793221.0905216 protocol iteration 101 [0, 0, 0, 0, 0, 20]
# Time 1713793222.0596914  Reply Finished driving 223859 S1done S2done S3done S4done S5done S6done
# Time 1713793222.068693  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   223866
# Time 1713793222.070708  Reply Start driving223868
# 1713793223.0916197 protocol iteration 102 [0, 0, 0, 0, 20, -40]
# Time 1713793224.0710268  Reply Finished driving 225869 S1done S2done S3done S4done S5done S6done
# Time 1713793224.0780478  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   225876
# Time 1713793224.0810444  Reply Start driving225879
# 1713793225.092289 protocol iteration 103 [0, 0, 0, 0, 0, 20]
# Time 1713793226.0807056  Reply Finished driving 227880 S1done S2done S3done S4done S5done S6done
# Time 1713793226.0897088  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   227888
# Time 1713793226.09177  Reply Start driving227890
# 1713793227.092668 protocol iteration 104 [0, 0, 0, 0, 0, 20]
# Time 1713793228.0918162  Reply Finished driving 229891 S1done S2done S3done S4done S5done S6done
# Time 1713793228.100821  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   229898
# Time 1713793228.1028247  Reply Start driving229900
# 1713793229.0934823 protocol iteration 105 [0, 0, 0, 0, 20, -40]
# Time 1713793230.102688  Reply Finished driving 231901 S1done S2done S3done S4done S5done S6done
# Time 1713793230.1109204  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   231908
# Time 1713793230.1129138  Reply Start driving231910
# 1713793231.0939686 protocol iteration 106 [0, 0, 0, 0, 0, 20]
# Time 1713793232.1137505  Reply Finished driving 233911 S1done S2done S3done S4done S5done S6done
# Time 1713793232.1207683  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   233918
# Time 1713793232.1217728  Reply Start driving233920
# 1713793233.0942564 protocol iteration 107 [0, 0, 0, 0, 0, 20]
# Time 1713793234.1235478  Reply Finished driving 235921 S1done S2done S3done S4done S5done S6done
# Time 1713793234.1315544  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   235928
# Time 1713793234.13255  Reply Start driving235930
# 1713793235.0943341 protocol iteration 108 [0, 0, 20, -40, -40, -40]
# Time 1713793236.132546  Reply Finished driving 237930 S1done S2done S3done S4done S5done S6done
# Time 1713793236.140544  Reply This just in ... M000000000014ffd8ffd8ffd807d0   M   0   0   20   -40   -40   -40   2000   237938
# Time 1713793236.1425443  Reply Start driving237939
# 1713793237.0952828 protocol iteration 109 [0, 0, 0, 0, 0, 20]
# Time 1713793238.14279  Reply Finished driving 239940 S1done S2done S3done S4done S5done S6done
# Time 1713793238.1507926  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   239947
# Time 1713793238.1537943  Reply Start driving239949
# 1713793239.0955555 protocol iteration 110 [0, 0, 0, 0, 0, 20]
# Time 1713793240.1535575  Reply Finished driving 241950 S1done S2done S3done S4done S5done S6done
# Time 1713793240.1615577  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   241957
# Time 1713793240.1625636  Reply Start driving241959
# 1713793241.0961199 protocol iteration 111 [0, 0, 0, 0, 20, -40]
# Time 1713793242.1634505  Reply Finished driving 243960 S1done S2done S3done S4done S5done S6done
# Time 1713793242.17247  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   243968
# Time 1713793242.1734684  Reply Start driving243970
# 1713793243.0969324 protocol iteration 112 [0, 0, 0, 0, 0, 20]
# Time 1713793244.1753583  Reply Finished driving 245971 S1done S2done S3done S4done S5done S6done
# Time 1713793244.1836085  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   245979
# Time 1713793244.1846144  Reply Start driving245981
# 1713793245.0976582 protocol iteration 113 [0, 0, 0, 0, 0, 20]
# Time 1713793246.1861947  Reply Finished driving 247982 S1done S2done S3done S4done S5done S6done
# Time 1713793246.1935573  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   247989
# Time 1713793246.1955576  Reply Start driving247991
# 1713793247.0991385 protocol iteration 114 [0, 0, 0, 0, 20, -40]
# Time 1713793248.1970348  Reply Finished driving 249992 S1done S2done S3done S4done S5done S6done
# Time 1713793248.20504  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   249999
# Time 1713793248.207034  Reply Start driving250001
# 1713793249.0995743 protocol iteration 115 [0, 0, 0, 0, 0, 20]
# Time 1713793250.207209  Reply Finished driving 252002 S1done S2done S3done S4done S5done S6done
# Time 1713793250.2152112  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   252009
# Time 1713793250.21721  Reply Start driving252011
# 1713793251.1005123 protocol iteration 116 [0, 0, 0, 0, 0, 20]
# Time 1713793252.2174833  Reply Finished driving 254012 S1done S2done S3done S4done S5done S6done
# Time 1713793252.225484  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   254019
# Time 1713793252.2264838  Reply Start driving254021
# 1713793253.1011744 protocol iteration 117 [0, 0, 0, 20, -40, -40]
# Time 1713793254.2261422  Reply Finished driving 256021 S1done S2done S3done S4done S5done S6done
# Time 1713793254.2351565  Reply This just in ... M0000000000000014ffd8ffd807d0   M   0   0   0   20   -40   -40   2000   256028
# Time 1713793254.236165  Reply Start driving256030
# 1713793255.1013966 protocol iteration 118 [0, 0, 0, 0, 0, 20]
# Time 1713793256.2377474  Reply Finished driving 258031 S1done S2done S3done S4done S5done S6done
# Time 1713793256.2457712  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   258038
# Time 1713793256.246752  Reply Start driving258040
# 1713793257.1020021 protocol iteration 119 [0, 0, 0, 0, 0, 20]
# Time 1713793258.248342  Reply Finished driving 260041 S1done S2done S3done S4done S5done S6done
# Time 1713793258.257342  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   260048
# Time 1713793258.258353  Reply Start driving260050
# 1713793259.1029537 protocol iteration 120 [0, 0, 0, 0, 20, -40]
# Time 1713793260.2578783  Reply Finished driving 262051 S1done S2done S3done S4done S5done S6done
# Time 1713793260.2658832  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   262059
# Time 1713793260.26688  Reply Start driving262061
# 1713793261.1034336 protocol iteration 121 [0, 0, 0, 0, 0, 20]
# Time 1713793262.2709558  Reply Finished driving 264062 S1done S2done S3done S4done S5done S6done
# Time 1713793262.2799563  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   264070
# Time 1713793262.281958  Reply Start driving264072
# 1713793263.1040397 protocol iteration 122 [0, 0, 0, 0, 0, 20]
# Time 1713793264.279107  Reply Finished driving 266073 S1done S2done S3done S4done S5done S6done
# Time 1713793264.287107  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   266080
# Time 1713793264.2901154  Reply Start driving266082
# 1713793265.104766 protocol iteration 123 [0, 0, 0, 0, 20, -40]
# Time 1713793266.2881522  Reply Finished driving 268082 S1done S2done S3done S4done S5done S6done
# Time 1713793266.2961504  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   268089
# Time 1713793266.29815  Reply Start driving268091
# 1713793267.105594 protocol iteration 124 [0, 0, 0, 0, 0, 20]
# Time 1713793268.2999432  Reply Finished driving 270092 S1done S2done S3done S4done S5done S6done
# Time 1713793268.307945  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   270099
# Time 1713793268.3089447  Reply Start driving270101
# 1713793269.105971 protocol iteration 125 [0, 0, 0, 0, 0, 20]
# Time 1713793270.3095222  Reply Finished driving 272102 S1done S2done S3done S4done S5done S6done
# Time 1713793270.3185275  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   272109
# Time 1713793270.319526  Reply Start driving272111
# 1713793271.106591 protocol iteration 126 [0, 0, 0, 20, -40, -40]
# Time 1713793272.318725  Reply Finished driving 274111 S1done S2done S3done S4done S5done S6done
# Time 1713793272.3267255  Reply This just in ... M0000000000000014ffd8ffd807d0   M   0   0   0   20   -40   -40   2000   274118
# Time 1713793272.3297255  Reply Start driving274120
# 1713793273.106922 protocol iteration 127 [0, 0, 0, 0, 0, 20]
# Time 1713793274.3293486  Reply Finished driving 276121 S1done S2done S3done S4done S5done S6done
# Time 1713793274.3373487  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   276128
# Time 1713793274.3393486  Reply Start driving276130
# 1713793275.1072338 protocol iteration 128 [0, 0, 0, 0, 0, 20]
# Time 1713793276.3400846  Reply Finished driving 278131 S1done S2done S3done S4done S5done S6done
# Time 1713793276.347102  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   278138
# Time 1713793276.3480992  Reply Start driving278140
# 1713793277.1082246 protocol iteration 129 [0, 0, 0, 0, 20, -40]
# Time 1713793278.3500473  Reply Finished driving 280141 S1done S2done S3done S4done S5done S6done
# Time 1713793278.3580482  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   280148
# Time 1713793278.3590484  Reply Start driving280151
# 1713793279.108486 protocol iteration 130 [0, 0, 0, 0, 0, 20]
# Time 1713793280.361536  Reply Finished driving 282152 S1done S2done S3done S4done S5done S6done
# Time 1713793280.3708653  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   282160
# Time 1713793280.3723743  Reply Start driving282162
# 1713793281.10849 protocol iteration 131 [0, 0, 0, 0, 0, 20]
# Time 1713793282.3722105  Reply Finished driving 284163 S1done S2done S3done S4done S5done S6done
# Time 1713793282.3802109  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   284170
# Time 1713793282.3822107  Reply Start driving284172
# 1713793283.109324 protocol iteration 132 [0, 0, 0, 0, 20, -40]
# Time 1713793284.3825562  Reply Finished driving 286173 S1done S2done S3done S4done S5done S6done
# Time 1713793284.3905568  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   286180
# Time 1713793284.3915577  Reply Start driving286182
# 1713793285.110307 protocol iteration 133 [0, 0, 0, 0, 0, 20]
# Time 1713793286.3913667  Reply Finished driving 288183 S1done S2done S3done S4done S5done S6done
# Time 1713793286.4003718  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   288190
# Time 1713793286.4023657  Reply Start driving288192
# 1713793287.1103575 protocol iteration 134 [0, 0, 0, 0, 0, 20]
# Time 1713793288.4029708  Reply Finished driving 290193 S1done S2done S3done S4done S5done S6done
# Time 1713793288.4099772  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   290200
# Time 1713793288.4129565  Reply Start driving290202
# 1713793289.110753 protocol iteration 135 [0, 0, 20, -40, -40, -40]
# Time 1713793290.4130232  Reply Finished driving 292203 S1done S2done S3done S4done S5done S6done
# Time 1713793290.4220228  Reply This just in ... M000000000014ffd8ffd8ffd807d0   M   0   0   20   -40   -40   -40   2000   292211
# Time 1713793290.424022  Reply Start driving292212
# 1713793291.1113162 protocol iteration 136 [0, 0, 0, 0, 0, 20]
# Time 1713793292.4231167  Reply Finished driving 294213 S1done S2done S3done S4done S5done S6done
# Time 1713793292.431121  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   294220
# Time 1713793292.4321134  Reply Start driving294222
# 1713793293.1117668 protocol iteration 137 [0, 0, 0, 0, 0, 20]
# Time 1713793294.4336724  Reply Finished driving 296223 S1done S2done S3done S4done S5done S6done
# Time 1713793294.4416957  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   296230
# Time 1713793294.4426973  Reply Start driving296232
# 1713793295.1120663 protocol iteration 138 [0, 0, 0, 0, 20, -40]
# Time 1713793296.444704  Reply Finished driving 298233 S1done S2done S3done S4done S5done S6done
# Time 1713793296.4526832  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   298241
# Time 1713793296.4536827  Reply Start driving298243
# 1713793297.1126323 protocol iteration 139 [0, 0, 0, 0, 0, 20]
# Time 1713793298.4559264  Reply Finished driving 300244 S1done S2done S3done S4done S5done S6done
# Time 1713793298.463943  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   300252
# Time 1713793298.4649456  Reply Start driving300254
# 1713793299.1127536 protocol iteration 140 [0, 0, 0, 0, 0, 20]
# Time 1713793300.467055  Reply Finished driving 302255 S1done S2done S3done S4done S5done S6done
# Time 1713793300.475069  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   302262
# Time 1713793300.4760761  Reply Start driving302264
# 1713793301.1136491 protocol iteration 141 [0, 0, 0, 0, 20, -40]
# Time 1713793302.4775112  Reply Finished driving 304265 S1done S2done S3done S4done S5done S6done
# Time 1713793302.4855351  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   304272
# Time 1713793302.4865365  Reply Start driving304274
# 1713793303.1145418 protocol iteration 142 [0, 0, 0, 0, 0, 20]
# Time 1713793304.4855957  Reply Finished driving 306275 S1done S2done S3done S4done S5done S6done
# Time 1713793304.4935942  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   306282
# Time 1713793304.496601  Reply Start driving306284
# 1713793305.1152432 protocol iteration 143 [0, 0, 0, 0, 0, 20]
# Time 1713793306.4977455  Reply Finished driving 308285 S1done S2done S3done S4done S5done S6done
# Time 1713793306.5067456  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   308292
# Time 1713793306.5079896  Reply Start driving308294
# 1713793307.1158607 protocol iteration 144 [0, 0, 0, 20, -40, -40]
# ...
# Time 1713793770.9096074  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   772631
# Time 1713793770.9106033  Reply Start driving772633
# 1713793771.2275248 protocol iteration 376 [0, 0, 0, 0, 0, 20]
# Time 1713793772.9092412  Reply Finished driving 774633 S1done S2done S3done S4done S5done S6done
# Time 1713793772.9182413  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   774640
# Time 1713793772.9202418  Reply Start driving774642
# 1713793773.2282653 protocol iteration 377 [0, 0, 0, 0, 0, 20]
# Time 1713793774.9201477  Reply Finished driving 776643 S1done S2done S3done S4done S5done S6done
# Time 1713793774.9291492  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   776650
# Time 1713793774.9311488  Reply Start driving776652
# 1713793775.2286558 protocol iteration 378 [0, 0, 20, -40, -40, -40]
# Time 1713793776.930942  Reply Finished driving 778653 S1done S2done S3done S4done S5done S6done
# Time 1713793776.9389503  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   778660
# Time 1713793776.939945  Reply Start driving778662
# 1713793777.2289739 protocol iteration 379 [0, 0, 0, 0, 0, 20]
# Time 1713793778.941177  Reply Finished driving 780662 S1done S2done S3done S4done S5done S6done
# Time 1713793778.949177  Reply This just in ... M000000000014ffd8ffd8ffd807d0   M   0   0   20   -40   -40   -40   2000   780670
# Time 1713793778.951164  Reply Start driving780672
# 1713793779.2292004 protocol iteration 380 [0, 0, 0, 0, 0, 20]
# Time 1713793780.952149  Reply Finished driving 782673 S1done S2done S3done S4done S5done S6done
# Time 1713793780.9611516  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   782681
# Time 1713793780.9621525  Reply Start driving782683
# 1713793781.2301881 protocol iteration 381 [0, 0, 0, 0, 20, -40]
# Time 1713793782.9628649  Reply Finished driving 784684 S1done S2done S3done S4done S5done S6done
# Time 1713793782.9714456  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   784691
# Time 1713793782.972446  Reply Start driving784693
# 1713793783.2302263 protocol iteration 382 [0, 0, 0, 0, 0, 20]
# Time 1713793784.9731588  Reply Finished driving 786694 S1done S2done S3done S4done S5done S6done
# Time 1713793784.9804134  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   786701
# Time 1713793784.982413  Reply Start driving786703
# 1713793785.2307928 protocol iteration 383 [0, 0, 0, 0, 0, 20]
# Time 1713793786.9820936  Reply Finished driving 788704 S1done S2done S3done S4done S5done S6done
# Time 1713793786.9910944  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   788711
# Time 1713793786.9930983  Reply Start driving788713
# 1713793787.2315466 protocol iteration 384 [0, 0, 0, 0, 20, -40]
# Time 1713793788.9943087  Reply Finished driving 790714 S1done S2done S3done S4done S5done S6done
# Time 1713793789.0023096  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   790721
# Time 1713793789.0043094  Reply Start driving790723
# 1713793789.2317157 protocol iteration 385 [0, 0, 0, 0, 0, 20]
# Time 1713793791.0048234  Reply Finished driving 792724 S1done S2done S3done S4done S5done S6done
# Time 1713793791.0128262  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   792731
# Time 1713793791.0138292  Reply Start driving792733
# 1713793791.2320006 protocol iteration 386 [0, 0, 0, 0, 0, 20]
# Time 1713793793.0152953  Reply Finished driving 794734 S1done S2done S3done S4done S5done S6done
# Time 1713793793.024313  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   794741
# Time 1713793793.0263135  Reply Start driving794743
# 1713793793.2323265 protocol iteration 387 [0, 0, 0, 20, -40, -40]
# Time 1713793795.025198  Reply Finished driving 796744 S1done S2done S3done S4done S5done S6done
# Time 1713793795.0331748  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   796751
# Time 1713793795.0351756  Reply Start driving796753
# 1713793795.2332094 protocol iteration 388 [0, 0, 0, 0, 0, 20]
# Time 1713793797.0338647  Reply Finished driving 798753 S1done S2done S3done S4done S5done S6done
# Time 1713793797.041866  Reply This just in ... M0000000000000014ffd8ffd807d0   M   0   0   0   20   -40   -40   2000   798760
# Time 1713793797.0448658  Reply Start driving798763
# 1713793797.233884 protocol iteration 389 [0, 0, 0, 0, 0, 20]
# Time 1713793799.0453918  Reply Finished driving 800764 S1done S2done S3done S4done S5done S6done
# Time 1713793799.0526364  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   800772
# Time 1713793799.0556328  Reply Start driving800774
# 1713793799.2345667 protocol iteration 390 [0, 0, 0, 0, 20, -40]
# Time 1713793801.055394  Reply Finished driving 802775 S1done S2done S3done S4done S5done S6done
# Time 1713793801.0643902  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   802782
# Time 1713793801.0663905  Reply Start driving802784
# 1713793801.2354515 protocol iteration 391 [0, 0, 0, 0, 0, 20]
# Time 1713793803.066244  Reply Finished driving 804785 S1done S2done S3done S4done S5done S6done
# Time 1713793803.07424  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   804792
# Time 1713793803.0752363  Reply Start driving804794
# 1713793803.2358725 protocol iteration 392 [0, 0, 0, 0, 0, 20]
# Time 1713793805.0775628  Reply Finished driving 806795 S1done S2done S3done S4done S5done S6done
# Time 1713793805.0855658  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   806802
# Time 1713793805.0865638  Reply Start driving806804
# 1713793805.2364857 protocol iteration 393 [0, 0, 0, 0, 20, -40]
# Time 1713793807.0888104  Reply Finished driving 808805 S1done S2done S3done S4done S5done S6done
# Time 1713793807.0958154  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   808812
# Time 1713793807.0968175  Reply Start driving808814
# 1713793807.237465 protocol iteration 394 [0, 0, 0, 0, 0, 20]
# Time 1713793809.0977516  Reply Finished driving 810814 S1done S2done S3done S4done S5done S6done
# Time 1713793809.103752  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   810821
# Time 1713793809.1067538  Reply Start driving810823
# 1713793809.2377145 protocol iteration 395 [0, 0, 0, 0, 0, 20]
# Time 1713793811.1069336  Reply Finished driving 812824 S1done S2done S3done S4done S5done S6done
# Time 1713793811.1149373  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   812831
# Time 1713793811.1179168  Reply Start driving812833
# 1713793811.2379405 protocol iteration 396 [0, 0, 0, 20, -40, -40]
# Time 1713793813.117267  Reply Finished driving 814834 S1done S2done S3done S4done S5done S6done
# Time 1713793813.126269  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   814841
# Time 1713793813.1272757  Reply Start driving814843
# 1713793813.2382748 protocol iteration 397 [0, 0, 0, 0, 0, 20]
# Time 1713793815.1282504  Reply Finished driving 816844 S1done S2done S3done S4done S5done S6done
# Time 1713793815.1362493  Reply This just in ... M0000000000000014ffd8ffd807d0   M   0   0   0   20   -40   -40   2000   816851
# Time 1713793815.137254  Reply Start driving816854
# 1713793815.2388177 protocol iteration 398 [0, 0, 0, 0, 0, 20]
# Time 1713793817.140503  Reply Finished driving 818855 S1done S2done S3done S4done S5done S6done
# Time 1713793817.1475174  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   818863
# Time 1713793817.148522  Reply Start driving818865
# 1713793817.239405 protocol iteration 399 [0, 0, 0, 0, 20, -40]
# Time 1713793819.15004  Reply Finished driving 820866 S1done S2done S3done S4done S5done S6done
# Time 1713793819.1580307  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   820873
# Time 1713793819.1590347  Reply Start driving820875
# 1713793819.2400224 protocol iteration 400 [0, 0, 0, 0, 0, 20]
# Time 1713793821.1602478  Reply Finished driving 822876 S1done S2done S3done S4done S5done S6done
# Time 1713793821.1682565  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   822883
# Time 1713793821.1692514  Reply Start driving822885
# 1713793821.2408545 protocol iteration 401 [0, 0, 0, 0, 0, 20]
# Time 1713793823.1713052  Reply Finished driving 824886 S1done S2done S3done S4done S5done S6done
# Time 1713793823.1773057  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   824893
# Time 1713793823.180306  Reply Start driving824895
# 1713793823.241657 protocol iteration 402 [0, 0, 0, 0, 20, -40]
# Time 1713793825.1814725  Reply Finished driving 826896 S1done S2done S3done S4done S5done S6done
# Time 1713793825.189949  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   826903
# Time 1713793825.1909266  Reply Start driving826905
# 1713793825.2419317 protocol iteration 403 [0, 0, 0, 0, 0, 20]
# Time 1713793827.1909645  Reply Finished driving 828906 S1done S2done S3done S4done S5done S6done
# Time 1713793827.1999674  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   828913
# Time 1713793827.201966  Reply Start driving828915
# 1713793827.2423384 protocol iteration 404 [0, 0, 0, 0, 0, 20]
# Time 1713793829.2019045  Reply Finished driving 830916 S1done S2done S3done S4done S5done S6done
# Time 1713793829.2099066  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   830923
# Time 1713793829.2119079  Reply Start driving830925
# 1713793829.2429087 protocol iteration 405 [0, 20, -40, -40, -40, -40]
# Time 1713793831.2119174  Reply Finished driving 832926 S1done S2done S3done S4done S5done S6done
# Time 1713793831.2208152  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   832933
# Time 1713793831.221815  Reply Start driving832935
# 1713793831.2437348 protocol iteration 406 [0, 0, 0, 0, 0, 20]
# Time 1713793833.222905  Reply Finished driving 834936 S1done S2done S3done S4done S5done S6done
# Time 1713793833.2309132  Reply This just in ... M00000014ffd8ffd8ffd8ffd807d0   M   0   20   -40   -40   -40   -40   2000   834945
# Time 1713793833.2319088  Reply Start driving834946
# 1713793833.2439163 protocol iteration 407 [0, 0, 0, 0, 0, 20]
# Time 1713793835.2344015  Reply Finished driving 836947 S1done S2done S3done S4done S5done S6done
# Time 1713793835.24239  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   836955
# Time 1713793835.2433882  Reply Start driving836957
# 1713793835.2443876 protocol iteration 408 [0, 0, 0, 0, 20, -40]
# 1713793837.245272 protocol iteration 409 [0, 0, 0, 0, 0, 20]
# Time 1713793837.2462723  Reply Finished driving 838958 S1done S2done S3done S4done S5done S6done
# Time 1713793837.2534697  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   838965
# Time 1713793837.2554862  Reply Start driving838967
# 1713793839.2458432 protocol iteration 410 [0, 0, 0, 0, 0, 20]
# Time 1713793839.2560768  Reply Finished driving 840968 S1done S2done S3done S4done S5done S6done
# Time 1713793839.2630813  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   840975
# Time 1713793839.2640767  Reply Start driving840977
# 1713793841.2466834 protocol iteration 411 [0, 0, 0, 0, 20, -40]
# Time 1713793841.2646852  Reply Finished driving 842978 S1done S2done S3done S4done S5done S6done
# Time 1713793841.2726884  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   842985
# Time 1713793841.2757058  Reply Start driving842987
# 1713793843.246744 protocol iteration 412 [0, 0, 0, 0, 0, 20]
# Time 1713793843.2747493  Reply Finished driving 844987 S1done S2done S3done S4done S5done S6done
# Time 1713793843.2827482  Reply This just in ... 00000000000000001407d0   0   0   0   0   1   16509   0   2000   844994
# Time 1713793843.2837481  Reply Start driving844995
# 1713793845.2473793 protocol iteration 413 [0, 0, 0, 0, 0, 20]
# Time 1713793845.2820976  Reply Finished driving 846996 S1done S2done S3done S4done S6done
# Time 1713793845.2920983  Reply This just in ... M000000<M00000000000000000000001407d0   M   0   0   0   0   0   0   0   847003
# Time 1713793845.2930973  Reply Start driving847005
# Time 1713793845.298101  Reply Finished driving 847007 S1done S2done S3done S4done S6done
# 1713793847.2480125 protocol iteration 414 [0, 0, 0, 20, -40, -40]
# Time 1713793847.2632947  Reply This just in ... M0000000000000000000000<M0000000000000014ffd8ffd807d0   M   0   0   0   0   0   0   0   848975
# Time 1713793847.2663004  Reply Start driving848976
# Time 1713793847.2712944  Reply Finished driving 848979 S1done S2done S3done S4done S6done
# 1713793849.2483938 protocol iteration 415 [0, 0, 0, 0, 0, 20]
# Time 1713793849.2624102  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   850973
# Time 1713793849.2634118  Reply Start driving850975
# 1713793851.2489257 protocol iteration 416 [0, 0, 0, 0, 0, 20]
# Time 1713793851.2641969  Reply Finished driving 852976 S1done S2done S3done S4done S6done
# Time 1713793851.272202  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   852982
# Time 1713793851.273198  Reply Start driving852984
# 1713793853.249554 protocol iteration 417 [0, 0, 0, 0, 20, -40]
# Time 1713793853.272814  Reply Finished driving 854985 S1done S2done S3done S4done S5done S6done
# Time 1713793853.282808  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   854992
# Time 1713793853.283794  Reply Start driving854994
# 1713793855.2497554 protocol iteration 418 [0, 0, 0, 0, 0, 20]
# Time 1713793855.2839842  Reply Finished driving 856995 S1done S2done S3done S4done S5done S6done
# Time 1713793855.291574  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   857003
# Time 1713793855.2945883  Reply Start driving857005
# 1713793857.2500794 protocol iteration 419 [0, 0, 0, 0, 0, 20]
# Time 1713793857.2951005  Reply Finished driving 859006 S1done S2done S3done S4done S5done S6done
# Time 1713793857.3031018  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   859014
# Time 1713793857.3061037  Reply Start driving859016
# 1713793859.2501125 protocol iteration 420 [0, 0, 0, 0, 20, -40]
# Time 1713793859.3061178  Reply Finished driving 861017 S1done S2done S3done S4done S5done S6done
# Time 1713793859.3141193  Reply This just in ... M00000000000000000014ffd807d0   M   0   0   0   0   20   -40   2000   861024
# Time 1713793859.3171222  Reply Start driving861026
# 1713793861.2510805 protocol iteration 421 [0, 0, 0, 0, 0, 20]
# Time 1713793861.316847  Reply Finished driving 863027 S1done S2done S3done S4done S5done S6done
# Time 1713793861.324846  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   863034
# Time 1713793861.3268452  Reply Start driving863036
# 1713793863.2519305 protocol iteration 422 [0, 0, 0, 0, 0, 20]
# Time 1713793863.3276744  Reply Finished driving 865037 S1done S2done S3done S4done S5done S6done
# Time 1713793863.3356767  Reply This just in ... M00000000000000000000001407d0   M   0   0   0   0   0   20   2000   865044
# Time 1713793863.3376768  Reply Start driving865046
# 1713793865.2528965 protocol iteration 423 [0, 0, 0, 20, -40, -40]
# Time 1713793865.3389015  Reply Finished driving 867047 S1done S2done S3done S4done S5done S6done
# Time 1713793865.346242  Reply This just in ... M0000000000000014ffd8ffd807d0   M   0   0   0   20   -40   -40   2000   867054
# Time 1713793865.3478117  Reply Start driving867056
