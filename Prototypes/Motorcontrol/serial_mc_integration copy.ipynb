# %%
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QVBoxLayout, QLabel, QCheckBox, QSpinBox
import serial
import time
import base64
#import keyboard

# %% [markdown]
# # UI

# %%
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QVBoxLayout, QLabel, QCheckBox, QSpinBox

class MotorControlerUI(QWidget):
    def __init__(self):
        super().__init__()
        self.initUI()
        self.ui_events = []

    def initUI(self):
        # Create buttons s1 to s6
        self.buttons = []
        button_pos =[(50,50),(50,100),(50,150),(50,200),(50,250),(50,300)]
        for i in range(1, 7):
            button = QPushButton(f'S{i}', self)
            button.clicked.connect(self.buttonClicked)
            button.move(button_pos[i-1][0],button_pos[i-1][1])
            self.buttons.append(button)

        #labels for s1->s6
        self.labels = []
        label_pos = [(bp[0]*4,bp[1]) for bp in button_pos]
        for i in range(1,7):
            label = QLabel(f"Label{i}",self)
            label.move(label_pos[i-1][0],label_pos[i-1][1])
            label.setText("0")
            label.setFixedWidth(50)
            self.labels.append(label)

        #spinBox for s1->s6
        self.spinboxs = []
        spinbox_pos = [(bp[0]*6,bp[1]) for bp in button_pos]
        for i in range(1,7):
            spinbox = QSpinBox(self)
            spinbox.setObjectName(f"s{i}")
            spinbox.setRange(-500,500)
            spinbox.setFixedWidth(150)
            spinbox.move(spinbox_pos[i-1][0],spinbox_pos[i-1][1])
            self.spinboxs.append(spinbox)
        
        #buton pairs (1-6,2-5,3-4)
        self.pair_buttons = []
        pair_button_pos = [(bp[0]*10,bp[1]) for bp in button_pos[:3]]
        pair_button_names = ["S1-6","S2-5","S3-4"]
        for i in range(3):
            button = QPushButton(pair_button_names[i], self)
            button.clicked.connect(self.pairButtonCliked)
            button.move(pair_button_pos[i][0],pair_button_pos[i][1])
            self.pair_buttons.append(button)
        
        #spinbox pairs (1-6,2-5,3-4)
        self.pair_spinboxs = []
        pair_spinbox_pos = [(bp[0]*12,bp[1]) for bp in button_pos[:3]]
        for i in range(3):
            spinbox = QSpinBox(self)
            spinbox.setObjectName(pair_button_names[i])
            spinbox.setRange(-500,500)
            spinbox.setFixedWidth(150)
            spinbox.move(pair_spinbox_pos[i][0],pair_spinbox_pos[i][1])
            self.pair_spinboxs.append(spinbox)


        #time input
        self.timeInput = QSpinBox(self)
        self.timeInput.setObjectName("timeInput")
        self.timeInput.setRange(800,100000)
        self.timeInput.setFixedWidth(150)
        self.timeInput.move(spinbox_pos[5][0],spinbox_pos[5][1]+100)

        #time input explanation
        self.labelTime = QLabel("Time pr. instruction",self)
        self.labelTime.move(label_pos[5][0]-50,label_pos[5][1]+100)

        #spinbox header
        self.labelInfo = QLabel("- = ClockWise",self)
        self.labelInfo.move(spinbox_pos[0][0],spinbox_pos[0][1]-25)

        #label header
        self.labelPos = QLabel("MotorPosition",self)
        self.labelPos.move(label_pos[0][0],label_pos[0][1]-25)

        #all motors input
        self.allButton = QPushButton(f'S1-6', self)
        self.allButton.clicked.connect(self.allButtonClicked)
        self.allButton.move(button_pos[5][0],button_pos[5][1]+100)

        #start protocol
        self.startProt = QPushButton("StartProtocol",self)
        self.startProt.clicked.connect(self.startProtocol)
        self.startProt.move(button_pos[5][0],button_pos[5][1]+200)

        self.setWindowTitle('Motor controler')
        self.setGeometry(300, 300, 800, 600)  # Set window position and size

    #UPDATES
    def updateLabels(self,mc): #pass array of motor change values to update labels
        for i in range(6):
            label = self.labels[i]
            cur_val = int(label.text())
            label.setText(str(cur_val+mc[i]))


    #UI EVENTS
    def buttonClicked(self): #button click (adds spinbox to label)
        sender = self.sender()
        index = int(sender.text()[1]) - 1
        spinbox = self.spinboxs[index]
        change_val = spinbox.value()
        label = self.labels[index]
        cur_val = int(label.text())
        new_val = change_val+cur_val
        label.setText(str(new_val))
        #get time
        time_val = self.timeInput.value()

        self.ui_events.append(["1B",index,change_val,time_val,f'Button {sender.text()} clicked. With Value {change_val}: {cur_val} -> {new_val}'])

    def allButtonClicked(self): #button for running all motors at the same time
        mc = [0,0,0,0,0,0]
        time_val = self.timeInput.value()
        
        for i in range(6): #get value from each of the spin boxes
            mc[i] = self.spinboxs[i].value()
            label = self.labels[i]
            label.setText(str(mc[i]+int(label.text())))

        self.ui_events.append(["AB",mc,time_val,f"Allbutton {self.sender().text()} clicked. With Values {mc}'"])

    def startProtocol(self):
        self.ui_events.append(["SP",f"StartProtocol {self.sender().text()} clicked."])

    def pairButtonCliked(self):
        sender = self.sender().text()
        time_val = self.timeInput.value()
        mc = [0,0,0,0,0,0]
        match sender: #could be made cleaner with a map or somting
            case "S1-6":
                val = self.pair_spinboxs[0].value()
                mc[0] = val
                mc[5] = val
            case "S2-5": #s2-5
                val = self.pair_spinboxs[1].value()
                mc[1] = val
                mc[4] = val   
            case "S3-4": #s3-4
                val = self.pair_spinboxs[2].value()
                mc[2] = val
                mc[3] = val

        self.updateLabels(mc)
        self.ui_events.append(["PB",mc,time_val,f"Pairbutton {sender} clicked. With Values {mc}'"])


#Handle events
def handleUIEvents(ui_widget,mc,timeval,protocol):
    while ui_widget.ui_events:
        event = ui_widget.ui_events.pop(0)
        print(event)

        match event[0]: #TODO: make a standard structure for events (but good enough for now)
            case "1B": #1:idx 2:changeVal 3: time val
                mc[event[1]] = event[2]
                timeval[0] = event[3]
            case "AB": #1: mcVal #2:time val
                #print(mc)
                for i in range(6):
                    mc[i] = event[1][i]
                #mc = event[1]
                #print(mc)
                timeval[0] = event[2]
            case "SP":
                protocol[0] = True
            case "PB":
                for i in range(6):
                    mc[i] = event[1][i]
                timeval[0] = event[2]
            case _:
                print(f"Unknown first event {event[0]}")

    app.processEvents()

# %% [markdown]
# # Serial protocol

# %%
#initial protocol from https://forum.arduino.cc/t/serial-input-basics-updated/382007/2
# and https://forum.arduino.cc/t/pc-arduino-comms-using-python-updated/574496 

startMarker = '<'
endMarker = '>'
dataStarted = False
dataBuf = ""
messageComplete = False

#========================
#========================
    # the functions

def setupSerial(baudRate, serialPortName):
    global  serialPort
    serialPort = serial.Serial(port= serialPortName, baudrate = baudRate, timeout=0, rtscts=True)
    print("Serial port " + serialPortName + " opened  Baudrate " + str(baudRate))
    waitForArduino()

#========================

def sendToArduino(stringToSend):
    # this adds the start- and end-markers before sending
    global startMarker, endMarker, serialPort
    
    stringWithMarkers = (startMarker)
    stringWithMarkers += stringToSend
    stringWithMarkers += (endMarker)

    serialPort.write(stringWithMarkers.encode('utf-8')) # encode needed for Python3


#==================

def recvLikeArduino():

    global startMarker, endMarker, serialPort, dataStarted, dataBuf, messageComplete

    if serialPort.inWaiting() > 0 and messageComplete == False:
        x = serialPort.read().decode("utf-8") # decode needed for Python3
        
        if dataStarted == True:
            if x != endMarker:
                dataBuf = dataBuf + x
            else:
                dataStarted = False
                messageComplete = True
        elif x == startMarker:
            dataBuf = ''
            dataStarted = True
    
    if (messageComplete == True):
        messageComplete = False
        return dataBuf
    else:
        return "XXX" 

#==================

def waitForArduino():
    # wait until the Arduino sends 'Arduino is ready' - allows time for Arduino reset
    # it also ensures that any bytes left over from a previous message are discarded
    print("Waiting for Arduino to reset")
     
    msg = ""
    while msg.find("Arduino is ready") == -1:
        msg = recvLikeArduino()
        if not (msg == 'XXX'): 
            print(msg)

# %% [markdown]
# # Messaging protocol

# %%
#<msg> (where "<" starts a msg and ">" ends 1)

#start <
#first char is used for identifying the type of msg. M=reltive move, R=reset
#next 4x6 chars are used for the amount you want the steppers to move 2signed bytes pr stepper
#4bytes for the amount of time to complete the moves
#end >

def num_to_hex(num):
  if num > 32767  or num < -32768:
    raise TypeError(f"Number {num} is does not fit withing 4 char hex")
  
  # Convert negative numbers to two's complement representation
  if num < 0:
    num = (1 << 16) + num
  
  hex_value = hex(num & 0xFFFF)[2:].zfill(4)  # Convert to hexadecimal and pad with zeros
  return hex_value

def hex_to_num(hex_string):
  if not isinstance(hex_string, str) or len(hex_string) != 4:
    TypeError(f"Input must be a string of 4 characters")
  
  num = int(hex_string, 16)
  # Handle negative numbers
  if num >= 0x8000:
      num -= 1 << 16
  return num

#convert array of relative motor steps to a string that can be sent to the arduino
#current types: (R) and M
def encode_motor_msg(motor_steps,timer,msg_type):
  if not(msg_type in ["M","R"]):
    TypeError(f"Unknown msg_type: {msg_type}")
  
  if len(motor_steps) != 6:
    TypeError(f"Expected 6 motor values got: {motor_steps}")
  
  motor_hex = ""
  for ms in motor_steps:
    motor_hex += num_to_hex(ms)
  
  time_hex = num_to_hex(timer)

  return msg_type + motor_hex + time_hex

#decode motor message

def decode_motor_msg(motor_msg):
  msg_type = motor_msg[0]
  motor_hex = motor_msg[1:25]
  timer_hex = motor_msg[25:29]

  motor_vals = []
  for i in range(0,24,4):
    motor_vals.append(hex_to_num(motor_hex[i:i+4])) 
  

  return msg_type, motor_vals, hex_to_num(timer_hex)


# Examples:
numbers = [-1234, 32767, 9012, 3456, -7890, 1234]

for i in numbers:
  hexval = num_to_hex(i)
  print(hexval,hex_to_num(hexval))

fullEncode = encode_motor_msg(numbers,1000,"M")
print(fullEncode,decode_motor_msg(fullEncode))
# Out:
# fb2e -1234
# 7fff 32767
# 2334 9012
# 0d80 3456
# e12e -7890
# 04d2 1234
# Mfb2e7fff23340d80e12e04d203e8 ('M', [-1234, 32767, 9012, 3456, -7890, 1234], 1000)

# %% [markdown]
# # Protocols

# %%
import itertools

# Define the ranges for each number
ranges = [
    range(-40, 41,40),  # Range for a
    range(-40, 41,40),  # Range for b
    range(-40, 41,40),  # Range for c
    range(-40, 41,40),  # Range for d
    range(-40, 41,40),  # Range for e
    range(-40, 41,40),  # Range for f
]

# Generate all combinations
combinations = list(itertools.product(*ranges))
#print(len(combinations))
comb_list = list(map(list,combinations))
#print(combinations)
#print(len(set(combinations)))
#print(set(combinations))

#print(comb_list)

# %%
#function for repeatin protocol (does not create copies, uses same ref)
def repeatProtocol(prot,amount):
  return prot*amount

a = [[1],[2],[3]]
repeatProtocol(a,4)

def calcRelativePos(cur,moves):
  rel_moves = []
  cur_poses = []
  for m in moves:
    rel = [0,0,0,0,0,0]
    for i in range(6):
      rel[i] = m[i] - cur[i]
    cur = m
    rel_moves.append(rel)
    cur_poses.append(cur)
  return rel_moves, cur_poses

# %%
prot_60data, _ = calcRelativePos([0,0,0,0,0,0],comb_list)
prot_60data_50 = prot_60data[:50]

print(len(prot_60data),len(prot_60data_50))
# Out:
# 729 50

# %%
 #up -> reset
prot_ur = [[100,100,100,100,100,100],[-100,-100,-100,-100,-100,-100]]
#up->reset->donw->reset
prot_full = [[100,100,100,100,100,100],[-100,-100,-100,-100,-100,-100],[-100,-100,-100,-100,-100,-100],[100,100,100,100,100,100]] 
prot_34 = [[0,0,100,100,0,0],[0,0,-100,-100,0,0],[0,0,-100,-100,0,0],[0,0,100,100,0,0]]

prot_dr = [[-100,-100,-100,-100,-100,-100],[100,100,100,100,100,100]]

prot_34_down = [[0,0,100,100,0,0],[0,0,-100,-100,0,0]]


prot_full_10 = repeatProtocol(prot_full,10)
prot_updwon_10 = repeatProtocol(prot_ur,50)
prot_34_10 = repeatProtocol(prot_34,10)
prot_dr_10 = repeatProtocol(prot_dr,50)

prot_34_down_50 = repeatProtocol(prot_34_down,50)

# %%
prot_60data[411]
# Out:
# [0, 0, 0, 0, 40, -80]

# %%
#0/0

# %% [markdown]
# # Main loop

# %%
#setupSerial(115200, "COM3")
setupSerial(1000_000, "COM4")
count = 0
prevTime = time.time()

motor_vals = [0,0,0,0,0,0] #current motor positions
motor_change = [0,0,0,0,0,0] #Changes for next motor iteration
time_val = [1] # time pointer

def calcMotorvals(cur,new):
    return [a+b for a,b in zip(cur,new)]

protocol_running = [False] #protocol pointer
protocol_ctr = 0 #counter for where in protocl we are
protocol_delay = 0.2 #in seconds
protocol_mc = prot_60data#prot_updwon_10 #prot_dr_10
protocol_prevtime = 0
protocol_maxctr = len(protocol_mc)


if __name__ == '__main__':
    app = QApplication(sys.argv)
    mcUI = MotorControlerUI()
    mcUI.show()

    # Your main loop
    while True:
        # Receive and handle messages from the microcontroller 
        arduinoReply = recvLikeArduino() # check for a reply
        if not (arduinoReply == 'XXX'):
            print ("Time %s  Reply %s" %(time.time(), arduinoReply))
    
        # Handle UI events
        handleUIEvents(mcUI,motor_change,time_val,protocol_running)

        # Respond to the microcontroller
        if motor_change != [0,0,0,0,0,0] and not protocol_running[0]: #control with UI
            motor_vals = calcMotorvals(motor_vals,motor_change) #update total motor values
            enc_msg = encode_motor_msg(motor_change,time_val[0],"M")
            sendToArduino(enc_msg)
            print("motorchange:",motor_change,"msg:", enc_msg, "time:", time_val)

            motor_change = [0,0,0,0,0,0]

        elif protocol_running[0]:
            if time.time() - protocol_prevtime > protocol_delay: #send next move after certain time
                protocol_prevtime = time.time()
                motor_vals = calcMotorvals(motor_vals,protocol_mc[protocol_ctr])

                mcUI.updateLabels(protocol_mc[protocol_ctr]) #update labels in UI

                enc_msg = encode_motor_msg(protocol_mc[protocol_ctr],int(protocol_delay*1000),"M")
                print(f"pyt: encoded msg: {enc_msg}")
                sendToArduino(enc_msg)

                print(protocol_prevtime,f"protocol iteration {protocol_ctr}",protocol_mc[protocol_ctr])
                protocol_ctr += 1
            
            if protocol_ctr == protocol_maxctr: #reset after protocol is finished
                protocol_running[0] = False
                protocol_ctr = 0
                print("protocol finished")


        #elif time.time() - prevTime > 1.0: # send a message at intervals
        #    sendToArduino("this is a test " + str(count))
        #    prevTime = time.time()
        #    count += 1
    
    sys.exit(app.exec_()) #independently run the program
# Out:
# Serial port COM4 opened  Baudrate 1000000
# Waiting for Arduino to reset
# Arduino is ready
# ['SP', 'StartProtocol StartProtocol clicked.']
# 1713798928.9635093 protocol iteration 0 [-40, -40, -40, -40, -40, -40]
# Time 1713798928.9655087  Reply first: M
# Time 1713798928.9745111  Reply This just in ... Mffd8ffd8ffd8ffd8ffd8ffd800c8   M   -40   -40   -40   -40   -40   -40   200   8626
# Time 1713798928.9755125  Reply Start driving8627
# 1713798929.163523 protocol iteration 1 [0, 0, 0, 0, 0, 40]
# Time 1713798929.171526  Reply Finished driving 8827
# Time 1713798929.171526  Reply first: M
# Time 1713798929.1755254  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   8829
# Time 1713798929.1765258  Reply Start driving8830
# 1713798929.3641467 protocol iteration 2 [0, 0, 0, 0, 0, 40]
# Time 1713798929.3751323  Reply Finished driving 9030 S1done S2done S3done S4done S5done
# Time 1713798929.3771353  Reply first: M
# Time 1713798929.385135  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   9032
# Time 1713798929.385135  Reply Start driving9033
# 1713798929.564505 protocol iteration 3 [0, 0, 0, 0, 40, -80]
# Time 1713798929.589505  Reply Finished driving 9233 S1done S2done S3done S4done S5done S6done
# Time 1713798929.5935059  Reply first: M
# Time 1713798929.613507  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   9235
# Time 1713798929.616508  Reply Start driving9236
# 1713798929.7645185 protocol iteration 4 [0, 0, 0, 0, 0, 40]
# Time 1713798929.7795203  Reply Finished driving 9436 S1done S2done S3done S4done
# Time 1713798929.7795203  Reply first: M
# Time 1713798929.7845225  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   9438
# Time 1713798929.7865217  Reply Start driving9439
# 1713798929.9655008 protocol iteration 5 [0, 0, 0, 0, 0, 40]
# Time 1713798929.9835045  Reply Finished driving 9639 S1done S2done S3done S4done S5done
# Time 1713798929.9845042  Reply first: M
# Time 1713798929.9895065  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   9641
# Time 1713798929.9905076  Reply Start driving9643
# 1713798930.1655178 protocol iteration 6 [0, 0, 0, 0, 40, -80]
# Time 1713798930.1895213  Reply Finished driving 9843 S1done S2done S3done S4done S5done
# Time 1713798930.191521  Reply first: M
# Time 1713798930.2015235  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   9845
# Time 1713798930.203523  Reply Start driving9846
# 1713798930.3655355 protocol iteration 7 [0, 0, 0, 0, 0, 40]
# Time 1713798930.390542  Reply Finished driving 10046 S1done S2done S3done S4done
# Time 1713798930.3925405  Reply first: M
# Time 1713798930.397538  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   10048
# Time 1713798930.3995397  Reply Start driving10049
# 1713798930.56574 protocol iteration 8 [0, 0, 0, 0, 0, 40]
# Time 1713798930.5937414  Reply Finished driving 10249 S1done S2done S3done S4done S5done
# Time 1713798930.5937414  Reply first: M
# Time 1713798930.6007588  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   10251
# Time 1713798930.601746  Reply Start driving10252
# 1713798930.7657773 protocol iteration 9 [0, 0, 0, 40, -80, -80]
# Time 1713798930.7947786  Reply Finished driving 10452 S1done S2done S3done S4done S5done
# Time 1713798930.7947786  Reply first: M
# Time 1713798930.7997801  Reply This just in ... M0000000000000028ffb0ffb000c8   M   0   0   0   40   -80   -80   200   10455
# Time 1713798930.800775  Reply Start driving10456
# 1713798930.9661586 protocol iteration 10 [0, 0, 0, 0, 0, 40]
# Time 1713798930.998728  Reply Finished driving 10656 S1done S2done S3done
# Time 1713798930.9997294  Reply first: M
# Time 1713798931.0047305  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   10658
# Time 1713798931.0057297  Reply Start driving10659
# 1713798931.1667678 protocol iteration 11 [0, 0, 0, 0, 0, 40]
# Time 1713798931.2017467  Reply Finished driving 10859 S1done S2done S3done S4done
# Time 1713798931.2027488  Reply first: M
# Time 1713798931.2077646  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   10861
# Time 1713798931.2087512  Reply Start driving10862
# 1713798931.3677602 protocol iteration 12 [0, 0, 0, 0, 40, -80]
# Time 1713798931.4047663  Reply Finished driving 11062 S1done S2done S3done S4done S5done
# Time 1713798931.4057646  Reply first: M
# Time 1713798931.4117794  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   11064
# Time 1713798931.4127824  Reply Start driving11065
# 1713798931.5685253 protocol iteration 13 [0, 0, 0, 0, 0, 40]
# Time 1713798931.6055284  Reply Finished driving 11265 S1done S2done S3done S4done
# Time 1713798931.6065297  Reply first: M
# Time 1713798931.610527  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   11267
# Time 1713798931.611527  Reply Start driving11268
# 1713798931.7685404 protocol iteration 14 [0, 0, 0, 0, 0, 40]
# Time 1713798931.8115587  Reply Finished driving 11468 S1done S2done S3done S4done S5done
# Time 1713798931.8125591  Reply first: M
# Time 1713798931.8165624  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   11470
# Time 1713798931.8175619  Reply Start driving11471
# 1713798931.968575 protocol iteration 15 [0, 0, 0, 0, 40, -80]
# Time 1713798932.0137682  Reply Finished driving 11671 S1done S2done S3done S4done S5done
# Time 1713798932.0147755  Reply first: M
# Time 1713798932.018778  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   11673
# Time 1713798932.019773  Reply Start driving11674
# 1713798932.1687832 protocol iteration 16 [0, 0, 0, 0, 0, 40]
# Time 1713798932.2157705  Reply Finished driving 11874 S1done S2done S3done S4done
# Time 1713798932.2177713  Reply first: M
# Time 1713798932.2247748  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   11876
# Time 1713798932.2257712  Reply Start driving11877
# 1713798932.369783 protocol iteration 17 [0, 0, 0, 0, 0, 40]
# Time 1713798932.417804  Reply Finished driving 12077 S1done S2done S3done S4done S5done
# Time 1713798932.417804  Reply first: M
# Time 1713798932.4217896  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   12079
# Time 1713798932.4228096  Reply Start driving12080
# 1713798932.5698981 protocol iteration 18 [0, 0, 0, 40, -80, -80]
# Time 1713798932.6218865  Reply Finished driving 12280 S1done S2done S3done S4done S5done
# Time 1713798932.6229017  Reply first: M
# Time 1713798932.6269045  Reply This just in ... M0000000000000028ffb0ffb000c8   M   0   0   0   40   -80   -80   200   12282
# Time 1713798932.6279085  Reply Start driving12283
# 1713798932.769899 protocol iteration 19 [0, 0, 0, 0, 0, 40]
# Time 1713798932.8239186  Reply Finished driving 12483 S1done S2done S3done
# Time 1713798932.8249183  Reply first: M
# Time 1713798932.8289185  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   12485
# Time 1713798932.8299217  Reply Start driving12486
# 1713798932.9699142 protocol iteration 20 [0, 0, 0, 0, 0, 40]
# Time 1713798933.0300267  Reply Finished driving 12686 S1done S2done S3done S4done
# Time 1713798933.0310261  Reply first: M
# Time 1713798933.0370264  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   12688
# Time 1713798933.0390306  Reply Start driving12689
# 1713798933.1700366 protocol iteration 21 [0, 0, 0, 0, 40, -80]
# Time 1713798933.2290587  Reply Finished driving 12889 S1done S2done S3done S4done S5done
# Time 1713798933.230066  Reply first: M
# Time 1713798933.2370427  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   12891
# Time 1713798933.2390428  Reply Start driving12892
# 1713798933.3700533 protocol iteration 22 [0, 0, 0, 0, 0, 40]
# Time 1713798933.4320586  Reply Finished driving 13092 S1done S2done S3done S4done
# Time 1713798933.4330578  Reply first: M
# Time 1713798933.437057  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   13094
# Time 1713798933.4380605  Reply Start driving13095
# 1713798933.5702884 protocol iteration 23 [0, 0, 0, 0, 0, 40]
# Time 1713798933.6373158  Reply Finished driving 13295 S1done S2done S3done S4done S5done
# Time 1713798933.6373158  Reply first: M
# Time 1713798933.6423142  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   13297
# Time 1713798933.643317  Reply Start driving13298
# 1713798933.7703032 protocol iteration 24 [0, 0, 0, 0, 40, -80]
# Time 1713798933.8393264  Reply Finished driving 13498 S1done S2done S3done S4done S5done
# Time 1713798933.8403237  Reply first: M
# Time 1713798933.845311  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   13500
# Time 1713798933.8463094  Reply Start driving13501
# 1713798933.970322 protocol iteration 25 [0, 0, 0, 0, 0, 40]
# Time 1713798934.0413501  Reply Finished driving 13701 S1done S2done S3done S4done
# Time 1713798934.0423431  Reply first: M
# Time 1713798934.0473437  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   13703
# Time 1713798934.0493302  Reply Start driving13704
# 1713798934.170334 protocol iteration 26 [0, 0, 0, 0, 0, 40]
# Time 1713798934.243339  Reply Finished driving 13904 S1done S2done S3done S4done S5done
# Time 1713798934.2443392  Reply first: M
# Time 1713798934.2483397  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   13906
# Time 1713798934.2493393  Reply Start driving13907
# 1713798934.3703496 protocol iteration 27 [0, 0, 40, -80, -80, -80]
# Time 1713798934.447356  Reply Finished driving 14107 S1done S2done S3done S4done S5done
# Time 1713798934.447356  Reply first: M
# Time 1713798934.4523566  Reply This just in ... M000000000028ffb0ffb0ffb000c8   M   0   0   40   -80   -80   -80   200   14109
# Time 1713798934.453356  Reply Start driving14110
# 1713798934.5704522 protocol iteration 28 [0, 0, 0, 0, 0, 40]
# Time 1713798934.648954  Reply Finished driving 14310 S1done S2done
# Time 1713798934.6499522  Reply first: M
# Time 1713798934.653949  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   14312
# Time 1713798934.6549363  Reply Start driving14313
# 1713798934.7704742 protocol iteration 29 [0, 0, 0, 0, 0, 40]
# Time 1713798934.8527267  Reply Finished driving 14513 S1done S2done S3done
# Time 1713798934.8527267  Reply first: M
# Time 1713798934.8597283  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   14515
# Time 1713798934.8608348  Reply Start driving14516
# 1713798934.971023 protocol iteration 30 [0, 0, 0, 0, 40, -80]
# Time 1713798935.0554447  Reply Finished driving 14716 S1done S2done S3done S4done S5done
# Time 1713798935.0564587  Reply first: M
# Time 1713798935.060467  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   14718
# Time 1713798935.060467  Reply Start driving14720
# 1713798935.1714551 protocol iteration 31 [0, 0, 0, 0, 0, 40]
# Time 1713798935.2584732  Reply Finished driving 14920 S1done S2done S3done S4done
# Time 1713798935.259475  Reply first: M
# Time 1713798935.2624714  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   14922
# Time 1713798935.263477  Reply Start driving14923
# 1713798935.372265 protocol iteration 32 [0, 0, 0, 0, 0, 40]
# Time 1713798935.4632938  Reply Finished driving 15123 S1done S2done S3done S4done S5done
# Time 1713798935.4642892  Reply first: M
# Time 1713798935.4682894  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   15125
# Time 1713798935.4692883  Reply Start driving15126
# 1713798935.5728343 protocol iteration 33 [0, 0, 0, 0, 40, -80]
# Time 1713798935.66736  Reply Finished driving 15326 S1done S2done S3done S4done S5done
# Time 1713798935.6683602  Reply first: M
# Time 1713798935.678446  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   15328
# Time 1713798935.6814442  Reply Start driving15329
# 1713798935.773015 protocol iteration 34 [0, 0, 0, 0, 0, 40]
# Time 1713798935.867899  Reply Finished driving 15529 S1done S2done S3done S4done
# Time 1713798935.868885  Reply first: M
# Time 1713798935.8758986  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   15532
# Time 1713798935.8769011  Reply Start driving15533
# 1713798935.9732065 protocol iteration 35 [0, 0, 0, 0, 0, 40]
# Time 1713798936.0708325  Reply Finished driving 15733 S1done S2done S3done S4done S5done
# Time 1713798936.0708325  Reply first: M
# Time 1713798936.0748467  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   15735
# Time 1713798936.077309  Reply Start driving15736
# 1713798936.1741939 protocol iteration 36 [0, 0, 0, 40, -80, -80]
# Time 1713798936.2734106  Reply Finished driving 15936 S1done S2done S3done S4done S5done
# Time 1713798936.274406  Reply first: M
# Time 1713798936.2784076  Reply This just in ... M0000000000000028ffb0ffb000c8   M   0   0   0   40   -80   -80   200   15938
# Time 1713798936.2794075  Reply Start driving15939
# 1713798936.374893 protocol iteration 37 [0, 0, 0, 0, 0, 40]
# Time 1713798936.4769022  Reply Finished driving 16139 S1done S2done S3done
# Time 1713798936.477918  Reply first: M
# Time 1713798936.4819243  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   16141
# Time 1713798936.4829197  Reply Start driving16142
# 1713798936.5756893 protocol iteration 38 [0, 0, 0, 0, 0, 40]
# Time 1713798936.6802876  Reply Finished driving 16342 S1done S2done S3done S4done
# Time 1713798936.6812828  Reply first: M
# Time 1713798936.6872642  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   16344
# Time 1713798936.6882672  Reply Start driving16345
# 1713798936.7765722 protocol iteration 39 [0, 0, 0, 0, 40, -80]
# Time 1713798936.8803444  Reply Finished driving 16545 S1done S2done S3done S4done S5done
# Time 1713798936.8813515  Reply first: M
# Time 1713798936.8853302  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   16547
# Time 1713798936.8863504  Reply Start driving16548
# 1713798936.9765773 protocol iteration 40 [0, 0, 0, 0, 0, 40]
# Time 1713798937.0845912  Reply Finished driving 16748 S1done S2done S3done S4done
# Time 1713798937.0845912  Reply first: M
# Time 1713798937.0885742  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   16750
# Time 1713798937.08959  Reply Start driving16751
# 1713798937.1768792 protocol iteration 41 [0, 0, 0, 0, 0, 40]
# Time 1713798937.288417  Reply Finished driving 16951 S1done S2done S3done S4done S5done
# Time 1713798937.2894337  Reply first: M
# Time 1713798937.2944336  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   16953
# Time 1713798937.2954335  Reply Start driving16954
# 1713798937.3771265 protocol iteration 42 [0, 0, 0, 0, 40, -80]
# Time 1713798937.489972  Reply Finished driving 17154 S1done S2done S3done S4done S5done
# Time 1713798937.4909554  Reply first: M
# Time 1713798937.49497  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   17156
# Time 1713798937.4959667  Reply Start driving17157
# 1713798937.5779624 protocol iteration 43 [0, 0, 0, 0, 0, 40]
# Time 1713798937.6931098  Reply Finished driving 17357 S1done S2done S3done S4done
# Time 1713798937.6941104  Reply first: M
# Time 1713798937.699108  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   17359
# Time 1713798937.7001045  Reply Start driving17360
# 1713798937.7781153 protocol iteration 44 [0, 0, 0, 0, 0, 40]
# Time 1713798937.8956106  Reply Finished driving 17560 S1done S2done S3done S4done S5done
# Time 1713798937.896609  Reply first: M
# Time 1713798937.9006293  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   17562
# Time 1713798937.9016252  Reply Start driving17563
# 1713798937.9786155 protocol iteration 45 [0, 0, 0, 40, -80, -80]
# Time 1713798938.097351  Reply Finished driving 17763 S1done S2done S3done S4done S5done
# Time 1713798938.0983508  Reply first: M
# Time 1713798938.1023517  Reply This just in ... M0000000000000028ffb0ffb000c8   M   0   0   0   40   -80   -80   200   17765
# Time 1713798938.1033516  Reply Start driving17766
# 1713798938.1788828 protocol iteration 46 [0, 0, 0, 0, 0, 40]
# Time 1713798938.30158  Reply Finished driving 17966 S1done S2done S3done
# Time 1713798938.30158  Reply first: M
# Time 1713798938.3075767  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   17968
# Time 1713798938.3085797  Reply Start driving17969
# 1713798938.379584 protocol iteration 47 [0, 0, 0, 0, 0, 40]
# Time 1713798938.5038693  Reply Finished driving 18169 S1done S2done S3done S4done
# Time 1713798938.5038693  Reply first: M
# Time 1713798938.5078845  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   18171
# Time 1713798938.5108838  Reply Start driving18172
# 1713798938.5803976 protocol iteration 48 [0, 0, 0, 0, 40, -80]
# Time 1713798938.7081926  Reply Finished driving 18372 S1done S2done S3done S4done S5done
# Time 1713798938.7092128  Reply first: M
# Time 1713798938.7132096  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   18374
# Time 1713798938.716197  Reply Start driving18375
# 1713798938.7812147 protocol iteration 49 [0, 0, 0, 0, 0, 40]
# Time 1713798938.9087355  Reply Finished driving 18575 S1done S2done S3done S4done
# Time 1713798938.9097328  Reply first: M
# Time 1713798938.9137301  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   18577
# Time 1713798938.9137301  Reply Start driving18578
# 1713798938.981743 protocol iteration 50 [0, 0, 0, 0, 0, 40]
# Time 1713798939.1124394  Reply Finished driving 18778 S1done S2done S3done S4done S5done
# Time 1713798939.1124394  Reply first: M
# Time 1713798939.1164458  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   18780
# Time 1713798939.1174445  Reply Start driving18781
# 1713798939.181886 protocol iteration 51 [0, 0, 0, 0, 40, -80]
# Time 1713798939.315427  Reply Finished driving 18981 S1done S2done S3done S4done S5done
# Time 1713798939.3164265  Reply first: M
# Time 1713798939.3234088  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   18983
# Time 1713798939.324406  Reply Start driving18984
# 1713798939.3824353 protocol iteration 52 [0, 0, 0, 0, 0, 40]
# Time 1713798939.5179029  Reply Finished driving 19184 S1done S2done S3done S4done
# Time 1713798939.520882  Reply first: M
# Time 1713798939.5258803  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   19186
# Time 1713798939.5268812  Reply Start driving19187
# 1713798939.5829055 protocol iteration 53 [0, 0, 0, 0, 0, 40]
# Time 1713798939.7202437  Reply Finished driving 19387 S1done S2done S3done S4done S5done
# Time 1713798939.7202437  Reply first: M
# Time 1713798939.726245  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   19389
# Time 1713798939.72825  Reply Start driving19390
# 1713798939.783254 protocol iteration 54 [0, 0, 40, -80, -80, -80]
# Time 1713798939.9231908  Reply Finished driving 19590 S1done S2done S3done S4done S5done
# Time 1713798939.9241934  Reply first: M
# Time 1713798939.9291909  Reply This just in ... M000000000028ffb0ffb0ffb000c8   M   0   0   40   -80   -80   -80   200   19592
# Time 1713798939.9311929  Reply Start driving19593
# 1713798939.9841979 protocol iteration 55 [0, 0, 0, 0, 0, 40]
# Time 1713798940.1262016  Reply Finished driving 19793 S1done S2done
# Time 1713798940.1262016  Reply first: M
# Time 1713798940.1302054  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   19795
# Time 1713798940.1312075  Reply Start driving19796
# 1713798940.1847994 protocol iteration 56 [0, 0, 0, 0, 0, 40]
# Time 1713798940.3294494  Reply Finished driving 19996 S1done S2done S3done
# Time 1713798940.3314264  Reply first: M
# Time 1713798940.3354433  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   19998
# Time 1713798940.336445  Reply Start driving19999
# 1713798940.3854516 protocol iteration 57 [0, 0, 0, 0, 40, -80]
# Time 1713798940.5330818  Reply Finished driving 20199 S1done S2done S3done S4done S5done
# Time 1713798940.5340824  Reply first: M
# Time 1713798940.5410683  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   20201
# Time 1713798940.543066  Reply Start driving20202
# 1713798940.586366 protocol iteration 58 [0, 0, 0, 0, 0, 40]
# Time 1713798940.735481  Reply Finished driving 20402 S1done S2done S3done S4done
# Time 1713798940.7374802  Reply first: M
# Time 1713798940.7429645  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   20404
# Time 1713798940.7439647  Reply Start driving20405
# 1713798940.7869692 protocol iteration 59 [0, 0, 0, 0, 0, 40]
# Time 1713798940.9397528  Reply Finished driving 20605 S1done S2done S3done S4done S5done
# Time 1713798940.9397528  Reply first: M
# Time 1713798940.9447625  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   20608
# Time 1713798940.9457617  Reply Start driving20609
# 1713798940.9877465 protocol iteration 60 [0, 0, 0, 0, 40, -80]
# Time 1713798941.142397  Reply Finished driving 20809 S1done S2done S3done S4done S5done
# Time 1713798941.1434147  Reply first: M
# Time 1713798941.1474204  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   20811
# Time 1713798941.1484215  Reply Start driving20812
# 1713798941.188405 protocol iteration 61 [0, 0, 0, 0, 0, 40]
# Time 1713798941.3466306  Reply Finished driving 21012 S1done S2done S3done S4done
# Time 1713798941.3476317  Reply first: M
# Time 1713798941.3536303  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   21014
# Time 1713798941.3546321  Reply Start driving21015
# 1713798941.388638 protocol iteration 62 [0, 0, 0, 0, 0, 40]
# Time 1713798941.54895  Reply Finished driving 21215 S1done S2done S3done S4done S5done
# Time 1713798941.5499496  Reply first: M
# Time 1713798941.557951  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   21217
# Time 1713798941.5599518  Reply Start driving21218
# 1713798941.5889544 protocol iteration 63 [0, 0, 0, 40, -80, -80]
# Time 1713798941.7499888  Reply Finished driving 21419 S1done S2done S3done S4done S5done
# Time 1713798941.7509823  Reply first: M
# Time 1713798941.7549715  Reply This just in ... M0000000000000028ffb0ffb000c8   M   0   0   0   40   -80   -80   200   21421
# Time 1713798941.7559886  Reply Start driving21422
# 1713798941.7898858 protocol iteration 64 [0, 0, 0, 0, 0, 40]
# Time 1713798941.9531226  Reply Finished driving 21622 S1done S2done S3done
# Time 1713798941.9541032  Reply first: M
# Time 1713798941.9591155  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   21624
# Time 1713798941.9601257  Reply Start driving21625
# 1713798941.9901035 protocol iteration 65 [0, 0, 0, 0, 0, 40]
# Time 1713798942.156093  Reply Finished driving 21825 S1done S2done S3done S4done
# Time 1713798942.157093  Reply first: M
# Time 1713798942.1610932  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   21827
# Time 1713798942.1620934  Reply Start driving21828
# 1713798942.1901128 protocol iteration 66 [0, 0, 0, 0, 40, -80]
# Time 1713798942.3603036  Reply Finished driving 22028 S1done S2done S3done S4done S5done
# Time 1713798942.3613122  Reply first: M
# Time 1713798942.3653162  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   22030
# Time 1713798942.3663163  Reply Start driving22031
# 1713798942.390305 protocol iteration 67 [0, 0, 0, 0, 0, 40]
# Time 1713798942.5609274  Reply Finished driving 22231 S1done S2done S3done S4done
# Time 1713798942.561936  Reply first: M
# Time 1713798942.568934  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   22233
# Time 1713798942.570934  Reply Start driving22234
# 1713798942.5909202 protocol iteration 68 [0, 0, 0, 0, 0, 40]
# Time 1713798942.76512  Reply Finished driving 22434 S1done S2done S3done S4done S5done
# Time 1713798942.76512  Reply first: M
# Time 1713798942.7731185  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   22436
# Time 1713798942.7741184  Reply Start driving22437
# 1713798942.7911048 protocol iteration 69 [0, 0, 0, 0, 40, -80]
# Time 1713798942.9690728  Reply Finished driving 22637 S1done S2done S3done S4done S5done
# Time 1713798942.9690728  Reply first: M
# Time 1713798942.9730716  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   22639
# Time 1713798942.97407  Reply Start driving22640
# 1713798942.9912593 protocol iteration 70 [0, 0, 0, 0, 0, 40]
# Time 1713798943.1700804  Reply Finished driving 22840 S1done S2done S3done S4done
# Time 1713798943.1700804  Reply first: M
# Time 1713798943.1740777  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   22842
# Time 1713798943.1750846  Reply Start driving22843
# 1713798943.192081 protocol iteration 71 [0, 0, 0, 0, 0, 40]
# Time 1713798943.3724303  Reply Finished driving 23043 S1done S2done S3done S4done S5done
# Time 1713798943.3734453  Reply first: M
# Time 1713798943.3774467  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   23045
# Time 1713798943.3784466  Reply Start driving23046
# 1713798943.392454 protocol iteration 72 [0, 0, 0, 40, -80, -80]
# Time 1713798943.5765755  Reply Finished driving 23246 S1done S2done S3done S4done S5done
# Time 1713798943.5765755  Reply first: M
# Time 1713798943.580578  Reply This just in ... M0000000000000028ffb0ffb000c8   M   0   0   0   40   -80   -80   200   23248
# Time 1713798943.5817063  Reply Start driving23249
# 1713798943.5925856 protocol iteration 73 [0, 0, 0, 0, 0, 40]
# Time 1713798943.7779746  Reply Finished driving 23449 S1done S2done S3done
# Time 1713798943.7779746  Reply first: M
# Time 1713798943.7819746  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   23451
# Time 1713798943.782981  Reply Start driving23452
# 1713798943.7929769 protocol iteration 74 [0, 0, 0, 0, 0, 40]
# Time 1713798943.9813294  Reply Finished driving 23652 S1done S2done S3done S4done
# Time 1713798943.98233  Reply first: M
# Time 1713798943.9863327  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   23654
# Time 1713798943.9873135  Reply Start driving23655
# 1713798943.9933367 protocol iteration 75 [0, 0, 0, 0, 40, -80]
# Time 1713798944.1850784  Reply Finished driving 23855 S1done S2done S3done S4done S5done
# Time 1713798944.1860783  Reply first: M
# Time 1713798944.1910765  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   23857
# Time 1713798944.1930764  Reply Start driving23858
# 1713798944.1940775 protocol iteration 76 [0, 0, 0, 0, 0, 40]
# Time 1713798944.3869288  Reply Finished driving 24058 S1done S2done S3done S4done
# Time 1713798944.387928  Reply first: M
# Time 1713798944.3939085  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   24060
# 1713798944.394908 protocol iteration 77 [0, 0, 0, 0, 0, 40]
# Time 1713798944.3969083  Reply Start driving24061
# Time 1713798944.5904627  Reply Finished driving 24261 S1done S2done S3done S4done S5done
# Time 1713798944.5914612  Reply first: M
# 1713798944.5954604 protocol iteration 78 [0, 0, 0, 0, 40, -80]
# Time 1713798944.598461  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   24263
# Time 1713798944.5994606  Reply Start driving24264
# Time 1713798944.7924929  Reply Finished driving 24464 S1done S2done S3done S4done S5done
# Time 1713798944.7934935  Reply first: M
# 1713798944.7954772 protocol iteration 79 [0, 0, 0, 0, 0, 40]
# Time 1713798944.8004987  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   24466
# Time 1713798944.8014958  Reply Start driving24467
# Time 1713798944.9948225  Reply Finished driving 24667 S1done S2done S3done S4done
# 1713798944.9958227 protocol iteration 80 [0, 0, 0, 0, 0, 40]
# Time 1713798944.996823  Reply first: M
# Time 1713798945.0018232  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   24669
# Time 1713798945.0028238  Reply Start driving24670
# 1713798945.1958377 protocol iteration 81 [0, 40, -80, -80, -80, -80]
# Time 1713798945.1998563  Reply Finished driving 24870 S1done S2done S3done S4done S5done
# Time 1713798945.1998563  Reply first: M
# Time 1713798945.2048438  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   24872
# Time 1713798945.2058442  Reply Start driving24873
# 1713798945.3963363 protocol iteration 82 [0, 0, 0, 0, 0, 40]
# Time 1713798945.4003386  Reply Finished driving 25073 S1done S2done S3done S4done S5done
# Time 1713798945.4013395  Reply first: f
# Time 1713798945.4053383  Reply This just in ... fi28ffb0ffb0ffb0ffb000c8   f   0   -1265   -1265   -1265   -1280   200   200   25076
# Time 1713798945.4063382  Reply Start driving25077
# 1713798945.5963542 protocol iteration 83 [0, 0, 0, 0, 0, 40]
# Time 1713798945.6033556  Reply Finished driving 25278 S1done
# Time 1713798945.604357  Reply first: M
# Time 1713798945.611368  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   25280
# Time 1713798945.6133733  Reply Start driving25281
# 1713798945.79637 protocol iteration 84 [0, 0, 0, 0, 40, -80]
# Time 1713798945.8073692  Reply Finished driving 25481 S1done
# Time 1713798945.8083696  Reply first: M
# Time 1713798945.8123696  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   25483
# Time 1713798945.8133705  Reply Start driving25484
# 1713798945.996432 protocol iteration 85 [0, 0, 0, 0, 0, 40]
# Time 1713798946.012433  Reply Finished driving 25684 S1done S2done S3done S4done S5done S6done
# Time 1713798946.012433  Reply first: M
# Time 1713798946.0164337  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   25687
# Time 1713798946.0184338  Reply Start driving25688
# 1713798946.196468 protocol iteration 86 [0, 0, 0, 0, 0, 40]
# Time 1713798946.2154663  Reply Finished driving 25888 S1done S2done S3done S4done
# Time 1713798946.2154663  Reply first: M
# Time 1713798946.21945  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   25890
# Time 1713798946.220451  Reply Start driving25891
# 1713798946.396595 protocol iteration 87 [0, 0, 0, 0, 40, -80]
# Time 1713798946.4184074  Reply Finished driving 26091 S1done S2done S3done S4done S5done
# Time 1713798946.4184074  Reply first: M
# Time 1713798946.425409  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   26093
# Time 1713798946.42741  Reply Start driving26094
# 1713798946.5974228 protocol iteration 88 [0, 0, 0, 0, 0, 40]
# Time 1713798946.6234243  Reply Finished driving 26294 S1done S2done S3done S4done S5done
# Time 1713798946.6234243  Reply first: M
# Time 1713798946.6294255  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   26296
# Time 1713798946.6314244  Reply Start driving26297
# 1713798946.7974381 protocol iteration 89 [0, 0, 0, 0, 0, 40]
# Time 1713798946.822443  Reply Finished driving 26497 S1done S2done S3done S4done
# Time 1713798946.8234415  Reply first: M
# Time 1713798946.827442  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   26499
# Time 1713798946.828442  Reply Start driving26500
# 1713798946.9977212 protocol iteration 90 [0, 0, 0, 40, -80, -80]
# Time 1713798947.0267227  Reply Finished driving 26700 S1done S2done S3done S4done S5done
# Time 1713798947.0277224  Reply first: M
# Time 1713798947.0328143  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   26702
# Time 1713798947.0337412  Reply Start driving26703
# 1713798947.1977386 protocol iteration 91 [0, 0, 0, 0, 0, 40]
# Time 1713798947.2297401  Reply Finished driving 26903 S1done S2done S3done S4done S5done
# Time 1713798947.2307553  Reply first: M
# Time 1713798947.2347417  Reply This just in ... M0000000000000028ffb0ffb000c8   M   0   0   0   40   -80   -80   200   26905
# Time 1713798947.2357428  Reply Start driving26906
# 1713798947.3977544 protocol iteration 92 [0, 0, 0, 0, 0, 40]
# Time 1713798947.4316669  Reply Finished driving 27106 S1done S2done S3done
# Time 1713798947.4316669  Reply first: M
# Time 1713798947.4356668  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   27108
# Time 1713798947.4366672  Reply Start driving27109
# 1713798947.598706 protocol iteration 93 [0, 0, 0, 0, 40, -80]
# Time 1713798947.6346993  Reply Finished driving 27309 S1done S2done S3done S4done
# Time 1713798947.6356978  Reply first: M
# Time 1713798947.6416838  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   27311
# Time 1713798947.6426837  Reply Start driving27312
# 1713798947.7996962 protocol iteration 94 [0, 0, 0, 0, 0, 40]
# Time 1713798947.8387005  Reply Finished driving 27512 S1done S2done S3done S4done S5done
# Time 1713798947.8397024  Reply first: M
# Time 1713798947.8457177  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   27514
# Time 1713798947.8467205  Reply Start driving27515
# 1713798947.9998252 protocol iteration 95 [0, 0, 0, 0, 0, 40]
# Time 1713798948.0428298  Reply Finished driving 27715 S1done S2done S3done S4done
# Time 1713798948.0438294  Reply first: M
# Time 1713798948.0498288  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   27717
# Time 1713798948.05083  Reply Start driving27718
# 1713798948.199841 protocol iteration 96 [0, 0, 0, 0, 40, -80]
# Time 1713798948.2428582  Reply Finished driving 27918 S1done S2done S3done S4done S5done
# Time 1713798948.2438636  Reply first: M
# Time 1713798948.250845  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   27920
# Time 1713798948.2518463  Reply Start driving27921
# 1713798948.3998613 protocol iteration 97 [0, 0, 0, 0, 0, 40]
# Time 1713798948.4457734  Reply Finished driving 28121 S1done S2done S3done S4done S5done
# Time 1713798948.446774  Reply first: M
# Time 1713798948.450794  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   28123
# Time 1713798948.4517899  Reply Start driving28124
# 1713798948.6007848 protocol iteration 98 [0, 0, 0, 0, 0, 40]
# Time 1713798948.6478093  Reply Finished driving 28324 S1done S2done S3done S4done
# Time 1713798948.6488047  Reply first: M
# Time 1713798948.6528056  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   28326
# Time 1713798948.6547904  Reply Start driving28327
# 1713798948.800801 protocol iteration 99 [0, 0, 0, 40, -80, -80]
# Time 1713798948.8538065  Reply Finished driving 28527 S1done S2done S3done S4done S5done
# Time 1713798948.8548064  Reply first: M
# Time 1713798948.8588057  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   28529
# Time 1713798948.8598065  Reply Start driving28530
# 1713798949.0010107 protocol iteration 100 [0, 0, 0, 0, 0, 40]
# Time 1713798949.0540178  Reply Finished driving 28730 S1done S2done S3done S4done S5done
# Time 1713798949.0540178  Reply first: M
# Time 1713798949.0600202  Reply This just in ... M0000000000000028ffb0ffb000c8   M   0   0   0   40   -80   -80   200   28732
# Time 1713798949.06202  Reply Start driving28733
# 1713798949.2010524 protocol iteration 101 [0, 0, 0, 0, 0, 40]
# Time 1713798949.2560325  Reply Finished driving 28933 S1done S2done S3done
# Time 1713798949.2570355  Reply first: M
# Time 1713798949.261054  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   28935
# Time 1713798949.262047  Reply Start driving28936
# 1713798949.4020433 protocol iteration 102 [0, 0, 0, 0, 40, -80]
# Time 1713798949.4586966  Reply Finished driving 29136 S1done S2done S3done S4done
# Time 1713798949.4586966  Reply first: M
# Time 1713798949.4631386  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   29138
# Time 1713798949.4641387  Reply Start driving29139
# 1713798949.602149 protocol iteration 103 [0, 0, 0, 0, 0, 40]
# Time 1713798949.663156  Reply Finished driving 29339 S1done S2done S3done S4done S5done
# Time 1713798949.664169  Reply first: M
# Time 1713798949.6691606  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   29341
# Time 1713798949.6701558  Reply Start driving29342
# 1713798949.8021677 protocol iteration 104 [0, 0, 0, 0, 0, 40]
# Time 1713798949.8641706  Reply Finished driving 29542 S1done S2done S3done S4done
# Time 1713798949.8651707  Reply first: M
# Time 1713798949.8721745  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   29544
# Time 1713798949.8741744  Reply Start driving29545
# 1713798950.002472 protocol iteration 105 [0, 0, 0, 0, 40, -80]
# Time 1713798950.0694993  Reply Finished driving 29745 S1done S2done S3done S4done S5done
# Time 1713798950.070478  Reply first: M
# Time 1713798950.073494  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   29747
# Time 1713798950.074479  Reply Start driving29748
# 1713798950.2025104 protocol iteration 106 [0, 0, 0, 0, 0, 40]
# Time 1713798950.2714958  Reply Finished driving 29948 S1done S2done S3done S4done S5done
# Time 1713798950.2724953  Reply first: M
# Time 1713798950.2774944  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   29950
# Time 1713798950.2784953  Reply Start driving29952
# 1713798950.4029999 protocol iteration 107 [0, 0, 0, 0, 0, 40]
# Time 1713798950.475023  Reply Finished driving 30152 S1done S2done S3done S4done
# Time 1713798950.4760215  Reply first: M
# Time 1713798950.4797082  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   30154
# Time 1713798950.4807084  Reply Start driving30155
# 1713798950.6032822 protocol iteration 108 [0, 0, 40, -80, -80, -80]
# Time 1713798950.6775873  Reply Finished driving 30355 S1done S2done S3done S4done S5done
# Time 1713798950.6785889  Reply first: M
# Time 1713798950.681586  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   30357
# Time 1713798950.68359  Reply Start driving30358
# 1713798950.8038054 protocol iteration 109 [0, 0, 0, 0, 0, 40]
# Time 1713798950.8828108  Reply Finished driving 30558 S1done S2done S3done S4done S5done
# Time 1713798950.883811  Reply first: M
# Time 1713798950.8928123  Reply This just in ... M000000000028ffb0ffb0ffb000c8   M   0   0   40   -80   -80   -80   200   30560
# Time 1713798950.894812  Reply Start driving30561
# 1713798951.0045922 protocol iteration 110 [0, 0, 0, 0, 0, 40]
# Time 1713798951.083364  Reply Finished driving 30761 S1done S2done
# Time 1713798951.083364  Reply first: M
# Time 1713798951.0873473  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   30764
# Time 1713798951.0893486  Reply Start driving30765
# 1713798951.2051628 protocol iteration 111 [0, 0, 0, 0, 40, -80]
# Time 1713798951.286048  Reply Finished driving 30965 S1done S2done S3done
# Time 1713798951.286048  Reply first: M
# Time 1713798951.2930553  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   30967
# Time 1713798951.2940555  Reply Start driving30968
# 1713798951.405296 protocol iteration 112 [0, 0, 0, 0, 0, 40]
# Time 1713798951.4905734  Reply Finished driving 31168 S1done S2done S3done S4done S5done
# Time 1713798951.491574  Reply first: M
# Time 1713798951.494573  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   31170
# Time 1713798951.4955733  Reply Start driving31171
# 1713798951.6060808 protocol iteration 113 [0, 0, 0, 0, 0, 40]
# Time 1713798951.6902661  Reply Finished driving 31371 S1done S2done S3done S4done
# Time 1713798951.691274  Reply first: M
# Time 1713798951.695263  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   31373
# Time 1713798951.695263  Reply Start driving31374
# 1713798951.807026 protocol iteration 114 [0, 0, 0, 0, 40, -80]
# Time 1713798951.8953073  Reply Finished driving 31574 S1done S2done S3done S4done S5done
# Time 1713798951.8953073  Reply first: M
# Time 1713798951.899314  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   31576
# Time 1713798951.9003124  Reply Start driving31577
# 1713798952.0076463 protocol iteration 115 [0, 0, 0, 0, 0, 40]
# Time 1713798952.0990453  Reply Finished driving 31777 S1done S2done S3done S4done S5done
# Time 1713798952.1000311  Reply first: M
# Time 1713798952.106048  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   31779
# Time 1713798952.1070433  Reply Start driving31780
# 1713798952.2080562 protocol iteration 116 [0, 0, 0, 0, 0, 40]
# Time 1713798952.3000624  Reply Finished driving 31980 S1done S2done S3done S4done
# Time 1713798952.3014047  Reply first: M
# Time 1713798952.307062  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   31982
# Time 1713798952.3080604  Reply Start driving31983
# 1713798952.4083238 protocol iteration 117 [0, 0, 0, 40, -80, -80]
# Time 1713798952.5026002  Reply Finished driving 32183 S1done S2done S3done S4done S5done
# Time 1713798952.5026002  Reply first: M
# Time 1713798952.5065932  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   32185
# Time 1713798952.5075934  Reply Start driving32186
# 1713798952.6083937 protocol iteration 118 [0, 0, 0, 0, 0, 40]
# Time 1713798952.7056277  Reply Finished driving 32386 S1done S2done S3done S4done S5done
# Time 1713798952.7066386  Reply first: M
# Time 1713798952.7106404  Reply This just in ... M0000000000000028ffb0ffb000c8   M   0   0   0   40   -80   -80   200   32388
# Time 1713798952.7116365  Reply Start driving32389
# 1713798952.8093297 protocol iteration 119 [0, 0, 0, 0, 0, 40]
# Time 1713798952.9093356  Reply Finished driving 32589 S1done S2done S3done
# Time 1713798952.9103525  Reply first: M
# Time 1713798952.9133577  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   32591
# Time 1713798952.9143574  Reply Start driving32592
# 1713798953.0093598 protocol iteration 120 [0, 0, 0, 0, 40, -80]
# Time 1713798953.1112418  Reply Finished driving 32792 S1done S2done S3done S4done
# Time 1713798953.1122363  Reply first: M
# Time 1713798953.1172416  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   32794
# Time 1713798953.118235  Reply Start driving32795
# 1713798953.2102416 protocol iteration 121 [0, 0, 0, 0, 0, 40]
# Time 1713798953.3142335  Reply Finished driving 32995 S1done S2done S3done S4done S5done
# Time 1713798953.3152337  Reply first: M
# Time 1713798953.3202362  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   32997
# Time 1713798953.3232355  Reply Start driving32998
# 1713798953.4102657 protocol iteration 122 [0, 0, 0, 0, 0, 40]
# Time 1713798953.5184538  Reply Finished driving 33198 S1done S2done S3done S4done
# Time 1713798953.5194528  Reply first: M
# Time 1713798953.525453  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   33200
# Time 1713798953.526454  Reply Start driving33201
# 1713798953.610424 protocol iteration 123 [0, 0, 0, 0, 40, -80]
# Time 1713798953.7207985  Reply Finished driving 33401 S1done S2done S3done S4done S5done
# Time 1713798953.7207985  Reply first: M
# Time 1713798953.7248192  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   33403
# Time 1713798953.7258198  Reply Start driving33404
# 1713798953.811149 protocol iteration 124 [0, 0, 0, 0, 0, 40]
# Time 1713798953.9231546  Reply Finished driving 33604 S1done S2done S3done S4done S5done
# Time 1713798953.9241388  Reply first: M
# Time 1713798953.9331539  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   33606
# Time 1713798953.9341547  Reply Start driving33607
# 1713798954.0112338 protocol iteration 125 [0, 0, 0, 0, 0, 40]
# Time 1713798954.1250522  Reply Finished driving 33807 S1done S2done S3done S4done
# Time 1713798954.1260586  Reply first: M
# Time 1713798954.1310558  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   33809
# Time 1713798954.1320548  Reply Start driving33810
# 1713798954.2118423 protocol iteration 126 [0, 0, 0, 40, -80, -80]
# Time 1713798954.3294282  Reply Finished driving 34010 S1done S2done S3done S4done S5done
# Time 1713798954.3304265  Reply first: M
# Time 1713798954.3384478  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   34012
# Time 1713798954.3394456  Reply Start driving34013
# 1713798954.4124525 protocol iteration 127 [0, 0, 0, 0, 0, 40]
# Time 1713798954.533555  Reply Finished driving 34213 S1done S2done S3done S4done S5done
# Time 1713798954.534557  Reply first: M
# Time 1713798954.5425568  Reply This just in ... M0000000000000028ffb0ffb000c8   M   0   0   0   40   -80   -80   200   34215
# Time 1713798954.5435567  Reply Start driving34216
# 1713798954.613394 protocol iteration 128 [0, 0, 0, 0, 0, 40]
# Time 1713798954.7344494  Reply Finished driving 34416 S1done S2done S3done
# Time 1713798954.7354496  Reply first: M
# Time 1713798954.7414327  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   34418
# Time 1713798954.7424455  Reply Start driving34419
# 1713798954.8136618 protocol iteration 129 [0, 0, 0, 0, 40, -80]
# Time 1713798954.9367063  Reply Finished driving 34619 S1done S2done S3done S4done
# Time 1713798954.937693  Reply first: M
# Time 1713798954.942689  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   34621
# Time 1713798954.944695  Reply Start driving34622
# 1713798955.0136943 protocol iteration 130 [0, 0, 0, 0, 0, 40]
# Time 1713798955.1392517  Reply Finished driving 34822 S1done S2done S3done S4done S5done
# Time 1713798955.1402342  Reply first: M
# Time 1713798955.1442523  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   34824
# Time 1713798955.1452587  Reply Start driving34825
# 1713798955.2141757 protocol iteration 131 [0, 0, 0, 0, 0, 40]
# Time 1713798955.3436565  Reply Finished driving 35025 S1done S2done S3done S4done
# Time 1713798955.3446574  Reply first: M
# Time 1713798955.3488605  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   35027
# Time 1713798955.3498538  Reply Start driving35028
# 1713798955.4151678 protocol iteration 132 [0, 0, 0, 0, 40, -80]
# Time 1713798955.5449443  Reply Finished driving 35228 S1done S2done S3done S4done S5done
# Time 1713798955.546945  Reply first: M
# Time 1713798955.5519514  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   35230
# Time 1713798955.552946  Reply Start driving35231
# 1713798955.6159441 protocol iteration 133 [0, 0, 0, 0, 0, 40]
# Time 1713798955.749216  Reply Finished driving 35431 S1done S2done S3done S4done S5done
# Time 1713798955.7502103  Reply first: M
# Time 1713798955.7562172  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   35433
# Time 1713798955.7582202  Reply Start driving35434
# 1713798955.8162138 protocol iteration 134 [0, 0, 0, 0, 0, 40]
# Time 1713798955.951146  Reply Finished driving 35634 S1done S2done S3done S4done
# Time 1713798955.951146  Reply first: M
# Time 1713798955.9551485  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   35636
# Time 1713798955.9561477  Reply Start driving35637
# 1713798956.016658 protocol iteration 135 [0, 0, 40, -80, -80, -80]
# Time 1713798956.1559289  Reply Finished driving 35837 S1done S2done S3done S4done S5done
# Time 1713798956.1569114  Reply first: M
# Time 1713798956.1609273  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   35840
# Time 1713798956.1619327  Reply Start driving35841
# 1713798956.2169175 protocol iteration 136 [0, 0, 0, 0, 0, 40]
# Time 1713798956.3575053  Reply Finished driving 36041 S1done S2done S3done S4done S5done
# Time 1713798956.3585055  Reply first: M
# Time 1713798956.3625004  Reply This just in ... M000000000028ffb0ffb0ffb000c8   M   0   0   40   -80   -80   -80   200   36043
# Time 1713798956.3625004  Reply Start driving36044
# 1713798956.417512 protocol iteration 137 [0, 0, 0, 0, 0, 40]
# Time 1713798956.5607913  Reply Finished driving 36244 S1done S2done
# Time 1713798956.5617979  Reply first: M
# Time 1713798956.5677984  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   36246
# Time 1713798956.569792  Reply Start driving36247
# 1713798956.6178007 protocol iteration 138 [0, 0, 0, 0, 40, -80]
# Time 1713798956.7610521  Reply Finished driving 36447 S1done S2done S3done
# Time 1713798956.7620678  Reply first: M
# Time 1713798956.7650692  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   36449
# Time 1713798956.7660677  Reply Start driving36450
# 1713798956.8182235 protocol iteration 139 [0, 0, 0, 0, 0, 40]
# Time 1713798956.9684353  Reply Finished driving 36651 S1done S2done S3done S4done S5done
# Time 1713798956.9704351  Reply first: M
# Time 1713798956.9774528  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   36653
# Time 1713798956.978453  Reply Start driving36654
# 1713798957.0187893 protocol iteration 140 [0, 0, 0, 0, 0, 40]
# Time 1713798957.1700988  Reply Finished driving 36854 S1done S2done S3done S4done
# Time 1713798957.1700988  Reply first: M
# Time 1713798957.1740978  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   36856
# Time 1713798957.175097  Reply Start driving36857
# 1713798957.2189736 protocol iteration 141 [0, 0, 0, 0, 40, -80]
# Time 1713798957.3735547  Reply Finished driving 37057 S1done S2done S3done S4done S5done
# Time 1713798957.3745546  Reply first: M
# Time 1713798957.3808181  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   37059
# Time 1713798957.3818183  Reply Start driving37060
# 1713798957.419841 protocol iteration 142 [0, 0, 0, 0, 0, 40]
# Time 1713798957.5754101  Reply Finished driving 37260 S1done S2done S3done S4done S5done
# Time 1713798957.5764103  Reply first: M
# Time 1713798957.5804107  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   37262
# Time 1713798957.581427  Reply Start driving37263
# 1713798957.6205947 protocol iteration 143 [0, 0, 0, 0, 0, 40]
# Time 1713798957.7782614  Reply Finished driving 37463 S1done S2done S3done S4done
# Time 1713798957.779266  Reply first: M
# Time 1713798957.785246  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   37465
# Time 1713798957.787247  Reply Start driving37466
# 1713798957.8212671 protocol iteration 144 [0, 0, 0, 40, -80, -80]
# Time 1713798957.9815755  Reply Finished driving 37666 S1done S2done S3done S4done S5done
# Time 1713798957.9815755  Reply first: M
# Time 1713798957.9855824  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   37668
# Time 1713798957.988565  Reply Start driving37669
# 1713798958.0219448 protocol iteration 145 [0, 0, 0, 0, 0, 40]
# Time 1713798958.1827  Reply Finished driving 37869 S1done S2done S3done S4done S5done
# Time 1713798958.1827  Reply first: M
# Time 1713798958.1867046  Reply This just in ... M0000000000000028ffb0ffb000c8   M   0   0   0   40   -80   -80   200   37871
# Time 1713798958.1876867  Reply Start driving37872
# 1713798958.2227008 protocol iteration 146 [0, 0, 0, 0, 0, 40]
# Time 1713798958.3874195  Reply Finished driving 38072 S1done S2done S3done
# Time 1713798958.3874195  Reply first: M
# Time 1713798958.391437  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   38074
# Time 1713798958.3924384  Reply Start driving38075
# 1713798958.4234333 protocol iteration 147 [0, 0, 0, 0, 40, -80]
# Time 1713798958.5886993  Reply Finished driving 38275 S1done S2done S3done S4done
# Time 1713798958.5896986  Reply first: M
# Time 1713798958.5937166  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   38277
# Time 1713798958.5947187  Reply Start driving38278
# 1713798958.6237204 protocol iteration 148 [0, 0, 0, 0, 0, 40]
# Time 1713798958.7940955  Reply Finished driving 38478 S1done S2done S3done S4done S5done
# Time 1713798958.795101  Reply first: M
# Time 1713798958.8010805  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   38480
# Time 1713798958.8030798  Reply Start driving38481
# 1713798958.8240862 protocol iteration 149 [0, 0, 0, 0, 0, 40]
# Time 1713798958.9934945  Reply Finished driving 38681 S1done S2done S3done S4done
# Time 1713798958.9934945  Reply first: M
# Time 1713798958.9974782  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   38683
# Time 1713798958.998478  Reply Start driving38684
# 1713798959.0247242 protocol iteration 150 [0, 0, 0, 0, 40, -80]
# Time 1713798959.1978972  Reply Finished driving 38884 S1done S2done S3done S4done S5done
# Time 1713798959.1978972  Reply first: M
# Time 1713798959.201898  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   38886
# Time 1713798959.2028975  Reply Start driving38887
# 1713798959.225159 protocol iteration 151 [0, 0, 0, 0, 0, 40]
# Time 1713798959.3996499  Reply Finished driving 39087 S1done S2done S3done S4done S5done
# Time 1713798959.400652  Reply first: M
# Time 1713798959.4066532  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   39089
# Time 1713798959.4076488  Reply Start driving39090
# 1713798959.4256346 protocol iteration 152 [0, 0, 0, 0, 0, 40]
# Time 1713798959.602257  Reply Finished driving 39290 S1done S2done S3done S4done
# Time 1713798959.6042366  Reply first: M
# Time 1713798959.608236  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   39292
# Time 1713798959.608236  Reply Start driving39293
# 1713798959.6262596 protocol iteration 153 [0, 0, 0, 40, -80, -80]
# Time 1713798959.805729  Reply Finished driving 39493 S1done S2done S3done S4done S5done
# Time 1713798959.806732  Reply first: M
# Time 1713798959.8127315  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   39495
# Time 1713798959.8137314  Reply Start driving39496
# 1713798959.8267272 protocol iteration 154 [0, 0, 0, 0, 0, 40]
# Time 1713798960.0087454  Reply Finished driving 39696 S1done S2done S3done S4done S5done
# Time 1713798960.01173  Reply first: M
# Time 1713798960.0222774  Reply This just in ... M0000000000000028ffb0ffb000c8   M   0   0   0   40   -80   -80   200   39698
# Time 1713798960.0232606  Reply Start driving39699
# 1713798960.027268 protocol iteration 155 [0, 0, 0, 0, 0, 40]
# Time 1713798960.2097292  Reply Finished driving 39899 S1done S2done S3done
# Time 1713798960.2097292  Reply first: M
# Time 1713798960.2137344  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   39901
# Time 1713798960.2147298  Reply Start driving39902
# 1713798960.2277288 protocol iteration 156 [0, 0, 0, 0, 40, -80]
# Time 1713798960.41403  Reply Finished driving 40102 S1done S2done S3done S4done
# Time 1713798960.4150271  Reply first: M
# Time 1713798960.4191597  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   40104
# Time 1713798960.4201415  Reply Start driving40105
# 1713798960.4281642 protocol iteration 157 [0, 0, 0, 0, 0, 40]
# Time 1713798960.6162348  Reply Finished driving 40305 S1done S2done S3done S4done S5done
# Time 1713798960.6182446  Reply first: M
# Time 1713798960.6222365  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   40307
# Time 1713798960.6232352  Reply Start driving40308
# 1713798960.6282363 protocol iteration 158 [0, 0, 0, 0, 0, 40]
# Time 1713798960.8200123  Reply Finished driving 40508 S1done S2done S3done S4done
# Time 1713798960.8210151  Reply first: M
# Time 1713798960.826032  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   40510
# Time 1713798960.8270323  Reply Start driving40511
# 1713798960.8290272 protocol iteration 159 [0, 0, 0, 0, 40, -80]
# Time 1713798961.0220304  Reply Finished driving 40711 S1done S2done S3done S4done S5done
# Time 1713798961.0220304  Reply first: M
# Time 1713798961.0270429  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   40713
# Time 1713798961.0290515  Reply Start driving40714
# 1713798961.0290515 protocol iteration 160 [0, 0, 0, 0, 0, 40]
# Time 1713798961.2260494  Reply Finished driving 40914 S1done S2done S3done S4done S5done
# Time 1713798961.2280464  Reply first: M
# 1713798961.2300458 protocol iteration 161 [0, 0, 0, 0, 0, 40]
# Time 1713798961.2340617  Reply This just in ... M00000000000000000028ffb000c8   M   0   0   0   0   40   -80   200   40916
# Time 1713798961.2340617  Reply Start driving40918
# 1713798961.4302194 protocol iteration 162 [0, 40, -80, -80, -80, -80]
# Time 1713798961.432222  Reply Finished driving 41118 S1done S2done S3done S4done
# Time 1713798961.4332194  Reply first: M
# Time 1713798961.4412048  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   41120
# Time 1713798961.4432018  Reply Start driving41121
# 1713798961.6312163 protocol iteration 163 [0, 0, 0, 0, 0, 40]
# Time 1713798961.632217  Reply Finished driving 41321 S1done S2done S3done S4done S5done
# Time 1713798961.6332178  Reply first: M
# Time 1713798961.6372204  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   41323
# Time 1713798961.6382203  Reply Start driving41324
# 1713798961.8312948 protocol iteration 164 [0, 0, 0, 0, 0, 40]
# Time 1713798961.835382  Reply Finished driving 41524 S1done S2done S3done S4done S5done
# Time 1713798961.835925  Reply first: M
# Time 1713798961.8420863  Reply This just in ... M00000028ffb0ffb0ffb0ffb000c8   M   0   40   -80   -80   -80   -80   200   41526
# Time 1713798961.843125  Reply Start driving41527
# 1713798962.0321581 protocol iteration 165 [0, 0, 0, 0, 40, -80]
# Time 1713798962.0351593  Reply Finished driving 41728 S1done
# Time 1713798962.037141  Reply first: M
# Time 1713798962.0421596  Reply This just in ... M00000000000000000000002800c8   M   0   0   0   0   0   40   200   41730
# Time 1713798962.044147  Reply Start driving41731
# 1713798962.232628 protocol iteration 166 [0, 0, 0, 0, 0, 40]
# Time 1713798962.2416275  Reply Finished driving 41931 S1done S2done
# Time 1713798962.2416275  Reply first: M
# Time 1713798962.2466235  Reply This just in ... M000<fi00000000000000002800c8   M   0   15   0   0   0   40   200   41933
# Time 1713798962.247624  Reply Start driving41934
# 1713798962.4326534 protocol iteration 167 [0, 0, 0, 0, 0, 40]
# Time 1713798962.4446652  Reply Finished driving 42134 S1done S2done S3done S4done S5done
# Time 1713798962.4456594  Reply first: <
# Time 1713798962.4506633  Reply This just in ... <M00000000000000000000002800c8   <   0   0   0   0   0   2   32780   42136
# Time 1713798962.4516654  Reply Start driving42137
# 1713798962.6326563 protocol iteration 168 [0, 0, 0, 0, 40, -80]
# 1713798962.832689 protocol iteration 169 [0, 0, 0, 0, 0, 40]
# 1713798963.0328877 protocol iteration 170 [0, 0, 0, 0, 0, 40]
# 1713798963.233423 protocol iteration 171 [0, 0, 0, 40, -80, -80]
# 1713798963.4339616 protocol iteration 172 [0, 0, 0, 0, 0, 40]
# 1713798963.6339622 protocol iteration 173 [0, 0, 0, 0, 0, 40]
# 1713798963.833996 protocol iteration 174 [0, 0, 0, 0, 40, -80]
# 1713798964.0340428 protocol iteration 175 [0, 0, 0, 0, 0, 40]
# 1713798964.2350383 protocol iteration 176 [0, 0, 0, 0, 0, 40]
# 1713798964.4353752 protocol iteration 177 [0, 0, 0, 0, 40, -80]
# 1713798964.6354039 protocol iteration 178 [0, 0, 0, 0, 0, 40]
# 1713798964.8354335 protocol iteration 179 [0, 0, 0, 0, 0, 40]
# 1713798965.0363793 protocol iteration 180 [0, 0, 0, 40, -80, -80]
# 1713798965.2363973 protocol iteration 181 [0, 0, 0, 0, 0, 40]
# 1713798965.4373665 protocol iteration 182 [0, 0, 0, 0, 0, 40]
# 1713798965.6381538 protocol iteration 183 [0, 0, 0, 0, 40, -80]
# 1713798965.838172 protocol iteration 184 [0, 0, 0, 0, 0, 40]
