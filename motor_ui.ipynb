# %%
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QVBoxLayout, QLabel, QCheckBox, QSpinBox
import serial
import time
import numpy as np
from datetime import datetime, timedelta
import random
import itertools

# %% [markdown]
# # UI

# %%
class MotorControlerUI(QWidget): #this ui code should be cleaned up
    def __init__(self):
        super().__init__()
        self.initUI()
        self.ui_events = []

    def initUI(self):
        # Create buttons s1 to s6
        self.buttons = []
        button_pos =[(50,50),(50,100),(50,150),(50,200),(50,250),(50,300)]
        for i in range(1, 7):
            button = QPushButton(f'S{i}', self)
            button.clicked.connect(self.buttonClicked)
            button.move(button_pos[i-1][0],button_pos[i-1][1])
            self.buttons.append(button)

        #labels for s1->s6
        self.labels = []
        label_pos = [(bp[0]*4,bp[1]) for bp in button_pos]
        for i in range(1,7):
            label = QLabel(f"Label{i}",self)
            label.move(label_pos[i-1][0],label_pos[i-1][1])
            label.setText("0")
            label.setFixedWidth(50)
            self.labels.append(label)

        #spinBox for s1->s6
        self.spinboxs = []
        spinbox_pos = [(bp[0]*6,bp[1]) for bp in button_pos]
        for i in range(1,7):
            spinbox = QSpinBox(self)
            spinbox.setObjectName(f"s{i}")
            spinbox.setRange(-500,500)
            spinbox.setFixedWidth(150)
            spinbox.move(spinbox_pos[i-1][0],spinbox_pos[i-1][1])
            self.spinboxs.append(spinbox)
        
        #buton pairs (1-6,2-5,3-4)
        self.pair_buttons = []
        pair_button_pos = [(bp[0]*10,bp[1]) for bp in button_pos[:3]]
        pair_button_names = ["S1-6","S2-5","S3-4"]
        for i in range(3):
            button = QPushButton(pair_button_names[i], self)
            button.clicked.connect(self.pairButtonCliked)
            button.move(pair_button_pos[i][0],pair_button_pos[i][1])
            self.pair_buttons.append(button)
        
        #spinbox pairs (1-6,2-5,3-4)
        self.pair_spinboxs = []
        pair_spinbox_pos = [(bp[0]*12,bp[1]) for bp in button_pos[:3]]
        for i in range(3):
            spinbox = QSpinBox(self)
            spinbox.setObjectName(pair_button_names[i])
            spinbox.setRange(-500,500)
            spinbox.setFixedWidth(150)
            spinbox.move(pair_spinbox_pos[i][0],pair_spinbox_pos[i][1])
            self.pair_spinboxs.append(spinbox)


        #time input
        self.timeInput = QSpinBox(self)
        self.timeInput.setObjectName("timeInput")
        self.timeInput.setRange(700,100000)
        self.timeInput.setFixedWidth(150)
        self.timeInput.move(spinbox_pos[5][0],spinbox_pos[5][1]+100)

        #time input explanation
        self.labelTime = QLabel("Time pr. instruction",self)
        self.labelTime.move(label_pos[5][0]-50,label_pos[5][1]+100)

        #spinbox header
        self.labelInfo = QLabel("- = ClockWise",self)
        self.labelInfo.move(spinbox_pos[0][0],spinbox_pos[0][1]-25)

        #label header
        self.labelPos = QLabel("MotorPosition",self)
        self.labelPos.move(label_pos[0][0],label_pos[0][1]-25)

        #all motors input
        self.allButton = QPushButton(f'S1-6', self)
        self.allButton.clicked.connect(self.allButtonClicked)
        self.allButton.move(button_pos[5][0],button_pos[5][1]+100)

        #start protocol
        self.startProt = QPushButton("StartProtocol",self)
        self.startProt.clicked.connect(self.startProtocol)
        self.startProt.move(button_pos[5][0],button_pos[5][1]+200)

        #reset position labels button

        #TESTPERSON SETUP
        #Start Testperson button
        self.startTP = QPushButton("StartTP",self)
        self.startTP.clicked.connect(self.startTestperson)
        self.startTP.move(button_pos[0][0]*16,button_pos[0][1])

        #Select testperson spinbox
        self.testperson = QSpinBox(self)
        self.testperson.setObjectName("SelectTP")
        self.testperson.setRange(0,9)
        self.testperson.setFixedWidth(150)
        self.testperson.move(button_pos[1][0]*16,button_pos[1][1])

        #Select model spinbox
        self.model = QSpinBox(self)
        self.model.setObjectName("SelectModel")
        self.model.setRange(0,9)
        self.model.setFixedWidth(150)
        self.model.move(button_pos[2][0]*16,button_pos[2][1])

        #Select amount of iterations spinbox
        self.repeats = QSpinBox(self)
        self.repeats.setObjectName("SelectTP")
        self.repeats.setRange(1,9)
        self.repeats.setFixedWidth(150)
        self.repeats.move(button_pos[3][0]*16,button_pos[3][1])

        #Show movment counter label
        self.ctrLabel = QLabel("CTR",self)
        self.ctrLabel.move(button_pos[4][0]*16,button_pos[4][1])


        self.setWindowTitle('Motor controler')
        self.setGeometry(300, 300, 1100, 600)  # Set window position and size

    #UPDATES
    def updateLabels(self,mc): #pass array of motor change values to update labels
        for i in range(6):
            label = self.labels[i]
            cur_val = int(label.text())
            label.setText(str(cur_val+mc[i]))

    def updateCtr(self,ctr): #update the ctr
        self.ctrLabel.setText(f"CTR: {ctr[0]}")

    #UI EVENTS
    def buttonClicked(self): #button click (adds spinbox to label)
        sender = self.sender()
        index = int(sender.text()[1]) - 1
        spinbox = self.spinboxs[index]
        change_val = spinbox.value()
        label = self.labels[index]
        cur_val = int(label.text())
        new_val = change_val+cur_val
        label.setText(str(new_val))
        #get time
        time_val = self.timeInput.value()

        self.ui_events.append(["1B",index,change_val,time_val,f'Button {sender.text()} clicked. With Value {change_val}: {cur_val} -> {new_val}'])

    def allButtonClicked(self): #button for running all motors at the same time
        mc = [0,0,0,0,0,0]
        time_val = self.timeInput.value()
        
        for i in range(6): #get value from each of the spin boxes
            mc[i] = self.spinboxs[i].value()
            label = self.labels[i]
            label.setText(str(mc[i]+int(label.text())))

        self.ui_events.append(["AB",mc,time_val,f"Allbutton {self.sender().text()} clicked. With Values {mc}'"])

    def startProtocol(self): #start a relative move protocol
        self.ui_events.append(["SP",f"StartProtocol {self.sender().text()} clicked."])

    def pairButtonCliked(self): #control motors pairwise
        sender = self.sender().text()
        time_val = self.timeInput.value()
        mc = [0,0,0,0,0,0]
        match sender: #could be made cleaner with a map or somting
            case "S1-6":
                val = self.pair_spinboxs[0].value()
                mc[0] = val
                mc[5] = val
            case "S2-5": #s2-5
                val = self.pair_spinboxs[1].value()
                mc[1] = val
                mc[4] = val   
            case "S3-4": #s3-4
                val = self.pair_spinboxs[2].value()
                mc[2] = val
                mc[3] = val

        self.updateLabels(mc)
        self.ui_events.append(["PB",mc,time_val,f"Pairbutton {sender} clicked. With Values {mc}'"])

    def startTestperson(self): #start a test person movement
        sender = self.sender().text()
        tp_val = self.testperson.value()
        model_val = self.model.value()
        repeats = self.repeats.value()

        self.ui_events.append(["TP",tp_val,model_val,repeats,f"TestPerson {sender} clicked."])

#Handle events
def handleUIEvents(ui_widget,mc,timeval,protocol,tp,mc_idx,repeats):
    while ui_widget.ui_events:
        event = ui_widget.ui_events.pop(0)
        print(event)

        match event[0]: #TODO: make a standard structure for events (but good enough for now)
            case "1B": #1:idx 2:changeVal 3: time val   #1 button clicked
                mc[event[1]] = event[2]
                timeval[0] = event[3]
            case "AB": #1: mcVal #2:time val            #All button clicked
                for i in range(6):
                    mc[i] = event[1][i]
                timeval[0] = event[2]
            case "SP":                                  #start protocol cliced
                protocol[0] = True
            case "PB": #1:mc 2:time                     #pair button clicked
                for i in range(6):
                    mc[i] = event[1][i]
                timeval[0] = event[2]
            case "TP": #1:tpval, 2:model val 3:repeats  #test person clicked
                tp[0] = True
                mc_idx[0] = event[1]
                mc_idx[1] = event[2]
                repeats[0] = event[3]
            case _:
                print(f"Unknown first event {event[0]}")

    app.processEvents()

# %% [markdown]
# # Serial protocol

# %%
#initial protocol from https://forum.arduino.cc/t/serial-input-basics-updated/382007/2
# and https://forum.arduino.cc/t/pc-arduino-comms-using-python-updated/574496 

startMarker = '<'
endMarker = '>'
dataStarted = False
dataBuf = ""
messageComplete = False

#========================
#========================
    # the functions

def setupSerial(baudRate, serialPortName):
    global  serialPort
    serialPort = serial.Serial(port= serialPortName, baudrate = baudRate, timeout=0, rtscts=True)
    print("Serial port " + serialPortName + " opened  Baudrate " + str(baudRate))
    waitForArduino()

#========================

def sendToArduino(stringToSend):
    # this adds the start- and end-markers before sending
    global startMarker, endMarker, serialPort
    
    stringWithMarkers = (startMarker)
    stringWithMarkers += stringToSend
    stringWithMarkers += (endMarker)

    serialPort.write(stringWithMarkers.encode('utf-8')) # encode needed for Python3

#==================

def recvLikeArduino():

    global startMarker, endMarker, serialPort, dataStarted, dataBuf, messageComplete

    if serialPort.inWaiting() > 0 and messageComplete == False:
        x = serialPort.read().decode("utf-8") # decode needed for Python3
        
        if dataStarted == True:
            if x != endMarker:
                dataBuf = dataBuf + x
            else:
                dataStarted = False
                messageComplete = True
        elif x == startMarker:
            dataBuf = ''
            dataStarted = True
    
    if (messageComplete == True):
        messageComplete = False
        return dataBuf
    else:
        return "XXX" 

#==================

def waitForArduino():
    # wait until the Arduino sends 'Arduino is ready' - allows time for Arduino reset
    # it also ensures that any bytes left over from a previous message are discarded
    print("Waiting for Arduino to reset")
     
    msg = ""
    while msg.find("Arduino is ready") == -1:
        msg = recvLikeArduino()
        if not (msg == 'XXX'): 
            print(msg)

# %% [markdown]
# # Messaging protocol

# %%
#<msg> (where "<" starts a msg and ">" ends 1)

#start <
#first char is used for identifying the type of msg. M=reltive move, G=goto move (not implemented yet)
#next 4x6 chars are used for the amount you want the steppers to move 2signed bytes pr stepper
#4bytes for the amount of time to complete the moves
#end >

def num_to_hex(num):
  if num > 32767  or num < -32768:
    raise TypeError(f"Number {num} is does not fit withing 4 char hex")
  
  # Convert negative numbers to two's complement representation
  if num < 0:
    num = (1 << 16) + num
  
  hex_value = hex(num & 0xFFFF)[2:].zfill(4)  # Convert to hexadecimal and pad with zeros
  return hex_value

def hex_to_num(hex_string):
  if not isinstance(hex_string, str) or len(hex_string) != 4:
    TypeError(f"Input must be a string of 4 characters")
  
  num = int(hex_string, 16)
  # Handle negative numbers
  if num >= 0x8000:
      num -= 1 << 16
  return num

#convert array of relative motor steps to a string that can be sent to the arduino
#current types: (R) and M
def encode_motor_msg(motor_steps,timer,msg_type):
  if not(msg_type in ["M","R"]):
    TypeError(f"Unknown msg_type: {msg_type}")
  
  if len(motor_steps) != 6:
    TypeError(f"Expected 6 motor values got: {motor_steps}")
  
  motor_hex = ""
  for ms in motor_steps:
    motor_hex += num_to_hex(ms)
  
  time_hex = num_to_hex(timer)

  return msg_type + motor_hex + time_hex

#decode motor message

def decode_motor_msg(motor_msg):
  msg_type = motor_msg[0]
  motor_hex = motor_msg[1:25]
  timer_hex = motor_msg[25:29]

  motor_vals = []
  for i in range(0,24,4):
    motor_vals.append(hex_to_num(motor_hex[i:i+4])) 
  

  return msg_type, motor_vals, hex_to_num(timer_hex)


#How to use:
#numbers = [-1234, 32767, 9012, 3456, -7890, 1234]
#for i in numbers:
#  hexval = num_to_hex(i)
#  print(hexval,hex_to_num(hexval))
#fullEncode = encode_motor_msg(numbers,1000,"M")
#print(fullEncode,decode_motor_msg(fullEncode))

# %% [markdown]
# # Protocols

# %%
# Define the ranges for each number
ranges = [
    range(-20, 21,20),  # Range for S1
    range(-20, 21,20),  # Range for S2
    range(-20, 21,20),  # Range for S3
    range(-20, 21,20),  # Range for S4
    range(-20, 21,20),  # Range for S5
    range(-20, 21,20),  # Range for S6
]

# Generate all combinations
combinations = list(itertools.product(*ranges))
comb_list = list(map(list,combinations))
print(len(comb_list))

# %%
#function for repeatin protocol (does not create copies, uses same ref)
def repeatProtocol(prot,amount):
  return prot*amount

#Transform exact positions into relative positions
def calcRelativePos(cur,moves):
  rel_moves = []
  cur_poses = []
  for m in moves:
    rel = [0,0,0,0,0,0]
    for i in range(6):
      rel[i] = m[i] - cur[i]
    cur = m
    rel_moves.append(rel)
    cur_poses.append(cur)
  return rel_moves, cur_poses

# %%
prot_20_gridsearch, _ = calcRelativePos([0,0,0,0,0,0],comb_list)

prot_ur = [[50,50,50,50,50,50],[-50,-50,-50,-50,-50,-50]]
prot_full = [[100,100,100,100,100,100],[-100,-100,-100,-100,-100,-100],[-100,-100,-100,-100,-100,-100],[100,100,100,100,100,100]] 
prot_34 = [[0,0,100,100,0,0],[0,0,-100,-100,0,0],[0,0,-100,-100,0,0],[0,0,100,100,0,0]]
prot_dr = [[-100,-100,-100,-100,-100,-100],[100,100,100,100,100,100]]
prot_34_down = [[0,0,100,100,0,0],[0,0,-100,-100,0,0]]


prot_full_10 = repeatProtocol(prot_full,10)
prot_updwon_10 = repeatProtocol(prot_ur,50)
prot_34_10 = repeatProtocol(prot_34,10)
prot_dr_10 = repeatProtocol(prot_dr,50)
prot_34_down_50 = repeatProtocol(prot_34_down,50)

# %% [markdown]
# # Testperson data -> protocol

# %%
#check size of relative moves
def inspect_tp_vals(tp,min_val,max_val):
  print(f"MAX {np.max(np.array(tp),axis=0)} MIN {np.min(np.array(tp),axis=0)}")
  for s,i in enumerate(tp):
    for j in i:
      if j > max_val or j < min_val:
        print(i,s)
        break

# %%
#load model predictions from /Predictions/
path = r"Predictions\Other\5_step_isolation_input.npy"
predictions = np.load(path)
rel_preds, _ = calcRelativePos([0,0,0,0,0,0],list(map(list,predictions)))

# %%
#inspect testperson prediction
# print(predictions.shape)

# for t in range(predictions.shape[0]):
#   l = list(map(list,predictions[t]))
#   rels, _ = calcRelativePos([0,0,0,0,0,0],l)
#   print(t,np.array(rels).shape,np.array(l).shape)
#   model0_rel.append(rels)

# print(np.array(model0_rel).shape)

# for i in range(len(model0_rel)):
#   print(f"######## tp {i} ########")
#   #print(type(arramodel0_rel[i][0]))
#   inspect_tp_vals(model0_rel[i],-20,20)

# #inspect_tp_vals(rel_iso,-20,20)

# %% [markdown]
# # Main loop

# %%
setupSerial(1000_000,"COM3")

motor_vals = [0,0,0,0,0,0] #current motor positions
motor_change = [0,0,0,0,0,0] #Changes for next motor iteration
time_val = [1] # time pointer

def calcMotorvals(cur,new):
    return [a+b for a,b in zip(cur,new)]

#OWN PROTOCOL SETUP
protocol_running = [False] #protocol pointer
protocol_ctr = 0 #counter for where in protocl we are
protocol_delay = 2 #in seconds
protocol_mc = prot_updwon_10 #Specify protocol (eg. grid search or testperson)
protocol_prevtime = 0
protocol_maxctr = len(protocol_mc)
protocol_protection = 100 #protection against overflow in ms

#TESTPERSON PROTOCOL SETUP (Not implemented yet)
tp_running = [False]
tp_ctr = 0
tp_delay = 0.8 #time between tp moves
tp_mc_idx = [0,0] #pointer to model number,testperson id
tp_mc = []  #mc for all models/testpersons
tp_prevtime = 0
tp_maxctr = 0 #needs to be set depending on protocol
tp_repeat = [1]
tp_protection = 50 #protection against overflow in ms

if __name__ == '__main__':
    app = QApplication(sys.argv)
    mcUI = MotorControlerUI()
    mcUI.show()

    # Your main loop
    while True:
        # Receive and handle messages from the microcontroller 
        arduinoReply = recvLikeArduino() # check for a reply
        if not (arduinoReply == 'XXX'):
            print ("Time %s  Reply %s" %(time.time(), arduinoReply))
    
        # Handle UI events
        handleUIEvents(mcUI,motor_change,time_val,protocol_running,tp_running,tp_mc_idx,tp_repeat)

        # Respond to the microcontroller
        if motor_change != [0,0,0,0,0,0] and not protocol_running[0]: #control with UI
            motor_vals = calcMotorvals(motor_vals,motor_change) #update total motor values
            enc_msg = encode_motor_msg(motor_change,time_val[0],"M")
            sendToArduino(enc_msg)
            print("motorchange:",motor_change,"msg:", enc_msg, "time:", time_val)

            motor_change = [0,0,0,0,0,0]

        elif protocol_running[0]: #protocol handling
            t = time.time()
            if protocol_prevtime == 0:
                protocol_prevtime = t
            if t - protocol_prevtime > protocol_delay: #send next move after certain time
                protocol_prevtime = (datetime.fromtimestamp(protocol_prevtime) + timedelta(seconds=protocol_delay)).timestamp()
                motor_vals = calcMotorvals(motor_vals,protocol_mc[protocol_ctr])

                mcUI.updateLabels(protocol_mc[protocol_ctr]) #update labels in UI

                enc_msg = encode_motor_msg(protocol_mc[protocol_ctr],int(protocol_delay*1000-protocol_protection),"M")
                sendToArduino(enc_msg)

                print(protocol_prevtime,f"protocol iteration {protocol_ctr}",protocol_mc[protocol_ctr])
                protocol_ctr += 1
            
            if protocol_ctr == protocol_maxctr: #reset after protocol is finished
                protocol_running[0] = False
                protocol_ctr = 0
                protocol_prevtime = 0
                print("protocol finished")

        elif tp_running[0]: #test person handling (not fully implemented)
            t = time.time()

            if tp_prevtime == 0: #handle first start
                tp_prevtime = time.time()

            if tp_ctr == 0: #handele each new iteration
                tp_maxctr = len(tp_mc[tp_mc_idx[0]][tp_mc_idx[1]])
                print(f"Starting Model {tp_mc_idx[0]} TP {tp_mc_idx[1]} Iteration {tp_repeat[0]}")

            if t - tp_prevtime > tp_delay: #send next move after certain time
                tp_prevtime = t

                next_motorval = tp_mc[tp_mc_idx[0]][tp_mc_idx[1]][tp_ctr]
                motor_vals = calcMotorvals(motor_vals,next_motorval)

                mcUI.updateLabels(next_motorval) #update UI labels
                mcUI.updateCtr([tp_ctr]) #update ctr

                enc_msg = encode_motor_msg(next_motorval,int(tp_delay*1000-tp_protection),"M")
                sendToArduino(enc_msg)

                print(tp_prevtime,f"M: {tp_mc_idx[0]} TP: {tp_mc_idx[1]} I: {tp_repeat[0]} step: {tp_ctr} mc: {next_motorval}")
                tp_ctr += 1
            
            if tp_ctr == tp_maxctr: #reset protocol / start next iteration
                tp_ctr = 0
                if tp_repeat[0] == 1: #check if all iterations are finished
                    tp_running[0] = False
                else:
                    print(f"Finished Model {tp_mc_idx[0]} TP {tp_mc_idx[1]} Iteration {tp_repeat[0]}")
                    tp_repeat[0] = tp_repeat[0] - 1


    
    sys.exit(app.exec_()) #independently run the program
# Out:
# Serial port COM3 opened  Baudrate 1000000
# Waiting for Arduino to reset
# Arduino is ready
# ['AB', [-50, -50, -50, -50, -50, -50], 2000, "Allbutton S1-6 clicked. With Values [-50, -50, -50, -50, -50, -50]'"]
# motorchange: [-50, -50, -50, -50, -50, -50] msg: Mffceffceffceffceffceffce07d0 time: [2000]
# Time 1717492252.8531232  Reply first: M
# Time 1717492252.8591266  Reply This just in ... Mffceffceffceffceffceffce07d0   M   -50   -50   -50   -50   -50   -50   2000   18091
# Time 1717492252.8611298  Reply Start driving18091
# Time 1717492254.8587165  Reply Finished driving 20092 S1done S2done S3done S4done S5done S6done
# ['AB', [-50, -50, -50, -50, -50, -50], 2000, "Allbutton S1-6 clicked. With Values [-50, -50, -50, -50, -50, -50]'"]
# motorchange: [-50, -50, -50, -50, -50, -50] msg: Mffceffceffceffceffceffce07d0 time: [2000]
# Time 1717492262.6918695  Reply first: M
# Time 1717492262.6978693  Reply This just in ... Mffceffceffceffceffceffce07d0   M   -50   -50   -50   -50   -50   -50   2000   27928
# Time 1717492262.6988692  Reply Start driving27929
# Time 1717492264.6981957  Reply Finished driving 29929 S1done S2done S3done S4done S5done S6done
# ['AB', [-10, -10, -10, -10, -10, -10], 2000, "Allbutton S1-6 clicked. With Values [-10, -10, -10, -10, -10, -10]'"]
# motorchange: [-10, -10, -10, -10, -10, -10] msg: Mfff6fff6fff6fff6fff6fff607d0 time: [2000]
# Time 1717492273.2547286  Reply first: M
# Time 1717492273.261732  Reply This just in ... Mfff6fff6fff6fff6fff6fff607d0   M   -10   -10   -10   -10   -10   -10   2000   38489
# Time 1717492273.26273  Reply Start driving38490
# Time 1717492275.2617207  Reply Finished driving 40491 S1done S2done S3done S4done S5done S6done
# ['AB', [-10, -10, -10, -10, -10, -10], 2000, "Allbutton S1-6 clicked. With Values [-10, -10, -10, -10, -10, -10]'"]
# motorchange: [-10, -10, -10, -10, -10, -10] msg: Mfff6fff6fff6fff6fff6fff607d0 time: [2000]
# Time 1717492276.8737564  Reply first: M
# Time 1717492276.8787715  Reply This just in ... Mfff6fff6fff6fff6fff6fff607d0   M   -10   -10   -10   -10   -10   -10   2000   42106
# Time 1717492276.8797715  Reply Start driving42107
# Time 1717492278.8810642  Reply Finished driving 44107 S1done S2done S3done S4done S5done S6done
# ['AB', [-10, -10, -10, -10, -10, -10], 2000, "Allbutton S1-6 clicked. With Values [-10, -10, -10, -10, -10, -10]'"]
# motorchange: [-10, -10, -10, -10, -10, -10] msg: Mfff6fff6fff6fff6fff6fff607d0 time: [2000]
# Time 1717492279.4175243  Reply first: M
# Time 1717492279.4245074  Reply This just in ... Mfff6fff6fff6fff6fff6fff607d0   M   -10   -10   -10   -10   -10   -10   2000   44650
# Time 1717492279.4255188  Reply Start driving44651
# Time 1717492281.425605  Reply Finished driving 46651 S1done S2done S3done S4done S5done S6done
# ['SP', 'StartProtocol StartProtocol clicked.']
# 1717492288.547617 protocol iteration 0 [50, 50, 50, 50, 50, 50]
# Time 1717492288.5526109  Reply first: M
# Time 1717492288.5596106  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   53783
# Time 1717492288.5616097  Reply Start driving53784
# Time 1717492290.4590988  Reply Finished driving 55684 S1done S2done S3done S4done S5done S6done
# 1717492290.547617 protocol iteration 1 [-50, -50, -50, -50, -50, -50]
# Time 1717492290.5511043  Reply first: M
# Time 1717492290.5561047  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   55782
# Time 1717492290.5571067  Reply Start driving55783
# Time 1717492292.4584937  Reply Finished driving 57683 S1done S2done S3done S4done S5done S6done
# 1717492292.547617 protocol iteration 2 [50, 50, 50, 50, 50, 50]
# Time 1717492292.5514982  Reply first: M
# Time 1717492292.5594983  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   57782
# Time 1717492292.5604975  Reply Start driving57783
# Time 1717492294.4575036  Reply Finished driving 59683 S1done S2done S3done S4done S5done S6done
# 1717492294.547617 protocol iteration 3 [-50, -50, -50, -50, -50, -50]
# Time 1717492294.5515254  Reply first: M
# Time 1717492294.556509  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   59782
# Time 1717492294.557522  Reply Start driving59783
# Time 1717492296.460487  Reply Finished driving 61683 S1done S2done S3done S4done S5done S6done
# 1717492296.547617 protocol iteration 4 [50, 50, 50, 50, 50, 50]
# Time 1717492296.551464  Reply first: M
# Time 1717492296.556452  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   61780
# Time 1717492296.5574546  Reply Start driving61782
# Time 1717492298.459424  Reply Finished driving 63682 S1done S2done S3done S4done S5done S6done
# 1717492298.547617 protocol iteration 5 [-50, -50, -50, -50, -50, -50]
# Time 1717492298.5495355  Reply first: M
# Time 1717492298.557518  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   63780
# Time 1717492298.558523  Reply Start driving63781
# Time 1717492300.4578485  Reply Finished driving 65681 S1done S2done S3done S4done S5done S6done
# 1717492300.547617 protocol iteration 6 [50, 50, 50, 50, 50, 50]
# Time 1717492300.5522826  Reply first: M
# Time 1717492300.556265  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   65780
# Time 1717492300.5572681  Reply Start driving65781
# Time 1717492302.4581113  Reply Finished driving 67681 S1done S2done S3done S4done S5done S6done
# 1717492302.547617 protocol iteration 7 [-50, -50, -50, -50, -50, -50]
# Time 1717492302.5516584  Reply first: M
# Time 1717492302.5566456  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   67780
# Time 1717492302.5576587  Reply Start driving67781
# Time 1717492304.4588723  Reply Finished driving 69681 S1done S2done S3done S4done S5done S6done
# 1717492304.547617 protocol iteration 8 [50, 50, 50, 50, 50, 50]
# Time 1717492304.5509005  Reply first: M
# Time 1717492304.5578983  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   69779
# Time 1717492304.5588953  Reply Start driving69780
# Time 1717492306.4581208  Reply Finished driving 71680 S1done S2done S3done S4done S5done S6done
# 1717492306.547617 protocol iteration 9 [-50, -50, -50, -50, -50, -50]
# Time 1717492306.551125  Reply first: M
# Time 1717492306.5581267  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   71779
# Time 1717492306.5591254  Reply Start driving71780
# Time 1717492308.457702  Reply Finished driving 73680 S1done S2done S3done S4done S5done S6done
# 1717492308.547617 protocol iteration 10 [50, 50, 50, 50, 50, 50]
# Time 1717492308.5521326  Reply first: M
# Time 1717492308.5591319  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   73779
# Time 1717492308.560132  Reply Start driving73780
# Time 1717492310.4593816  Reply Finished driving 75680 S1done S2done S3done S4done S5done S6done
# 1717492310.547617 protocol iteration 11 [-50, -50, -50, -50, -50, -50]
# Time 1717492310.5510828  Reply first: M
# Time 1717492310.557097  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   75779
# Time 1717492310.5580935  Reply Start driving75780
# Time 1717492312.4588823  Reply Finished driving 77680 S1done S2done S3done S4done S5done S6done
# 1717492312.547617 protocol iteration 12 [50, 50, 50, 50, 50, 50]
# Time 1717492312.5491927  Reply first: M
# Time 1717492312.5572057  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   77777
# Time 1717492312.5582051  Reply Start driving77778
# Time 1717492314.4576175  Reply Finished driving 79678 S1done S2done S3done S4done S5done S6done
# 1717492314.547617 protocol iteration 13 [-50, -50, -50, -50, -50, -50]
# Time 1717492314.5516953  Reply first: M
# Time 1717492314.5576868  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   79778
# Time 1717492314.5576868  Reply Start driving79779
# Time 1717492316.4589286  Reply Finished driving 81679 S1done S2done S3done S4done S5done S6done
# 1717492316.547617 protocol iteration 14 [50, 50, 50, 50, 50, 50]
# Time 1717492316.551547  Reply first: M
# Time 1717492316.5562356  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   81777
# Time 1717492316.5562356  Reply Start driving81778
# Time 1717492318.4585385  Reply Finished driving 83678 S1done S2done S3done S4done S5done S6done
# 1717492318.547617 protocol iteration 15 [-50, -50, -50, -50, -50, -50]
# Time 1717492318.549757  Reply first: M
# Time 1717492318.5557773  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   83777
# Time 1717492318.5567734  Reply Start driving83778
# Time 1717492320.456439  Reply Finished driving 85678 S1done S2done S3done S4done S5done S6done
# 1717492320.547617 protocol iteration 16 [50, 50, 50, 50, 50, 50]
# Time 1717492320.5524628  Reply first: M
# Time 1717492320.5584438  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   85777
# Time 1717492320.560443  Reply Start driving85778
# Time 1717492322.4593792  Reply Finished driving 87678 S1done S2done S3done S4done S5done S6done
# 1717492322.547617 protocol iteration 17 [-50, -50, -50, -50, -50, -50]
# Time 1717492322.5513825  Reply first: M
# Time 1717492322.5563676  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   87777
# Time 1717492322.5583801  Reply Start driving87778
# Time 1717492324.459369  Reply Finished driving 89678 S1done S2done S3done S4done S5done S6done
# 1717492324.547617 protocol iteration 18 [50, 50, 50, 50, 50, 50]
# Time 1717492324.5500026  Reply first: M
# Time 1717492324.5560043  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   89776
# Time 1717492324.5570047  Reply Start driving89777
# Time 1717492326.4572253  Reply Finished driving 91677 S1done S2done S3done S4done S5done S6done
# 1717492326.547617 protocol iteration 19 [-50, -50, -50, -50, -50, -50]
# Time 1717492326.5508165  Reply first: M
# Time 1717492326.5568192  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   91776
# Time 1717492326.5578187  Reply Start driving91777
# Time 1717492328.4585767  Reply Finished driving 93677 S1done S2done S3done S4done S5done S6done
# 1717492328.547617 protocol iteration 20 [50, 50, 50, 50, 50, 50]
# Time 1717492328.5518985  Reply first: M
# Time 1717492328.5558963  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   93775
# Time 1717492328.5568986  Reply Start driving93776
# Time 1717492330.4590902  Reply Finished driving 95676 S1done S2done S3done S4done S5done S6done
# 1717492330.547617 protocol iteration 21 [-50, -50, -50, -50, -50, -50]
# Time 1717492330.5496428  Reply first: M
# Time 1717492330.5556228  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   95775
# Time 1717492330.5566285  Reply Start driving95776
# Time 1717492332.4590683  Reply Finished driving 97676 S1done S2done S3done S4done S5done S6done
# 1717492332.547617 protocol iteration 22 [50, 50, 50, 50, 50, 50]
# Time 1717492332.551359  Reply first: M
# Time 1717492332.5553477  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   97774
# Time 1717492332.556363  Reply Start driving97775
# Time 1717492334.4562428  Reply Finished driving 99675 S1done S2done S3done S4done S5done S6done
# 1717492334.547617 protocol iteration 23 [-50, -50, -50, -50, -50, -50]
# Time 1717492334.5506806  Reply first: M
# Time 1717492334.5556808  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   99774
# Time 1717492334.556683  Reply Start driving99775
# Time 1717492336.4566493  Reply Finished driving 101675 S1done S2done S3done S4done S5done S6done
# 1717492336.547617 protocol iteration 24 [50, 50, 50, 50, 50, 50]
# Time 1717492336.550655  Reply first: M
# Time 1717492336.5566561  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   101774
# Time 1717492336.557657  Reply Start driving101774
# Time 1717492338.4589336  Reply Finished driving 103675 S1done S2done S3done S4done S5done S6done
# 1717492338.547617 protocol iteration 25 [-50, -50, -50, -50, -50, -50]
# Time 1717492338.5519412  Reply first: M
# Time 1717492338.556945  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   103774
# Time 1717492338.557946  Reply Start driving103775
# Time 1717492340.4576595  Reply Finished driving 105675 S1done S2done S3done S4done S5done S6done
# 1717492340.547617 protocol iteration 26 [50, 50, 50, 50, 50, 50]
# Time 1717492340.551681  Reply first: M
# Time 1717492340.555667  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   105773
# Time 1717492340.5566673  Reply Start driving105774
# Time 1717492342.4580781  Reply Finished driving 107674 S1done S2done S3done S4done S5done S6done
# 1717492342.547617 protocol iteration 27 [-50, -50, -50, -50, -50, -50]
# Time 1717492342.5511713  Reply first: M
# Time 1717492342.5551717  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   107772
# Time 1717492342.5561733  Reply Start driving107773
# Time 1717492344.4583821  Reply Finished driving 109673 S1done S2done S3done S4done S5done S6done
# 1717492344.547617 protocol iteration 28 [50, 50, 50, 50, 50, 50]
# Time 1717492344.5497584  Reply first: M
# Time 1717492344.5577533  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   109772
# Time 1717492344.5587602  Reply Start driving109773
# Time 1717492346.4569032  Reply Finished driving 111673 S1done S2done S3done S4done S5done S6done
# 1717492346.547617 protocol iteration 29 [-50, -50, -50, -50, -50, -50]
# Time 1717492346.5515873  Reply first: M
# Time 1717492346.5585878  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   111772
# Time 1717492346.559588  Reply Start driving111773
# Time 1717492348.4566908  Reply Finished driving 113673 S1done S2done S3done S4done S5done S6done
# 1717492348.547617 protocol iteration 30 [50, 50, 50, 50, 50, 50]
# Time 1717492348.5510006  Reply first: M
# Time 1717492348.5560043  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   113772
# Time 1717492348.5570042  Reply Start driving113772
# Time 1717492350.4592412  Reply Finished driving 115673 S1done S2done S3done S4done S5done S6done
# 1717492350.547617 protocol iteration 31 [-50, -50, -50, -50, -50, -50]
# Time 1717492350.5502467  Reply first: M
# Time 1717492350.557247  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   115772
# Time 1717492350.5592444  Reply Start driving115773
# Time 1717492352.4577432  Reply Finished driving 117673 S1done S2done S3done S4done S5done S6done
# 1717492352.547617 protocol iteration 32 [50, 50, 50, 50, 50, 50]
# Time 1717492352.5517304  Reply first: M
# Time 1717492352.555734  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   117771
# Time 1717492352.5567324  Reply Start driving117772
# Time 1717492354.4590619  Reply Finished driving 119672 S1done S2done S3done S4done S5done S6done
# 1717492354.547617 protocol iteration 33 [-50, -50, -50, -50, -50, -50]
# Time 1717492354.5510507  Reply first: M
# Time 1717492354.557067  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   119771
# Time 1717492354.5580685  Reply Start driving119772
# Time 1717492356.4588594  Reply Finished driving 121672 S1done S2done S3done S4done S5done S6done
# 1717492356.547617 protocol iteration 34 [50, 50, 50, 50, 50, 50]
# Time 1717492356.5508673  Reply first: M
# Time 1717492356.5558746  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   121771
# Time 1717492356.55687  Reply Start driving121771
# Time 1717492358.457238  Reply Finished driving 123672 S1done S2done S3done S4done S5done S6done
# 1717492358.547617 protocol iteration 35 [-50, -50, -50, -50, -50, -50]
# Time 1717492358.5517583  Reply first: M
# Time 1717492358.5567462  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   123770
# Time 1717492358.5577574  Reply Start driving123771
# Time 1717492360.456341  Reply Finished driving 125671 S1done S2done S3done S4done S5done S6done
# 1717492360.547617 protocol iteration 36 [50, 50, 50, 50, 50, 50]
# Time 1717492360.55136  Reply first: M
# Time 1717492360.5563715  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   125770
# Time 1717492360.5583487  Reply Start driving125770
# Time 1717492362.4582877  Reply Finished driving 127671 S1done S2done S3done S4done S5done S6done
# 1717492362.547617 protocol iteration 37 [-50, -50, -50, -50, -50, -50]
# Time 1717492362.5506773  Reply first: M
# Time 1717492362.5556624  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   127769
# Time 1717492362.556686  Reply Start driving127770
# Time 1717492364.458299  Reply Finished driving 129671 S1done S2done S3done S4done S5done S6done
# 1717492364.547617 protocol iteration 38 [50, 50, 50, 50, 50, 50]
# Time 1717492364.5521197  Reply first: M
# Time 1717492364.5581195  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   129769
# Time 1717492364.559126  Reply Start driving129770
# Time 1717492366.4573033  Reply Finished driving 131670 S1done S2done S3done S4done S5done S6done
# 1717492366.547617 protocol iteration 39 [-50, -50, -50, -50, -50, -50]
# Time 1717492366.5521476  Reply first: M
# Time 1717492366.5591333  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   131769
# Time 1717492366.5601332  Reply Start driving131770
# Time 1717492368.460212  Reply Finished driving 133670 S1done S2done S3done S4done S5done S6done
# 1717492368.547617 protocol iteration 40 [50, 50, 50, 50, 50, 50]
# Time 1717492368.5512981  Reply first: M
# Time 1717492368.5563004  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   133769
# Time 1717492368.5572999  Reply Start driving133769
# Time 1717492370.4581735  Reply Finished driving 135670 S1done S2done S3done S4done S5done S6done
# 1717492370.547617 protocol iteration 41 [-50, -50, -50, -50, -50, -50]
# Time 1717492370.5486913  Reply first: M
# Time 1717492370.5556931  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   135768
# Time 1717492370.5566912  Reply Start driving135769
# Time 1717492372.4565823  Reply Finished driving 137669 S1done S2done S3done S4done S5done S6done
# 1717492372.547617 protocol iteration 42 [50, 50, 50, 50, 50, 50]
# Time 1717492372.5515723  Reply first: M
# Time 1717492372.5575871  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   137768
# Time 1717492372.5585957  Reply Start driving137768
# Time 1717492374.4607446  Reply Finished driving 139669 S1done S2done S3done S4done S5done S6done
# 1717492374.547617 protocol iteration 43 [-50, -50, -50, -50, -50, -50]
# Time 1717492374.5512488  Reply first: M
# Time 1717492374.558245  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   139767
# Time 1717492374.5602422  Reply Start driving139768
# Time 1717492376.4575853  Reply Finished driving 141668 S1done S2done S3done S4done S5done S6done
# 1717492376.547617 protocol iteration 44 [50, 50, 50, 50, 50, 50]
# Time 1717492376.5515122  Reply first: M
# Time 1717492376.5575304  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   141767
# Time 1717492376.559532  Reply Start driving141768
# Time 1717492378.4576688  Reply Finished driving 143668 S1done S2done S3done S4done S5done S6done
# 1717492378.547617 protocol iteration 45 [-50, -50, -50, -50, -50, -50]
# Time 1717492378.5509508  Reply first: M
# Time 1717492378.5559556  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   143766
# Time 1717492378.556957  Reply Start driving143767
# Time 1717492380.4563375  Reply Finished driving 145667 S1done S2done S3done S4done S5done S6done
# 1717492380.547617 protocol iteration 46 [50, 50, 50, 50, 50, 50]
# Time 1717492380.5519106  Reply first: M
# Time 1717492380.5569265  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   145767
# Time 1717492380.5579278  Reply Start driving145767
# Time 1717492382.4588099  Reply Finished driving 147668 S1done S2done S3done S4done S5done S6done
# 1717492382.547617 protocol iteration 47 [-50, -50, -50, -50, -50, -50]
# Time 1717492382.5495386  Reply first: M
# Time 1717492382.5575342  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   147766
# Time 1717492382.5585387  Reply Start driving147767
# Time 1717492384.458316  Reply Finished driving 149667 S1done S2done S3done S4done S5done S6done
# 1717492384.547617 protocol iteration 48 [50, 50, 50, 50, 50, 50]
# Time 1717492384.552324  Reply first: M
# Time 1717492384.559325  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   149766
# Time 1717492384.5603242  Reply Start driving149767
# Time 1717492386.4604578  Reply Finished driving 151667 S1done S2done S3done S4done S5done S6done
# 1717492386.547617 protocol iteration 49 [-50, -50, -50, -50, -50, -50]
# Time 1717492386.5524566  Reply first: M
# Time 1717492386.559443  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   151766
# Time 1717492386.560443  Reply Start driving151767
# Time 1717492388.4592998  Reply Finished driving 153667 S1done S2done S3done S4done S5done S6done
# 1717492388.547617 protocol iteration 50 [50, 50, 50, 50, 50, 50]
# Time 1717492388.5498867  Reply first: M
# Time 1717492388.5558891  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   153764
# Time 1717492388.5568914  Reply Start driving153765
# Time 1717492390.4583693  Reply Finished driving 155665 S1done S2done S3done S4done S5done S6done
# 1717492390.547617 protocol iteration 51 [-50, -50, -50, -50, -50, -50]
# Time 1717492390.5513408  Reply first: M
# Time 1717492390.556337  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   155764
# Time 1717492390.5573404  Reply Start driving155765
# Time 1717492392.4568214  Reply Finished driving 157665 S1done S2done S3done S4done S5done S6done
# 1717492392.547617 protocol iteration 52 [50, 50, 50, 50, 50, 50]
# Time 1717492392.5520608  Reply first: M
# Time 1717492392.558111  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   157764
# Time 1717492392.5591128  Reply Start driving157765
# Time 1717492394.457797  Reply Finished driving 159665 S1done S2done S3done S4done S5done S6done
# 1717492394.547617 protocol iteration 53 [-50, -50, -50, -50, -50, -50]
# Time 1717492394.5509024  Reply first: M
# Time 1717492394.5559037  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   159764
# Time 1717492394.556903  Reply Start driving159764
# Time 1717492396.4574227  Reply Finished driving 161665 S1done S2done S3done S4done S5done S6done
# 1717492396.547617 protocol iteration 54 [50, 50, 50, 50, 50, 50]
# Time 1717492396.5513923  Reply first: M
# Time 1717492396.5563927  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   161763
# Time 1717492396.5573926  Reply Start driving161764
# Time 1717492398.4603066  Reply Finished driving 163665 S1done S2done S3done S4done S5done S6done
# 1717492398.547617 protocol iteration 55 [-50, -50, -50, -50, -50, -50]
# Time 1717492398.5524693  Reply first: M
# Time 1717492398.5604718  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   163764
# Time 1717492398.5614703  Reply Start driving163764
# Time 1717492400.4604938  Reply Finished driving 165665 S1done S2done S3done S4done S5done S6done
# 1717492400.547617 protocol iteration 56 [50, 50, 50, 50, 50, 50]
# Time 1717492400.5504982  Reply first: M
# Time 1717492400.556504  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   165763
# Time 1717492400.557507  Reply Start driving165764
# Time 1717492402.4592805  Reply Finished driving 167665 S1done S2done S3done S4done S5done S6done
# 1717492402.547617 protocol iteration 57 [-50, -50, -50, -50, -50, -50]
# Time 1717492402.5512905  Reply first: M
# Time 1717492402.5572865  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   167762
# Time 1717492402.5582876  Reply Start driving167763
# Time 1717492404.4594998  Reply Finished driving 169663 S1done S2done S3done S4done S5done S6done
# 1717492404.547617 protocol iteration 58 [50, 50, 50, 50, 50, 50]
# Time 1717492404.5525095  Reply first: M
# Time 1717492404.5615096  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   169762
# Time 1717492404.5635092  Reply Start driving169763
# Time 1717492406.4577985  Reply Finished driving 171663 S1done S2done S3done S4done S5done S6done
# 1717492406.547617 protocol iteration 59 [-50, -50, -50, -50, -50, -50]
# Time 1717492406.5514688  Reply first: M
# Time 1717492406.5584843  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   171761
# Time 1717492406.559486  Reply Start driving171762
# Time 1717492408.4589014  Reply Finished driving 173663 S1done S2done S3done S4done S5done S6done
# 1717492408.547617 protocol iteration 60 [50, 50, 50, 50, 50, 50]
# Time 1717492408.550187  Reply first: M
# Time 1717492408.5551755  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   173761
# Time 1717492408.5561888  Reply Start driving173762
# Time 1717492410.458907  Reply Finished driving 175662 S1done S2done S3done S4done S5done S6done
# 1717492410.547617 protocol iteration 61 [-50, -50, -50, -50, -50, -50]
# Time 1717492410.551289  Reply first: M
# Time 1717492410.5572674  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   175761
# Time 1717492410.5582676  Reply Start driving175762
# Time 1717492412.4593713  Reply Finished driving 177662 S1done S2done S3done S4done S5done S6done
# 1717492412.547617 protocol iteration 62 [50, 50, 50, 50, 50, 50]
# Time 1717492412.55171  Reply first: M
# Time 1717492412.5587308  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   177760
# Time 1717492412.5607471  Reply Start driving177761
# Time 1717492414.458852  Reply Finished driving 179661 S1done S2done S3done S4done S5done S6done
# 1717492414.547617 protocol iteration 63 [-50, -50, -50, -50, -50, -50]
# Time 1717492414.5501804  Reply first: M
# Time 1717492414.5561833  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   179760
# Time 1717492414.5571787  Reply Start driving179761
# Time 1717492416.4588926  Reply Finished driving 181661 S1done S2done S3done S4done S5done S6done
# 1717492416.547617 protocol iteration 64 [50, 50, 50, 50, 50, 50]
# Time 1717492416.5519004  Reply first: M
# Time 1717492416.5568993  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   181760
# Time 1717492416.5578995  Reply Start driving181761
# Time 1717492418.4574742  Reply Finished driving 183661 S1done S2done S3done S4done S5done S6done
# 1717492418.547617 protocol iteration 65 [-50, -50, -50, -50, -50, -50]
# Time 1717492418.5524852  Reply first: M
# Time 1717492418.5584848  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   183759
# Time 1717492418.5594862  Reply Start driving183760
# Time 1717492420.4589548  Reply Finished driving 185661 S1done S2done S3done S4done S5done S6done
# 1717492420.547617 protocol iteration 66 [50, 50, 50, 50, 50, 50]
# Time 1717492420.550048  Reply first: M
# Time 1717492420.5560346  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   185759
# Time 1717492420.5570512  Reply Start driving185760
# Time 1717492422.457773  Reply Finished driving 187660 S1done S2done S3done S4done S5done S6done
# 1717492422.547617 protocol iteration 67 [-50, -50, -50, -50, -50, -50]
# Time 1717492422.5515735  Reply first: M
# Time 1717492422.556566  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   187759
# Time 1717492422.5575726  Reply Start driving187760
# Time 1717492424.4568074  Reply Finished driving 189660 S1done S2done S3done S4done S5done S6done
# 1717492424.547617 protocol iteration 68 [50, 50, 50, 50, 50, 50]
# Time 1717492424.5513866  Reply first: M
# Time 1717492424.5563838  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   189758
# Time 1717492424.5573843  Reply Start driving189759
# Time 1717492426.4558015  Reply Finished driving 191659 S1done S2done S3done S4done S5done S6done
# 1717492426.547617 protocol iteration 69 [-50, -50, -50, -50, -50, -50]
# Time 1717492426.551202  Reply first: M
# Time 1717492426.5562024  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   191758
# Time 1717492426.5572026  Reply Start driving191759
# Time 1717492428.4573927  Reply Finished driving 193659 S1done S2done S3done S4done S5done S6done
# 1717492428.547617 protocol iteration 70 [50, 50, 50, 50, 50, 50]
# Time 1717492428.5526636  Reply first: M
# Time 1717492428.5596588  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   193758
# Time 1717492428.560659  Reply Start driving193759
# Time 1717492430.4576519  Reply Finished driving 195659 S1done S2done S3done S4done S5done S6done
# 1717492430.547617 protocol iteration 71 [-50, -50, -50, -50, -50, -50]
# Time 1717492430.5519333  Reply first: M
# Time 1717492430.5639367  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   195758
# Time 1717492430.5649428  Reply Start driving195758
# Time 1717492432.4605656  Reply Finished driving 197659 S1done S2done S3done S4done S5done S6done
# 1717492432.547617 protocol iteration 72 [50, 50, 50, 50, 50, 50]
# Time 1717492432.5510798  Reply first: M
# Time 1717492432.55808  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   197756
# Time 1717492432.5600803  Reply Start driving197757
# Time 1717492434.4583673  Reply Finished driving 199658 S1done S2done S3done S4done S5done S6done
# 1717492434.547617 protocol iteration 73 [-50, -50, -50, -50, -50, -50]
# Time 1717492434.5491686  Reply first: M
# Time 1717492434.5571694  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   199756
# Time 1717492434.55917  Reply Start driving199757
# Time 1717492436.4567418  Reply Finished driving 201658 S1done S2done S3done S4done S5done S6done
# 1717492436.547617 protocol iteration 74 [50, 50, 50, 50, 50, 50]
# Time 1717492436.5523562  Reply first: M
# Time 1717492436.5593565  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   201756
# Time 1717492436.5603578  Reply Start driving201757
# Time 1717492438.4561076  Reply Finished driving 203657 S1done S2done S3done S4done S5done S6done
# 1717492438.547617 protocol iteration 75 [-50, -50, -50, -50, -50, -50]
# Time 1717492438.5511143  Reply first: M
# Time 1717492438.5561147  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   203756
# Time 1717492438.5571146  Reply Start driving203756
# Time 1717492440.4591074  Reply Finished driving 205657 S1done S2done S3done S4done S5done S6done
# 1717492440.547617 protocol iteration 76 [50, 50, 50, 50, 50, 50]
# Time 1717492440.550378  Reply first: M
# Time 1717492440.5573819  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   205756
# Time 1717492440.5593827  Reply Start driving205756
# Time 1717492442.4591842  Reply Finished driving 207657 S1done S2done S3done S4done S5done S6done
# 1717492442.547617 protocol iteration 77 [-50, -50, -50, -50, -50, -50]
# Time 1717492442.5521915  Reply first: M
# Time 1717492442.5571916  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   207756
# Time 1717492442.5581915  Reply Start driving207756
# Time 1717492444.4609675  Reply Finished driving 209657 S1done S2done S3done S4done S5done S6done
# 1717492444.547617 protocol iteration 78 [50, 50, 50, 50, 50, 50]
# Time 1717492444.5517359  Reply first: M
# Time 1717492444.5577552  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   209755
# Time 1717492444.5597537  Reply Start driving209756
# Time 1717492446.4594994  Reply Finished driving 211656 S1done S2done S3done S4done S5done S6done
# 1717492446.547617 protocol iteration 79 [-50, -50, -50, -50, -50, -50]
# Time 1717492446.550768  Reply first: M
# Time 1717492446.5577843  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   211755
# Time 1717492446.5587835  Reply Start driving211756
# Time 1717492448.458671  Reply Finished driving 213657 S1done S2done S3done S4done S5done S6done
# 1717492448.547617 protocol iteration 80 [50, 50, 50, 50, 50, 50]
# Time 1717492448.551693  Reply first: M
# Time 1717492448.560679  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   213753
# Time 1717492448.5626924  Reply Start driving213754
# Time 1717492450.4573712  Reply Finished driving 215655 S1done S2done S3done S4done S5done S6done
# 1717492450.547617 protocol iteration 81 [-50, -50, -50, -50, -50, -50]
# Time 1717492450.5523787  Reply first: M
# Time 1717492450.55938  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   215754
# Time 1717492450.5603795  Reply Start driving215755
# Time 1717492452.4598126  Reply Finished driving 217655 S1done S2done S3done S4done S5done S6done
# 1717492452.547617 protocol iteration 82 [50, 50, 50, 50, 50, 50]
# Time 1717492452.5508027  Reply first: M
# Time 1717492452.5578196  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   217753
# Time 1717492452.5588188  Reply Start driving217754
# Time 1717492454.4582558  Reply Finished driving 219654 S1done S2done S3done S4done S5done S6done
# 1717492454.547617 protocol iteration 83 [-50, -50, -50, -50, -50, -50]
# Time 1717492454.5512817  Reply first: M
# Time 1717492454.5572789  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   219753
# Time 1717492454.5582855  Reply Start driving219754
# Time 1717492456.4568412  Reply Finished driving 221654 S1done S2done S3done S4done S5done S6done
# 1717492456.547617 protocol iteration 84 [50, 50, 50, 50, 50, 50]
# Time 1717492456.5520859  Reply first: M
# Time 1717492456.5570853  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   221753
# Time 1717492456.5580866  Reply Start driving221754
# Time 1717492458.4617455  Reply Finished driving 223654 S1done S2done S3done S4done S5done S6done
# 1717492458.547617 protocol iteration 85 [-50, -50, -50, -50, -50, -50]
# Time 1717492458.5515933  Reply first: M
# Time 1717492458.558842  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   223753
# Time 1717492458.560844  Reply Start driving223753
# Time 1717492460.4575849  Reply Finished driving 225654 S1done S2done S3done S4done S5done S6done
# 1717492460.547617 protocol iteration 86 [50, 50, 50, 50, 50, 50]
# Time 1717492460.5525901  Reply first: M
# Time 1717492460.56059  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   225753
# Time 1717492460.5625901  Reply Start driving225754
# Time 1717492462.4581559  Reply Finished driving 227654 S1done S2done S3done S4done S5done S6done
# 1717492462.547617 protocol iteration 87 [-50, -50, -50, -50, -50, -50]
# Time 1717492462.5511734  Reply first: M
# Time 1717492462.5571558  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   227751
# Time 1717492462.5581722  Reply Start driving227752
# Time 1717492464.45542  Reply Finished driving 229652 S1done S2done S3done S4done S5done S6done
# 1717492464.547617 protocol iteration 88 [50, 50, 50, 50, 50, 50]
# Time 1717492464.5514212  Reply first: M
# Time 1717492464.558426  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   229751
# Time 1717492464.5594237  Reply Start driving229752
# Time 1717492466.4582856  Reply Finished driving 231652 S1done S2done S3done S4done S5done S6done
# 1717492466.547617 protocol iteration 89 [-50, -50, -50, -50, -50, -50]
# Time 1717492466.550293  Reply first: M
# Time 1717492466.559292  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   231751
# Time 1717492466.561294  Reply Start driving231752
# Time 1717492468.4580557  Reply Finished driving 233652 S1done S2done S3done S4done S5done S6done
# 1717492468.547617 protocol iteration 90 [50, 50, 50, 50, 50, 50]
# Time 1717492468.5507886  Reply first: M
# Time 1717492468.5587902  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   233750
# Time 1717492468.5597908  Reply Start driving233751
# Time 1717492470.4568546  Reply Finished driving 235651 S1done S2done S3done S4done S5done S6done
# 1717492470.547617 protocol iteration 91 [-50, -50, -50, -50, -50, -50]
# Time 1717492470.5508618  Reply first: M
# Time 1717492470.5578635  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   235750
# Time 1717492470.5588636  Reply Start driving235751
# Time 1717492472.460392  Reply Finished driving 237651 S1done S2done S3done S4done S5done S6done
# 1717492472.547617 protocol iteration 92 [50, 50, 50, 50, 50, 50]
# Time 1717492472.5497684  Reply first: M
# Time 1717492472.5567703  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   237750
# Time 1717492472.5577662  Reply Start driving237751
# Time 1717492474.4579313  Reply Finished driving 239652 S1done S2done S3done S4done S5done S6done
# 1717492474.547617 protocol iteration 93 [-50, -50, -50, -50, -50, -50]
# Time 1717492474.5510654  Reply first: M
# Time 1717492474.5590672  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   239750
# Time 1717492474.5600677  Reply Start driving239751
# Time 1717492476.458246  Reply Finished driving 241651 S1done S2done S3done S4done S5done S6done
# 1717492476.547617 protocol iteration 94 [50, 50, 50, 50, 50, 50]
# Time 1717492476.5513618  Reply first: M
# Time 1717492476.5563772  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   241750
# Time 1717492476.5573814  Reply Start driving241751
# Time 1717492478.4587255  Reply Finished driving 243651 S1done S2done S3done S4done S5done S6done
# 1717492478.547617 protocol iteration 95 [-50, -50, -50, -50, -50, -50]
# Time 1717492478.5508869  Reply first: M
# Time 1717492478.5574393  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   243748
# Time 1717492478.5594397  Reply Start driving243749
# Time 1717492480.4573874  Reply Finished driving 245649 S1done S2done S3done S4done S5done S6done
# 1717492480.547617 protocol iteration 96 [50, 50, 50, 50, 50, 50]
# Time 1717492480.5523827  Reply first: M
# Time 1717492480.5603786  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   245748
# Time 1717492480.561378  Reply Start driving245749
# Time 1717492482.4567318  Reply Finished driving 247650 S1done S2done S3done S4done S5done S6done
# 1717492482.547617 protocol iteration 97 [-50, -50, -50, -50, -50, -50]
# Time 1717492482.55074  Reply first: M
# Time 1717492482.556742  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   247748
# Time 1717492482.5577416  Reply Start driving247749
# Time 1717492484.4572759  Reply Finished driving 249649 S1done S2done S3done S4done S5done S6done
# 1717492484.547617 protocol iteration 98 [50, 50, 50, 50, 50, 50]
# Time 1717492484.5506375  Reply first: M
# Time 1717492484.5576522  Reply This just in ... M003200320032003200320032076c   M   50   50   50   50   50   50   1900   249748
# Time 1717492484.55866  Reply Start driving249749
# Time 1717492486.458797  Reply Finished driving 251649 S1done S2done S3done S4done S5done S6done
# 1717492486.547617 protocol iteration 99 [-50, -50, -50, -50, -50, -50]
# protocol finished
# Time 1717492486.548793  Reply first: M
# Time 1717492486.555795  Reply This just in ... Mffceffceffceffceffceffce076c   M   -50   -50   -50   -50   -50   -50   1900   251747
# Time 1717492486.556795  Reply Start driving251748
# Time 1717492488.456422  Reply Finished driving 253648 S1done S2done S3done S4done S5done S6done
